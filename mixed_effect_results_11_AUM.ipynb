# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)

# %% [markdown]
# # This analysis is for the version AM_n001_10s_B1, SNR, risk division

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1 Dataset_AU/trialsAUM_10s_B1.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# divid the data by the sign of the initial bias "x0". 
# risk lovers
data1_L <- subset(data1, x0 > 0) 
# risk haters
data1_H <- subset(data1, x0 < 0) 


# # Similarly, create another dataset in wh subjects with error_choice > 5 are rejected
# data2 <- subset(data1, error_choice <= 5)
# data2_L <- subset(data2, x0 > 0)
# data2_H <- subset(data2, x0 < 0)

# %% [markdown]
# # Predicting choice with the full set of DDM paramerters (SNR, x0)

# %% [markdown]
# ###  All continuous variables are scaled due to the inclusion of interactive terms and to avoid the error "Model failed to converge with max|grad|".
# Interactive effects between the "SNR and x0" are included.

# %%
# all subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0)):treatment + (1|subject), data1))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(SNR) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18056.9
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.54995 -0.90761 -0.04787  0.87698  3.14696
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007206 0.08489
#  Residual             0.192621 0.43889
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.772e-01  1.116e-02  6.400e+01  42.776
# scale(lottery_favour):treatmentA  1.763e-01  5.614e-03  1.227e+04  31.406
# scale(lottery_favour):treatmentE  1.949e-01  5.792e-03  1.333e+04  33.654
# scale(SNR):treatmentA             2.239e-02  1.591e-02  6.358e+01   1.408
# scale(SNR):treatmentE             7.315e-02  1.638e-02  6.359e+01   4.466
# scale(x0):treatmentA              1.420e-01  1.390e-02  6.378e+01  10.214
# scale(x0):treatmentE              1.514e-01  1.794e-02  6.345e+01   8.441
# scale(SNR):scale(x0):treatmentA  -1.979e-02  1.886e-02  6.373e+01  -1.049
# scale(SNR):scale(x0):treatmentE   5.225e-03  2.143e-02  6.345e+01   0.244
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(SNR):treatmentA               0.164
# scale(SNR):treatmentE            3.34e-05 ***
# scale(x0):treatmentA             4.73e-15 ***
# scale(x0):treatmentE             5.74e-12 ***
# scale(SNR):scale(x0):treatmentA     0.298
# scale(SNR):scale(x0):treatmentE     0.808
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(SNR):A s(SNR):E s(0):A s(0):E s(SNR):(0):A
# scl(ltt_):A   0.038
# scl(ltt_):E  -0.042 -0.002
# scl(SNR):tA   0.073  0.009 -0.003
# scl(SNR):tE   0.051  0.002  0.025  0.004
# scl(x0):trA  -0.092 -0.017  0.004 -0.226   -0.005
# scl(x0):trE   0.154  0.006 -0.001  0.011    0.080   -0.014
# s(SNR):(0):A -0.236  0.016  0.010 -0.282   -0.012   -0.049 -0.036
# s(SNR):(0):E  0.053  0.002  0.008  0.004    0.345   -0.005  0.164 -0.013

# %%
# risk-loveing subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0)):treatment + (1|subject), data1_L))

# summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0)):treatment + (1|subject), subset(data1, x0>0.2)))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(SNR) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data1_L
#
# REML criterion at convergence: 7260.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.5673 -1.0437  0.3798  0.7940  2.6632
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005878 0.07667
#  Residual             0.200161 0.44739
# Number of obs: 5826, groups:  subject, 28
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       6.287e-01  2.033e-02  2.039e+01  30.919
# scale(lottery_favour):treatmentA  1.951e-01  8.082e-03  4.252e+03  24.144
# scale(lottery_favour):treatmentE  1.917e-01  1.188e-02  4.996e+03  16.131
# scale(SNR):treatmentA             1.123e-02  2.300e-02  2.031e+01   0.488
# scale(SNR):treatmentE             1.485e-01  4.006e-02  2.061e+01   3.707
# scale(x0):treatmentA              8.834e-02  2.037e-02  2.031e+01   4.338
# scale(x0):treatmentE              5.789e-02  4.383e-02  2.033e+01   1.321
# scale(SNR):scale(x0):treatmentA  -2.644e-02  2.348e-02  2.030e+01  -1.126
# scale(SNR):scale(x0):treatmentE  -1.113e-01  4.539e-02  2.077e+01  -2.453
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(SNR):treatmentA             0.63059
# scale(SNR):treatmentE             0.00134 **
# scale(x0):treatmentA              0.00031 ***
# scale(x0):treatmentE              0.20121
# scale(SNR):scale(x0):treatmentA   0.27332
# scale(SNR):scale(x0):treatmentE   0.02311 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(SNR):A s(SNR):E s(0):A s(0):E s(SNR):(0):A
# scl(ltt_):A   0.032
# scl(ltt_):E  -0.024 -0.001
# scl(SNR):tA  -0.296  0.032  0.007
# scl(SNR):tE   0.280  0.009  0.087 -0.083
# scl(x0):trA   0.109  0.025 -0.003 -0.527    0.031
# scl(x0):trE  -0.168 -0.005  0.029  0.050   -0.477   -0.018
# s(SNR):(0):A -0.580  0.001  0.014  0.401   -0.162   -0.103  0.097
# s(SNR):(0):E -0.330 -0.011 -0.093  0.098   -0.332   -0.036  0.206  0.191

# %%
# risk-hating subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0)):treatment + (1|subject), data1_H))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(SNR) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data1_H
#
# REML criterion at convergence: 10810
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2422 -0.8449 -0.2744  0.9490  3.0872
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006024 0.07761
#  Residual             0.187670 0.43321
# Number of obs: 9161, groups:  subject, 44
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       3.935e-01  1.290e-02  3.672e+01  30.492
# scale(lottery_favour):treatmentA  1.577e-01  7.846e-03  7.334e+03  20.096
# scale(lottery_favour):treatmentE  1.961e-01  6.572e-03  8.128e+03  29.833
# scale(SNR):treatmentA             2.272e-02  2.448e-02  3.648e+01   0.928
# scale(SNR):treatmentE             6.278e-02  1.670e-02  3.631e+01   3.759
# scale(x0):treatmentA              1.031e-01  1.910e-02  3.675e+01   5.396
# scale(x0):treatmentE              1.295e-01  2.367e-02  3.670e+01   5.470
# scale(SNR):scale(x0):treatmentA  -3.395e-02  2.434e-02  3.682e+01  -1.395
# scale(SNR):scale(x0):treatmentE  -7.016e-03  2.950e-02  3.675e+01  -0.238
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(SNR):treatmentA            0.359463
# scale(SNR):treatmentE            0.000599 ***
# scale(x0):treatmentA             4.21e-06 ***
# scale(x0):treatmentE             3.35e-06 ***
# scale(SNR):scale(x0):treatmentA  0.171366
# scale(SNR):scale(x0):treatmentE  0.813338
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(SNR):A s(SNR):E s(0):A s(0):E s(SNR):(0):A
# scl(ltt_):A   0.059
# scl(ltt_):E  -0.042 -0.002
# scl(SNR):tA   0.075  0.005 -0.003
# scl(SNR):tE   0.029  0.002  0.016  0.002
# scl(x0):trA  -0.017 -0.049  0.001 -0.423    0.000
# scl(x0):trE  -0.129 -0.008 -0.013 -0.010   -0.180    0.002
# s(SNR):(0):A -0.168 -0.055  0.007 -0.520   -0.005    0.493  0.022
# s(SNR):(0):E -0.090 -0.005 -0.029 -0.007   -0.291    0.001  0.557  0.015

# %% [markdown]
# #  Predicting choice with the DDM paramerters and psychometric measurements
# Interactive effects between the SNR and x0, reflection and BNT; and reflection and BNT are included.

# %%
# all subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) + scale(SNR):scale(BNT)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(SNR) * scale(x0) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) +
#     scale(SNR):scale(BNT)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18130.1
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.56024 -0.90677 -0.05043  0.87677  3.14683
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007285 0.08535
#  Residual             0.192619 0.43888
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              4.764e-01  1.526e-02  5.011e+01
# scale(lottery_favour):treatmentA         1.769e-01  5.629e-03  1.236e+04
# scale(lottery_favour):treatmentE         1.955e-01  5.814e-03  1.385e+04
# scale(SNR):treatmentA                    1.589e-02  2.045e-02  5.012e+01
# scale(SNR):treatmentE                    7.827e-02  2.022e-02  4.992e+01
# scale(x0):treatmentA                     1.466e-01  1.544e-02  5.004e+01
# scale(x0):treatmentE                     1.489e-01  2.110e-02  4.994e+01
# scale(reflection):treatmentA             3.215e-03  2.142e-02  5.000e+01
# scale(reflection):treatmentE             2.798e-02  2.045e-02  5.013e+01
# scale(BNT):treatmentA                    1.648e-03  2.294e-02  5.018e+01
# scale(BNT):treatmentE                   -3.152e-02  1.802e-02  4.995e+01
# scale(NFC):treatmentA                    9.189e-03  2.041e-02  5.003e+01
# scale(NFC):treatmentE                   -7.234e-03  1.486e-02  5.004e+01
# scale(FI):treatmentA                    -1.744e-02  1.694e-02  5.004e+01
# scale(FI):treatmentE                     2.461e-02  1.862e-02  5.010e+01
# scale(SNR):scale(x0):treatmentA         -2.087e-02  2.210e-02  5.013e+01
# scale(SNR):scale(x0):treatmentE          2.295e-02  2.544e-02  4.996e+01
# scale(reflection):scale(BNT):treatmentA  2.124e-02  1.934e-02  5.009e+01
# scale(reflection):scale(BNT):treatmentE -1.850e-02  1.825e-02  5.009e+01
# scale(SNR):scale(reflection):treatmentA -2.036e-02  2.332e-02  5.000e+01
# scale(SNR):scale(reflection):treatmentE -2.054e-02  1.961e-02  4.978e+01
# scale(SNR):scale(BNT):treatmentA         1.457e-02  3.114e-02  5.012e+01
# scale(SNR):scale(BNT):treatmentE         6.729e-03  1.656e-02  4.990e+01
#                                         t value Pr(>|t|)
# (Intercept)                              31.208  < 2e-16 ***
# scale(lottery_favour):treatmentA         31.420  < 2e-16 ***
# scale(lottery_favour):treatmentE         33.621  < 2e-16 ***
# scale(SNR):treatmentA                     0.777 0.440955
# scale(SNR):treatmentE                     3.870 0.000316 ***
# scale(x0):treatmentA                      9.493 8.90e-13 ***
# scale(x0):treatmentE                      7.059 4.89e-09 ***
# scale(reflection):treatmentA              0.150 0.881316
# scale(reflection):treatmentE              1.368 0.177264
# scale(BNT):treatmentA                     0.072 0.943034
# scale(BNT):treatmentE                    -1.749 0.086507 .
# scale(NFC):treatmentA                     0.450 0.654584
# scale(NFC):treatmentE                    -0.487 0.628593
# scale(FI):treatmentA                     -1.029 0.308256
# scale(FI):treatmentE                      1.322 0.192189
# scale(SNR):scale(x0):treatmentA          -0.944 0.349513
# scale(SNR):scale(x0):treatmentE           0.902 0.371371
# scale(reflection):scale(BNT):treatmentA   1.098 0.277458
# scale(reflection):scale(BNT):treatmentE  -1.014 0.315532
# scale(SNR):scale(reflection):treatmentA  -0.873 0.386852
# scale(SNR):scale(reflection):treatmentE  -1.047 0.299961
# scale(SNR):scale(BNT):treatmentA          0.468 0.641929
# scale(SNR):scale(BNT):treatmentE          0.406 0.686223
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# risk-loving subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) + scale(SNR):scale(BNT)):treatment + (1|subject), data1_L))
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# Correlation matrix not shown by default, as p = 22 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(SNR) * scale(x0) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) +
#     scale(SNR):scale(BNT)):treatment + (1 | subject)
#    Data: data1_L
#
# REML criterion at convergence: 7305.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.5772 -1.0374  0.3730  0.7923  2.6574
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00367  0.06058
#  Residual             0.20015  0.44738
# Number of obs: 5826, groups:  subject, 28
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              6.186e-01  2.598e-02  7.951e+00
# scale(lottery_favour):treatmentA         1.982e-01  8.207e-03  5.531e+03
# scale(lottery_favour):treatmentE         1.966e-01  1.205e-02  5.796e+03
# scale(SNR):treatmentA                    2.043e-02  2.176e-02  8.011e+00
# scale(SNR):treatmentE                    2.354e-01  5.373e-02  8.373e+00
# scale(x0):treatmentA                     9.143e-02  2.259e-02  8.033e+00
# scale(x0):treatmentE                     2.648e-01  8.025e-02  8.220e+00
# scale(reflection):treatmentA             2.620e-02  3.161e-02  7.891e+00
# scale(reflection):treatmentE             2.279e-01  9.369e-02  8.290e+00
# scale(BNT):treatmentA                    2.405e-02  3.275e-02  7.916e+00
# scale(BNT):treatmentE                   -4.467e-02  3.632e-02  7.989e+00
# scale(NFC):treatmentA                    5.840e-02  2.449e-02  8.255e+00
# scale(NFC):treatmentE                   -1.219e-01  5.699e-02  8.214e+00
# scale(FI):treatmentA                    -1.601e-02  1.758e-02  8.003e+00
# scale(FI):treatmentE                     2.263e-01  7.306e-02  8.238e+00
# scale(SNR):scale(x0):treatmentA          2.246e-02  4.060e-02  7.930e+00
# scale(SNR):scale(x0):treatmentE         -3.327e-01  1.115e-01  8.080e+00
# scale(reflection):scale(BNT):treatmentA -5.546e-03  2.673e-02  7.882e+00
# scale(reflection):scale(BNT):treatmentE -1.824e-01  7.878e-02  8.167e+00
# scale(SNR):scale(reflection):treatmentA -6.604e-02  4.370e-02  7.915e+00
# scale(SNR):scale(reflection):treatmentE  2.751e-02  7.729e-02  7.943e+00
# scale(SNR):scale(BNT):treatmentA         7.433e-03  3.472e-02  7.912e+00
#                                         t value Pr(>|t|)
# (Intercept)                              23.808 1.12e-08 ***
# scale(lottery_favour):treatmentA         24.145  < 2e-16 ***
# scale(lottery_favour):treatmentE         16.321  < 2e-16 ***
# scale(SNR):treatmentA                     0.939  0.37520
# scale(SNR):treatmentE                     4.381  0.00210 **
# scale(x0):treatmentA                      4.048  0.00366 **
# scale(x0):treatmentE                      3.299  0.01047 *
# scale(reflection):treatmentA              0.829  0.43155
# scale(reflection):treatmentE              2.432  0.04003 *
# scale(BNT):treatmentA                     0.734  0.48393
# scale(BNT):treatmentE                    -1.230  0.25377
# scale(NFC):treatmentA                     2.384  0.04333 *
# scale(NFC):treatmentE                    -2.138  0.06406 .
# scale(FI):treatmentA                     -0.911  0.38908
# scale(FI):treatmentE                      3.098  0.01420 *
# scale(SNR):scale(x0):treatmentA           0.553  0.59533
# scale(SNR):scale(x0):treatmentE          -2.984  0.01731 *
# scale(reflection):scale(BNT):treatmentA  -0.207  0.84089
# scale(reflection):scale(BNT):treatmentE  -2.315  0.04865 *
# scale(SNR):scale(reflection):treatmentA  -1.511  0.16954
# scale(SNR):scale(reflection):treatmentE   0.356  0.73115
# scale(SNR):scale(BNT):treatmentA          0.214  0.83591
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
# risk_hating subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(SNR)*scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) + scale(SNR):scale(BNT)):treatment + (1|subject), data1_H))
# Out:
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(SNR) * scale(x0) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) +
#     scale(SNR):scale(BNT)):treatment + (1 | subject)
#    Data: data1_H
#
# REML criterion at convergence: 10870.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2699 -0.8461 -0.2756  0.9415  3.1006
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005037 0.07097
#  Residual             0.187665 0.43320
# Number of obs: 9161, groups:  subject, 44
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              3.961e-01  1.684e-02  2.291e+01
# scale(lottery_favour):treatmentA         1.605e-01  7.942e-03  8.850e+03
# scale(lottery_favour):treatmentE         1.971e-01  6.607e-03  8.533e+03
# scale(SNR):treatmentA                   -3.177e-03  3.971e-02  2.323e+01
# scale(SNR):treatmentE                    5.295e-02  1.803e-02  2.287e+01
# scale(x0):treatmentA                     1.110e-01  2.214e-02  2.296e+01
# scale(x0):treatmentE                     1.018e-01  2.979e-02  2.296e+01
# scale(reflection):treatmentA             1.457e-02  3.430e-02  2.317e+01
# scale(reflection):treatmentE             5.066e-02  2.294e-02  2.320e+01
# scale(BNT):treatmentA                    2.240e-02  3.362e-02  2.331e+01
# scale(BNT):treatmentE                   -2.680e-02  2.089e-02  2.278e+01
# scale(NFC):treatmentA                   -5.646e-02  3.929e-02  2.351e+01
# scale(NFC):treatmentE                   -2.172e-02  1.612e-02  2.280e+01
# scale(FI):treatmentA                     4.413e-03  2.492e-02  2.302e+01
# scale(FI):treatmentE                     4.008e-02  2.128e-02  2.303e+01
# scale(SNR):scale(x0):treatmentA         -4.754e-02  2.692e-02  2.328e+01
# scale(SNR):scale(x0):treatmentE         -2.616e-02  3.536e-02  2.300e+01
# scale(reflection):scale(BNT):treatmentA  9.765e-03  2.742e-02  2.288e+01
# scale(reflection):scale(BNT):treatmentE -1.713e-02  1.977e-02  2.293e+01
# scale(SNR):scale(reflection):treatmentA  8.012e-02  4.685e-02  2.372e+01
# scale(SNR):scale(reflection):treatmentE -1.448e-02  1.873e-02  2.278e+01
# scale(SNR):scale(BNT):treatmentA        -7.701e-02  5.771e-02  2.368e+01
# scale(SNR):scale(BNT):treatmentE         1.295e-03  1.808e-02  2.280e+01
#                                         t value Pr(>|t|)
# (Intercept)                              23.523  < 2e-16 ***
# scale(lottery_favour):treatmentA         20.209  < 2e-16 ***
# scale(lottery_favour):treatmentE         29.838  < 2e-16 ***
# scale(SNR):treatmentA                    -0.080  0.93692
# scale(SNR):treatmentE                     2.937  0.00743 **
# scale(x0):treatmentA                      5.016 4.51e-05 ***
# scale(x0):treatmentE                      3.418  0.00236 **
# scale(reflection):treatmentA              0.425  0.67491
# scale(reflection):treatmentE              2.209  0.03735 *
# scale(BNT):treatmentA                     0.666  0.51173
# scale(BNT):treatmentE                    -1.283  0.21242
# scale(NFC):treatmentA                    -1.437  0.16385
# scale(NFC):treatmentE                    -1.347  0.19110
# scale(FI):treatmentA                      0.177  0.86101
# scale(FI):treatmentE                      1.883  0.07233 .
# scale(SNR):scale(x0):treatmentA          -1.766  0.09047 .
# scale(SNR):scale(x0):treatmentE          -0.740  0.46689
# scale(reflection):scale(BNT):treatmentA   0.356  0.72501
# scale(reflection):scale(BNT):treatmentE  -0.866  0.39531
# scale(SNR):scale(reflection):treatmentA   1.710  0.10025
# scale(SNR):scale(reflection):treatmentE  -0.773  0.44735
# scale(SNR):scale(BNT):treatmentA         -1.334  0.19479
# scale(SNR):scale(BNT):treatmentE          0.072  0.94353
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Predicting choice with psychometric measurements alone

# %%
# all subjects
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(reflection) * scale(BNT) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18159.5
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.55582 -0.90641 -0.04805  0.87610  3.13696
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02983  0.1727
#  Residual             0.19261  0.4389
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              4.875e-01  2.488e-02  6.095e+01
# scale(lottery_favour):treatmentA         1.790e-01  5.691e-03  1.491e+04
# scale(lottery_favour):treatmentE         1.978e-01  5.855e-03  1.496e+04
# scale(reflection):treatmentA             2.269e-03  3.995e-02  6.089e+01
# scale(reflection):treatmentE             5.942e-02  3.534e-02  6.094e+01
# scale(BNT):treatmentA                    2.821e-02  4.378e-02  6.097e+01
# scale(BNT):treatmentE                    1.323e-02  3.300e-02  6.089e+01
# scale(NFC):treatmentA                   -3.153e-03  3.712e-02  6.091e+01
# scale(NFC):treatmentE                    6.230e-03  2.645e-02  6.095e+01
# scale(FI):treatmentA                    -2.252e-02  3.137e-02  6.094e+01
# scale(FI):treatmentE                     9.282e-02  3.159e-02  6.092e+01
# scale(reflection):scale(BNT):treatmentA -1.767e-02  3.379e-02  6.097e+01
# scale(reflection):scale(BNT):treatmentE -4.611e-02  2.871e-02  6.094e+01
#                                         t value Pr(>|t|)
# (Intercept)                              19.596  < 2e-16 ***
# scale(lottery_favour):treatmentA         31.449  < 2e-16 ***
# scale(lottery_favour):treatmentE         33.781  < 2e-16 ***
# scale(reflection):treatmentA              0.057  0.95490
# scale(reflection):treatmentE              1.681  0.09784 .
# scale(BNT):treatmentA                     0.644  0.52174
# scale(BNT):treatmentE                     0.401  0.68982
# scale(NFC):treatmentA                    -0.085  0.93258
# scale(NFC):treatmentE                     0.236  0.81455
# scale(FI):treatmentA                     -0.718  0.47542
# scale(FI):treatmentE                      2.938  0.00466 **
# scale(reflection):scale(BNT):treatmentA  -0.523  0.60280
# scale(reflection):scale(BNT):treatmentE  -1.606  0.11341
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Others

# %% [markdown]
# ### Is RT affected by treatments?
# No difference for RT per trial, but choosing lottery takes longer time only in the treatment E.

# %%
summary(glmer(RT ~ value_diff + slc_lot + treatment + (1|subject), data1, family = Gamma(link = "identity")))

summary(lmer(logRT ~ (value_diff + slc_lot):treatment + (1|subject), data1))
summary(glmer(RT ~ (value_diff + slc_lot):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ value_diff + slc_lot + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45392.3  45438.0 -22690.1  45380.3    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4632 -0.6092 -0.2828  0.2783 12.7789
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2455   0.4955
#  Residual             0.3982   0.6310
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#              Estimate Std. Error t value Pr(>|z|)
# (Intercept)  2.369114   0.127884  18.526  < 2e-16 ***
# value_diff  -0.012500   0.002608  -4.793 1.64e-06 ***
# slc_lot      0.053675   0.018020   2.979  0.00289 **
# treatmentE   0.195395   0.179595   1.088  0.27661
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#            (Intr) vl_dff slc_lt
# value_diff -0.079
# slc_lot    -0.068  0.022
# treatmentE -0.705  0.001  0.001
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: logRT ~ (value_diff + slc_lot):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 11797.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -4.0967 -0.6800 -0.1901  0.4826  4.7913
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.04147  0.2036
#  Residual             0.12572  0.3546
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                         Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)            1.141e+00  2.460e-02  7.584e+01  46.408  < 2e-16 ***
# value_diff:treatmentA -3.963e-03  1.265e-03  1.486e+04  -3.133  0.00173 **
# value_diff:treatmentE -4.162e-03  1.326e-03  1.490e+04  -3.138  0.00170 **
# slc_lot:treatmentA     1.513e-02  8.797e-03  1.486e+04   1.720  0.08551 .
# slc_lot:treatmentE     2.421e-02  8.664e-03  1.496e+04   2.794  0.00521 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) vl_d:A vl_d:E slc_:A
# vl_dff:trtA -0.102
# vl_dff:trtE -0.098  0.010
# slc_lt:trtA -0.095  0.076  0.009
# slc_lt:trtE -0.078  0.008 -0.050  0.007
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (value_diff + slc_lot):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45391.8  45445.1 -22688.9  45377.8    14980
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4638 -0.6095 -0.2836  0.2773 12.6967
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2493   0.4993
#  Residual             0.3978   0.6307
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                        Estimate Std. Error t value Pr(>|z|)
# (Intercept)            2.468215   0.091467  26.985  < 2e-16 ***
# value_diff:treatmentA -0.010601   0.003503  -3.026  0.00248 **
# value_diff:treatmentE -0.015780   0.003926  -4.019 5.84e-05 ***
# slc_lot:treatmentA     0.028436   0.024319   1.169  0.24228
# slc_lot:treatmentE     0.088093   0.027112   3.249  0.00116 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) vl_d:A vl_d:E slc_:A
# vl_dff:trtA -0.079
# vl_dff:trtE -0.078  0.006
# slc_lt:trtA -0.071  0.090  0.005
# slc_lt:trtE -0.060  0.004 -0.076  0.004

# %% [markdown]
# ### Is chance of choosing lottery affected by treatments?
# NO (marginal significance)

# %%
summary(glmer(slc_lot ~ scale(lottery_favour) + scale(RT) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ scale(lottery_favour) + scale(RT) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17045.6  17083.7  -8517.8  17035.6    14982
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.9730 -0.7530 -0.2375  0.7477 12.4468
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8254   0.9085
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)            0.02138    0.15391   0.139   0.8895
# scale(lottery_favour)  1.05250    0.02650  39.716   <2e-16 ***
# scale(RT)              0.04501    0.02071   2.173   0.0298 *
# treatmentE            -0.39593    0.21768  -1.819   0.0689 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) sc(RT)
# scl(lttry_)  0.015
# scale(RT)    0.003  0.004
# treatmentE  -0.707 -0.038 -0.011

# %% [markdown]
# # Predicting choice with extra variables: stake of gamble (WTP) and risk level (risk_level)
# Interactive effects between the "lottery_favour", "WTP", and "risk_level" are also considered

# %%
# DDM parameters alone
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(WTP) + scale(risk_level) + scale(lottery_favour):scale(WTP) + scale(lottery_favour):scale(risk_level) + scale(WTP):scale(risk_level) + scale(SNR)*scale(x0)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(WTP) + scale(risk_level) +
#     scale(lottery_favour):scale(WTP) + scale(lottery_favour):scale(risk_level) +
#     scale(WTP):scale(risk_level) + scale(SNR) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17591.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2513 -0.9056  0.0585  0.8511  3.2758
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006651 0.08155
#  Residual             0.185839 0.43109
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                                      Estimate Std. Error
# (Intercept)                                         4.864e-01  1.108e-02
# scale(lottery_favour):treatmentA                    1.888e-01  6.246e-03
# scale(lottery_favour):treatmentE                    2.703e-01  7.814e-03
# scale(WTP):treatmentA                              -3.905e-02  7.992e-03
# scale(WTP):treatmentE                              -7.948e-02  7.208e-03
# scale(risk_level):treatmentA                       -5.427e-02  6.201e-03
# scale(risk_level):treatmentE                       -6.665e-02  6.075e-03
# scale(SNR):treatmentA                               1.947e-02  1.534e-02
# scale(SNR):treatmentE                               6.208e-02  1.580e-02
# scale(x0):treatmentA                                1.425e-01  1.340e-02
# scale(x0):treatmentE                                1.531e-01  1.729e-02
# scale(lottery_favour):scale(WTP):treatmentA        -1.764e-02  5.647e-03
# scale(lottery_favour):scale(WTP):treatmentE        -5.138e-02  5.996e-03
# scale(lottery_favour):scale(risk_level):treatmentA -2.025e-02  6.582e-03
# scale(lottery_favour):scale(risk_level):treatmentE -6.252e-02  7.464e-03
# scale(WTP):scale(risk_level):treatmentA             8.182e-03  6.644e-03
# scale(WTP):scale(risk_level):treatmentE            -1.009e-02  6.189e-03
# scale(SNR):scale(x0):treatmentA                    -2.163e-02  1.820e-02
# scale(SNR):scale(x0):treatmentE                     1.621e-03  2.065e-02
#                                                            df t value Pr(>|t|)
# (Intercept)                                         6.996e+01  43.891  < 2e-16
# scale(lottery_favour):treatmentA                    1.375e+04  30.222  < 2e-16
# scale(lottery_favour):treatmentE                    1.233e+04  34.589  < 2e-16
# scale(WTP):treatmentA                               9.434e+03  -4.886 1.05e-06
# scale(WTP):treatmentE                               1.339e+04 -11.027  < 2e-16
# scale(risk_level):treatmentA                        1.362e+04  -8.752  < 2e-16
# scale(risk_level):treatmentE                        1.445e+04 -10.972  < 2e-16
# scale(SNR):treatmentA                               6.202e+01   1.270 0.208940
# scale(SNR):treatmentE                               6.212e+01   3.929 0.000217
# scale(x0):treatmentA                                6.211e+01  10.632 1.30e-15
# scale(x0):treatmentE                                6.180e+01   8.851 1.38e-12
# scale(lottery_favour):scale(WTP):treatmentA         8.405e+03  -3.123 0.001794
# scale(lottery_favour):scale(WTP):treatmentE         1.057e+04  -8.568  < 2e-16
# scale(lottery_favour):scale(risk_level):treatmentA  1.354e+04  -3.077 0.002095
# scale(lottery_favour):scale(risk_level):treatmentE  1.438e+04  -8.376  < 2e-16
# scale(WTP):scale(risk_level):treatmentA             1.266e+04   1.232 0.218144
# scale(WTP):scale(risk_level):treatmentE             1.452e+04  -1.630 0.103199
# scale(SNR):scale(x0):treatmentA                     6.233e+01  -1.188 0.239278
# scale(SNR):scale(x0):treatmentE                     6.165e+01   0.078 0.937697
#
# (Intercept)                                        ***
# scale(lottery_favour):treatmentA                   ***
# scale(lottery_favour):treatmentE                   ***
# scale(WTP):treatmentA                              ***
# scale(WTP):treatmentE                              ***
# scale(risk_level):treatmentA                       ***
# scale(risk_level):treatmentE                       ***
# scale(SNR):treatmentA
# scale(SNR):treatmentE                              ***
# scale(x0):treatmentA                               ***
# scale(x0):treatmentE                               ***
# scale(lottery_favour):scale(WTP):treatmentA        **
# scale(lottery_favour):scale(WTP):treatmentE        ***
# scale(lottery_favour):scale(risk_level):treatmentA **
# scale(lottery_favour):scale(risk_level):treatmentE ***
# scale(WTP):scale(risk_level):treatmentA
# scale(WTP):scale(risk_level):treatmentE
# scale(SNR):scale(x0):treatmentA
# scale(SNR):scale(x0):treatmentE
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# DDM parameters and psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(WTP) + scale(risk_level) + scale(lottery_favour):scale(WTP) + scale(lottery_favour):scale(risk_level) + scale(WTP):scale(risk_level) + scale(SNR)*scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) + scale(SNR):scale(BNT)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 33 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(WTP) + scale(risk_level) +
#     scale(lottery_favour):scale(WTP) + scale(lottery_favour):scale(risk_level) +
#     scale(WTP):scale(risk_level) + scale(SNR) * scale(x0) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI) + scale(SNR):scale(reflection) +
#     scale(SNR):scale(BNT)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17661.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2624 -0.9061  0.0624  0.8502  3.2727
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006179 0.07861
#  Residual             0.185833 0.43108
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                                      Estimate Std. Error
# (Intercept)                                         4.854e-01  1.439e-02
# scale(lottery_favour):treatmentA                    1.891e-01  6.254e-03
# scale(lottery_favour):treatmentE                    2.713e-01  7.847e-03
# scale(WTP):treatmentA                              -3.798e-02  8.049e-03
# scale(WTP):treatmentE                              -7.902e-02  7.228e-03
# scale(risk_level):treatmentA                       -5.368e-02  6.221e-03
# scale(risk_level):treatmentE                       -6.612e-02  6.087e-03
# scale(SNR):treatmentA                               1.282e-02  1.903e-02
# scale(SNR):treatmentE                               6.443e-02  1.885e-02
# scale(x0):treatmentA                                1.470e-01  1.437e-02
# scale(x0):treatmentE                                1.502e-01  1.960e-02
# scale(reflection):treatmentA                        3.413e-03  1.997e-02
# scale(reflection):treatmentE                        3.872e-02  1.908e-02
# scale(BNT):treatmentA                               2.832e-03  2.130e-02
# scale(BNT):treatmentE                              -3.716e-02  1.674e-02
# scale(NFC):treatmentA                               6.203e-03  1.898e-02
# scale(NFC):treatmentE                              -1.141e-02  1.380e-02
# scale(FI):treatmentA                               -1.668e-02  1.574e-02
# scale(FI):treatmentE                                3.027e-02  1.732e-02
# scale(lottery_favour):scale(WTP):treatmentA        -1.852e-02  5.709e-03
# scale(lottery_favour):scale(WTP):treatmentE        -5.244e-02  6.037e-03
# scale(lottery_favour):scale(risk_level):treatmentA -2.073e-02  6.605e-03
# scale(lottery_favour):scale(risk_level):treatmentE -6.326e-02  7.483e-03
# scale(WTP):scale(risk_level):treatmentA             9.184e-03  6.685e-03
# scale(WTP):scale(risk_level):treatmentE            -1.046e-02  6.204e-03
# scale(SNR):scale(x0):treatmentA                    -2.278e-02  2.056e-02
# scale(SNR):scale(x0):treatmentE                     1.540e-02  2.362e-02
# scale(reflection):scale(BNT):treatmentA             2.062e-02  1.820e-02
# scale(reflection):scale(BNT):treatmentE            -1.352e-02  1.695e-02
# scale(SNR):scale(reflection):treatmentA            -1.995e-02  2.165e-02
# scale(SNR):scale(reflection):treatmentE            -2.293e-02  1.821e-02
# scale(SNR):scale(BNT):treatmentA                    1.354e-02  2.892e-02
# scale(SNR):scale(BNT):treatmentE                    3.010e-03  1.538e-02
#                                                            df t value Pr(>|t|)
# (Intercept)                                         5.185e+01  33.738  < 2e-16
# scale(lottery_favour):treatmentA                    1.357e+04  30.229  < 2e-16
# scale(lottery_favour):treatmentE                    1.287e+04  34.579  < 2e-16
# scale(WTP):treatmentA                               1.029e+04  -4.719 2.40e-06
# scale(WTP):treatmentE                               1.359e+04 -10.933  < 2e-16
# scale(risk_level):treatmentA                        1.388e+04  -8.630  < 2e-16
# scale(risk_level):treatmentE                        1.454e+04 -10.863  < 2e-16
# scale(SNR):treatmentA                               4.925e+01   0.674  0.50357
# scale(SNR):treatmentE                               4.935e+01   3.419  0.00127
# scale(x0):treatmentA                                4.931e+01  10.229 8.79e-14
# scale(x0):treatmentE                                4.879e+01   7.664 6.43e-10
# scale(reflection):treatmentA                        4.942e+01   0.171  0.86496
# scale(reflection):treatmentE                        4.980e+01   2.030  0.04774
# scale(BNT):treatmentA                               4.893e+01   0.133  0.89477
# scale(BNT):treatmentE                               4.872e+01  -2.220  0.03110
# scale(NFC):treatmentA                               4.896e+01   0.327  0.74514
# scale(NFC):treatmentE                               4.882e+01  -0.827  0.41232
# scale(FI):treatmentA                                4.890e+01  -1.060  0.29445
# scale(FI):treatmentE                                4.924e+01   1.747  0.08679
# scale(lottery_favour):scale(WTP):treatmentA         1.028e+04  -3.243  0.00119
# scale(lottery_favour):scale(WTP):treatmentE         1.174e+04  -8.687  < 2e-16
# scale(lottery_favour):scale(risk_level):treatmentA  1.389e+04  -3.138  0.00171
# scale(lottery_favour):scale(risk_level):treatmentE  1.455e+04  -8.455  < 2e-16
# scale(WTP):scale(risk_level):treatmentA             1.364e+04   1.374  0.16951
# scale(WTP):scale(risk_level):treatmentE             1.468e+04  -1.686  0.09179
# scale(SNR):scale(x0):treatmentA                     4.929e+01  -1.108  0.27345
# scale(SNR):scale(x0):treatmentE                     4.872e+01   0.652  0.51750
# scale(reflection):scale(BNT):treatmentA             5.130e+01   1.133  0.26241
# scale(reflection):scale(BNT):treatmentE             4.889e+01  -0.798  0.42872
# scale(SNR):scale(reflection):treatmentA             4.872e+01  -0.922  0.36130
# scale(SNR):scale(reflection):treatmentE             4.854e+01  -1.259  0.21394
# scale(SNR):scale(BNT):treatmentA                    4.887e+01   0.468  0.64183
# scale(SNR):scale(BNT):treatmentE                    4.867e+01   0.196  0.84561
#
# (Intercept)                                        ***
# scale(lottery_favour):treatmentA                   ***
# scale(lottery_favour):treatmentE                   ***
# scale(WTP):treatmentA                              ***
# scale(WTP):treatmentE                              ***
# scale(risk_level):treatmentA                       ***
# scale(risk_level):treatmentE                       ***
# scale(SNR):treatmentA
# scale(SNR):treatmentE                              **
# scale(x0):treatmentA                               ***
# scale(x0):treatmentE                               ***
# scale(reflection):treatmentA
# scale(reflection):treatmentE                       *
# scale(BNT):treatmentA
# scale(BNT):treatmentE                              *
# scale(NFC):treatmentA
# scale(NFC):treatmentE
# scale(FI):treatmentA
# scale(FI):treatmentE                               .
# scale(lottery_favour):scale(WTP):treatmentA        **
# scale(lottery_favour):scale(WTP):treatmentE        ***
# scale(lottery_favour):scale(risk_level):treatmentA **
# scale(lottery_favour):scale(risk_level):treatmentE ***
# scale(WTP):scale(risk_level):treatmentA
# scale(WTP):scale(risk_level):treatmentE            .
# scale(SNR):scale(x0):treatmentA
# scale(SNR):scale(x0):treatmentE
# scale(reflection):scale(BNT):treatmentA
# scale(reflection):scale(BNT):treatmentE
# scale(SNR):scale(reflection):treatmentA
# scale(SNR):scale(reflection):treatmentE
# scale(SNR):scale(BNT):treatmentA
# scale(SNR):scale(BNT):treatmentE
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Psychometrics alone
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(WTP) + scale(risk_level) + scale(lottery_favour):scale(WTP) + scale(lottery_favour):scale(risk_level) + scale(WTP):scale(risk_level) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(WTP) + scale(risk_level) +
#     scale(lottery_favour):scale(WTP) + scale(lottery_favour):scale(risk_level) +
#     scale(WTP):scale(risk_level) + scale(reflection) * scale(BNT) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17695.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2497 -0.9016  0.0680  0.8461  3.2623
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02846  0.1687
#  Residual             0.18582  0.4311
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                                      Estimate Std. Error
# (Intercept)                                         4.975e-01  2.443e-02
# scale(lottery_favour):treatmentA                    1.912e-01  6.308e-03
# scale(lottery_favour):treatmentE                    2.749e-01  7.923e-03
# scale(WTP):treatmentA                              -3.542e-02  8.180e-03
# scale(WTP):treatmentE                              -7.586e-02  7.285e-03
# scale(risk_level):treatmentA                       -5.253e-02  6.267e-03
# scale(risk_level):treatmentE                       -6.416e-02  6.116e-03
# scale(reflection):treatmentA                        1.426e-03  3.909e-02
# scale(reflection):treatmentE                        6.695e-02  3.456e-02
# scale(BNT):treatmentA                               2.889e-02  4.278e-02
# scale(BNT):treatmentE                               4.628e-03  3.226e-02
# scale(NFC):treatmentA                              -4.550e-03  3.628e-02
# scale(NFC):treatmentE                               4.773e-05  2.584e-02
# scale(FI):treatmentA                               -2.192e-02  3.067e-02
# scale(FI):treatmentE                                9.688e-02  3.088e-02
# scale(lottery_favour):scale(WTP):treatmentA        -2.031e-02  5.799e-03
# scale(lottery_favour):scale(WTP):treatmentE        -5.516e-02  6.107e-03
# scale(lottery_favour):scale(risk_level):treatmentA -2.290e-02  6.655e-03
# scale(lottery_favour):scale(risk_level):treatmentE -6.539e-02  7.517e-03
# scale(WTP):scale(risk_level):treatmentA             9.412e-03  6.736e-03
# scale(WTP):scale(risk_level):treatmentE            -8.914e-03  6.228e-03
# scale(reflection):scale(BNT):treatmentA            -1.886e-02  3.313e-02
# scale(reflection):scale(BNT):treatmentE            -4.482e-02  2.806e-02
#                                                            df t value Pr(>|t|)
# (Intercept)                                         6.199e+01  20.361  < 2e-16
# scale(lottery_favour):treatmentA                    1.495e+04  30.304  < 2e-16
# scale(lottery_favour):treatmentE                    1.491e+04  34.695  < 2e-16
# scale(WTP):treatmentA                               1.474e+04  -4.330  1.5e-05
# scale(WTP):treatmentE                               1.494e+04 -10.413  < 2e-16
# scale(risk_level):treatmentA                        1.495e+04  -8.381  < 2e-16
# scale(risk_level):treatmentE                        1.496e+04 -10.490  < 2e-16
# scale(reflection):treatmentA                        6.102e+01   0.036 0.971021
# scale(reflection):treatmentE                        6.094e+01   1.937 0.057382
# scale(BNT):treatmentA                               6.079e+01   0.675 0.502087
# scale(BNT):treatmentE                               6.077e+01   0.143 0.886396
# scale(NFC):treatmentA                               6.077e+01  -0.125 0.900596
# scale(NFC):treatmentE                               6.078e+01   0.002 0.998532
# scale(FI):treatmentA                                6.088e+01  -0.715 0.477401
# scale(FI):treatmentE                                6.078e+01   3.138 0.002626
# scale(lottery_favour):scale(WTP):treatmentA         1.471e+04  -3.503 0.000462
# scale(lottery_favour):scale(WTP):treatmentE         1.477e+04  -9.032  < 2e-16
# scale(lottery_favour):scale(risk_level):treatmentA  1.496e+04  -3.442 0.000580
# scale(lottery_favour):scale(risk_level):treatmentE  1.496e+04  -8.699  < 2e-16
# scale(WTP):scale(risk_level):treatmentA             1.493e+04   1.397 0.162359
# scale(WTP):scale(risk_level):treatmentE             1.496e+04  -1.431 0.152398
# scale(reflection):scale(BNT):treatmentA             6.162e+01  -0.569 0.571248
# scale(reflection):scale(BNT):treatmentE             6.084e+01  -1.597 0.115397
#
# (Intercept)                                        ***
# scale(lottery_favour):treatmentA                   ***
# scale(lottery_favour):treatmentE                   ***
# scale(WTP):treatmentA                              ***
# scale(WTP):treatmentE                              ***
# scale(risk_level):treatmentA                       ***
# scale(risk_level):treatmentE                       ***
# scale(reflection):treatmentA
# scale(reflection):treatmentE                       .
# scale(BNT):treatmentA
# scale(BNT):treatmentE
# scale(NFC):treatmentA
# scale(NFC):treatmentE
# scale(FI):treatmentA
# scale(FI):treatmentE                               **
# scale(lottery_favour):scale(WTP):treatmentA        ***
# scale(lottery_favour):scale(WTP):treatmentE        ***
# scale(lottery_favour):scale(risk_level):treatmentA ***
# scale(lottery_favour):scale(risk_level):treatmentE ***
# scale(WTP):scale(risk_level):treatmentA
# scale(WTP):scale(risk_level):treatmentE
# scale(reflection):scale(BNT):treatmentA
# scale(reflection):scale(BNT):treatmentE
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
