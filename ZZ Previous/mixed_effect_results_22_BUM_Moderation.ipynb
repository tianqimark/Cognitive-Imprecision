# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)

# %% [markdown]
# # This analysis is for the version AM_n001_10s_B1, risk division

# %% [markdown]
# ## Test d and B in prediction

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1C Dataset_BU/trialsBUM_10s.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# create another dataset in wh subjects with error_choice > 5 are rejected
data2 <- subset(data1, error_choice <= 5)

# %%
names(data1)
# Out:
#  [1] "subject"        "trial"          "treatment"      "lot_code"
#  [5] "risk"           "reward"         "WTP"            "certainty"
#  [9] "RT"             "choice"         "slc_lot"        "display"
# [13] "correct"        "decmode"        "reflection"     "intuition"
# [17] "BNT"            "NFC"            "FI"             "value_diff"
# [21] "value_sum"      "lottery_favour" "lot_correct"    "error_choice"
# [25] "accuracy"       "risk_level"     "d"              "B"
# [29] "x0"             "nondectime"     "logRT"

# %% [markdown]
# # Predicting choice with the full set of DDM paramerters (d, x0)

# %% [markdown]
# ###  All continuous variables are scaled due to the inclusion of interactive terms and to avoid the error "Model failed to converge with max|grad|".
# Interactive effects between the "lottery_favour and WTP".

# %%
# All subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0)):treatment + (1|subject), data1))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) + scale(x0)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17925.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4837 -0.9164  0.0356  0.8623  3.1771
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007637 0.08739
#  Residual             0.190629 0.43661
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.905e-01  1.124e-02  6.859e+01
# scale(lottery_favour):treatmentA             1.809e-01  6.021e-03  1.454e+04
# scale(lottery_favour):treatmentE             2.347e-01  6.723e-03  1.426e+04
# scale(WTP):treatmentA                       -4.253e-03  6.506e-03  1.414e+04
# ...

# %%
# All subjects (with interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17936.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4829 -0.9171  0.0379  0.8632  3.1904
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00776  0.08809
#  Residual             0.19063  0.43661
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.933e-01  1.166e-02  6.606e+01
# scale(lottery_favour):treatmentA             1.809e-01  6.022e-03  1.454e+04
# ...

# %%
# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0)):treatment + (1|subject), data2))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) + scale(x0)):treatment +
#     (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11174.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4594 -0.8692 -0.0482  0.8380  3.7843
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006297 0.07936
#  Residual             0.168107 0.41001
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.493e-01  1.229e-02  4.628e+01
# scale(lottery_favour):treatmentA             2.383e-01  7.019e-03  1.020e+04
# scale(lottery_favour):treatmentE             2.870e-01  7.221e-03  9.684e+03
# scale(WTP):treatmentA                       -4.238e-02  7.582e-03  1.002e+04
# ...

# %%
# without low-attention individuals (with interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11184.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4624 -0.8669 -0.0513  0.8385  3.8008
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006372 0.07983
#  Residual             0.168106 0.41001
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.559e-01  1.351e-02  4.375e+01
# scale(lottery_favour):treatmentA             2.382e-01  7.020e-03  1.019e+04
# ...

# %% [markdown]
# #  Predicting choice with the DDM paramerters and psychometric measurements
# Interactive effects between the "lottery_favour and WTP" are included.

# %%
# All subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) + scale(x0) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) +
#     scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) +
#     scale(d):scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17996.5
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.49218 -0.91611  0.03638  0.85937  3.15959
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005961 0.0772
#  Residual             0.190625 0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# ...

# %%
# All subjects (with interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) * scale(x0) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) +
#     scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) +
#     scale(d):scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18006.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4898 -0.9161  0.0363  0.8595  3.1740
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006115 0.0782
#  Residual             0.190625 0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# ...

# %%
# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) + scale(x0) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) +
#     scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) +
#     scale(d):scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11239
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4797 -0.8688 -0.0447  0.8382  3.7788
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003938 0.06275
#  Residual             0.168102 0.41000
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# ...

# %%
# without low-attention individuals (with interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) * scale(x0) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) +
#     scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) +
#     scale(d):scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11248.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4799 -0.8653 -0.0444  0.8381  3.7969
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004095 0.06399
#  Residual             0.168102 0.41000
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# ...

# %% [markdown]
# # Predicting choice with psychometric measurements alone

# %%
# all subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18025.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4841 -0.9171  0.0361  0.8613  3.1753
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.0297   0.1723
#  Residual             0.1906   0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.879e-01  2.123e-02  6.380e+01
# scale(lottery_favour):treatmentA             1.827e-01  6.057e-03  1.497e+04
# ...

# %%
# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11251.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4779 -0.8729 -0.0518  0.8370  3.7854
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02827  0.1681
#  Residual             0.16810  0.4100
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.331e-01  2.653e-02  4.143e+01
# scale(lottery_favour):treatmentA             2.394e-01  7.058e-03  1.041e+04
# ...

# %% [markdown]
# # RT Pattern & Risk Taking Propensity

# %% [markdown]
# ### Is RT affected by treatments?
# No difference for RT per trial, but choosing lottery takes longer time only in the treatment E.

# %%
# all subjects 
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45378.7  45439.6 -22681.4  45362.7    14979
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4641 -0.6078 -0.2815  0.2766 12.8588
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2449   0.4949
#  Residual             0.3978   0.6307
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.319494   0.127447  18.200  < 2e-16 ***
# scale(value_diff)            -0.047105   0.008963  -5.255 1.48e-07 ***
# scale(WTP)                   -0.014621   0.010495  -1.393   0.1636
# slc_lot                       0.045321   0.018174   2.494   0.0126 *
# ...

# %%
# all subjects with Psychometrics
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + treatment + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula:
# RT ~ scale(value_diff) * scale(WTP) + slc_lot + treatment + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45380.1  45471.5 -22678.1  45356.1    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4646 -0.6088 -0.2814  0.2765 12.8729
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2236   0.4728
#  Residual             0.3975   0.6305
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.326491   0.122869  18.935  < 2e-16 ***
# scale(value_diff)            -0.047011   0.008964  -5.244 1.57e-07 ***
# scale(WTP)                   -0.014546   0.010496  -1.386    0.166
# ...

# %% [markdown]
# ### Is chance of choosing lottery affected by treatments?
# NO (marginal significance with all subjects)

# %%
# All subjects
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16845.0  16890.7  -8416.5  16833.0    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1540 -0.7438 -0.1979  0.7181 17.7392
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8703   0.9329
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.12833    0.15833   0.811 0.417648
# scale(lottery_favour)             1.24103    0.03118  39.801  < 2e-16 ***
# scale(WTP)                       -0.08056    0.02384  -3.379 0.000728 ***
# treatmentE                       -0.40198    0.22339  -1.799 0.071945 .
# ...

# %%
# All subjects with Psychometrics
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16850.9  16927.0  -8415.4  16830.9    14977
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1803 -0.7442 -0.1977  0.7183 17.7803
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8436   0.9185
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.1282165  0.1577926   0.813 0.416468
# scale(lottery_favour)             1.2411462  0.0311809  39.805  < 2e-16 ***
# scale(WTP)                       -0.0804726  0.0238446  -3.375 0.000738 ***
# ...

# %% [markdown]
# # Split by the pre-evaluation bias

# %%
# split data by whether the subject has a positive or negative pre-evaluation bias
# L: risk-lover; H: risk-hater
data1L <- subset(data1, x0 > 0)
data1H <- subset(data1, x0 < 0)

data2L <- subset(data2, x0 > 0)
data2H <- subset(data2, x0 < 0)

# %%
# All subjects (without psychometrics; without interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0)):treatment + (1|subject), data1H))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) + scale(x0)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7988.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4076 -1.0550  0.3730  0.7863  3.0798
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.009476 0.09735
#  Residual             0.198296 0.44530
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.289e-01  1.869e-02  2.615e+01
# scale(lottery_favour):treatmentA             1.896e-01  8.293e-03  6.263e+03
# scale(lottery_favour):treatmentE             2.427e-01  1.379e-02  6.101e+03
# scale(WTP):treatmentA                        2.172e-02  8.724e-03  6.270e+03
# ...

# %%
# All subjects (without psychometrics; with interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) * scale(x0)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7992.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4058 -1.0550  0.3716  0.7843  3.0776
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.008056 0.08976
#  Residual             0.198296 0.44530
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.495e-01  2.128e-02  2.387e+01
# scale(lottery_favour):treatmentA             1.894e-01  8.284e-03  6.159e+03
# ...

# %%
# All subjects (with psychometrics; without interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) + scale(x0) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) +
#     scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) +
#     scale(d):scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8035.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4276 -1.0539  0.3702  0.7870  3.0782
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003645 0.06037
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# ...

# %%
# All subjects (with psychometrics; with interaction)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) + scale(d):scale(FI)):treatment + (1|subject), data1H))
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# Correlation matrix not shown by default, as p = 28 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(d) * scale(x0) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) +
#     scale(d):scale(reflection) + scale(d):scale(BNT) + scale(d):scale(NFC) +
#     scale(d):scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8039.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4296 -1.0518  0.3695  0.7852  3.0813
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003926 0.06266
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
# ...

# %% [markdown]
# # Accuracy as a proxy of cognitive uncertainty
# In this "standard appraoch", the accuracy predicts choosing the lotteries in both treatments.

# %% [markdown]
# ### Without psychometrics

# %%
# All subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(accuracy)):treatment + (1|subject), data1))

# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(accuracy)):treatment + (1|subject), data2))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(accuracy)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17991.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4855 -0.9161  0.0343  0.8609  3.1866
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02549  0.1597
#  Residual             0.19062  0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.898e-01  1.927e-02  7.012e+01
# scale(lottery_favour):treatmentA             1.827e-01  6.054e-03  1.498e+04
# scale(lottery_favour):treatmentE             2.372e-01  6.767e-03  1.497e+04
# scale(WTP):treatmentA                       -2.218e-03  6.552e-03  1.496e+04
# ...

# %% [markdown]
# ### With psychometrics

# %%
# All subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(accuracy) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))

# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(accuracy) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(accuracy) +
#     scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18024.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4807 -0.9168  0.0364  0.8598  3.1866
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02537  0.1593
#  Residual             0.19062  0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.883e-01  1.971e-02  6.192e+01
# ...
