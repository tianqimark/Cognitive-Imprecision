# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)

# %% [markdown]
# # This analysis is for the version AM_n001_10s_B1

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1 Dataset_M/trialsAM_10s_B1.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# create another dataset in wh subjects with error_choice > 5 are rejected
data2 <- subset(data1, error_choice <= 5)

# # split the dataset by treatment
# data1_A <- subset(data1, treatment == 'A')
# data1_E <- subset(data1, treatment == 'E')

# data2_A <- subset(data2, treatment == 'A')
# data2_E <- subset(data2, treatment == 'E')

# %% [markdown]
# ## 1 Predicting choice with RT and value difference alone

# %% [markdown]
# ### 1.1 whole dataset

# %%
summary(glmer(slc_lot ~ (lottery_favour + RT):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (lottery_favour + RT):treatment + (1|subject), data1))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (lottery_favour + RT):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17046.6  17092.3  -8517.3  17034.6    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7975 -0.7539 -0.2375  0.7471 11.4177
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8541   0.9242
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                            Estimate Std. Error z value Pr(>|z|)
# (Intercept)               -0.378654   0.114900  -3.296 0.000982 ***
# lottery_favour:treatmentA  0.208949   0.007659  27.283  < 2e-16 ***
# lottery_favour:treatmentE  0.223666   0.007707  29.021  < 2e-16 ***
# RT:treatmentA              0.045986   0.017709   2.597 0.009412 **
# RT:treatmentE              0.008696   0.016934   0.514 0.607597
# ---
# ...

# %% [markdown]
# ### 1.1b logRT

# %%
summary(glmer(slc_lot ~ (lottery_favour + logRT):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (lottery_favour + logRT):treatment + (1|subject), data1))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (lottery_favour + logRT):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17044.1  17089.8  -8516.1  17032.1    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.9042 -0.7530 -0.2374  0.7477 11.3667
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8421   0.9177
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                            Estimate Std. Error z value Pr(>|z|)
# (Intercept)               -0.469570   0.125626  -3.738 0.000186 ***
# lottery_favour:treatmentA  0.208981   0.007659  27.287  < 2e-16 ***
# lottery_favour:treatmentE  0.223725   0.007710  29.017  < 2e-16 ***
# logRT:treatmentA           0.216392   0.071415   3.030 0.002445 **
# logRT:treatmentE           0.060627   0.069730   0.869 0.384601
# ...

# %% [markdown]
# ### 1.2 without the low-effort group

# %%
summary(glmer(slc_lot ~ (lottery_favour + RT):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (lottery_favour + RT):treatment + (1|subject), data2))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (lottery_favour + RT):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10603.7  10647.2  -5295.9  10591.7    10419
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.7596  -0.6265  -0.2140   0.6510  26.2527
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 1.197    1.094
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)               -0.76985    0.16228  -4.744 2.10e-06 ***
# lottery_favour:treatmentA  0.32801    0.01240  26.448  < 2e-16 ***
# lottery_favour:treatmentE  0.30799    0.01054  29.226  < 2e-16 ***
# RT:treatmentA              0.11487    0.02390   4.807 1.53e-06 ***
# RT:treatmentE              0.03849    0.02053   1.874   0.0609 .
# ...

# %% [markdown]
# ### 1.2b logRT

# %%
summary(glmer(slc_lot ~ (lottery_favour + logRT):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (lottery_favour + logRT):treatment + (1|subject), data2))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (lottery_favour + logRT):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10590.9  10634.4  -5289.4  10578.9    10419
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.7117  -0.6228  -0.2129   0.6495  25.7947
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 1.185    1.088
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)               -1.07041    0.17695  -6.049 1.46e-09 ***
# lottery_favour:treatmentA  0.32782    0.01241  26.424  < 2e-16 ***
# lottery_favour:treatmentE  0.30797    0.01055  29.185  < 2e-16 ***
# logRT:treatmentA           0.55921    0.09867   5.667 1.45e-08 ***
# ...

# %% [markdown]
# ## 2 Predicting choice with the full set of DDM paramerters (noise level, drift rate,  initial bias x0)

# %% [markdown]
# ### Henceforward all continuous variables are scaled to avoid the error "Model failed to converge with max|grad|"

# %% [markdown]
# ### 2.1 whole dataset

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data1))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) +
#     scale(d) + scale(x0)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16951.7  17043.0  -8463.8  16927.7    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7321 -0.7550 -0.2397  0.7486 11.1859
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.172    0.4148
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.17655    0.05393  -3.274 0.001062 **
# scale(lottery_favour):treatmentA  0.99856    0.03684  27.108  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.06998    0.03718  28.780  < 2e-16 ***
# ...

# %% [markdown]
# ### 2.1b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data1))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) +
#     scale(d) + scale(x0)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16950.1  17041.5  -8463.1  16926.1    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.8148 -0.7550 -0.2392  0.7483 11.2044
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.1724   0.4152
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.17648    0.05397  -3.270 0.001077 **
# scale(lottery_favour):treatmentA  0.99877    0.03684  27.109  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.06955    0.03718  28.763  < 2e-16 ***
# ...

# %% [markdown]
# ### 2.2 without the low-effort group

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data2))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) +
#     scale(d) + scale(x0)):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10537.7  10624.7  -5256.8  10513.7    10413
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.2579  -0.6269  -0.2142   0.6487  25.1238
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.2229   0.4722
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.43446    0.07301  -5.951 2.67e-09 ***
# scale(lottery_favour):treatmentA  1.56449    0.05947  26.308  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.46897    0.05062  29.020  < 2e-16 ***
# ...

# %% [markdown]
# ### 2.2b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0)):treatment + (1|subject), data2))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) +
#     scale(d) + scale(x0)):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10525.6  10612.6  -5250.8  10501.6    10413
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.2387  -0.6235  -0.2125   0.6473  24.7773
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.2241   0.4734
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.436881   0.073197  -5.969 2.39e-09 ***
# scale(lottery_favour):treatmentA  1.564761   0.059523  26.289  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.467573   0.050675  28.960  < 2e-16 ***
# ...

# %% [markdown]
# ## 3 Predicting choice with the full set of DDM paramerters and psychometric measurements
# Interactive effects between the "reflection and BNT" and "reflection and noise level" are included.

# %% [markdown]
# ### 3.1 whole dataset

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) +
#     scale(d) + scale(x0) + scale(reflection) * scale(BNT) + scale(NFC) +
#     scale(FI) + scale(reflection):scale(noise)):treatment + (1 |      subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16954.1  17136.9  -8453.1  16906.1    14963
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7785 -0.7581 -0.2355  0.7467 11.1597
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.121    0.3479
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                            Estimate Std. Error z value Pr(>|z|)
# ...

# %% [markdown]
# ### 3.1b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) +
#     scale(d) + scale(x0) + scale(reflection) * scale(BNT) + scale(NFC) +
#     scale(FI) + scale(reflection):scale(noise)):treatment + (1 |      subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16952.6  17135.4  -8452.3  16904.6    14963
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.8637 -0.7573 -0.2355  0.7466 11.1779
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.1213   0.3483
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                            Estimate Std. Error z value Pr(>|z|)
# ...

# %% [markdown]
# ### 3.2 without the low-effort group

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2))
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0023116 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) +
#     scale(d) + scale(x0) + scale(reflection) * scale(BNT) + scale(NFC) +
#     scale(FI) + scale(reflection):scale(noise)):treatment + (1 |      subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10527.1  10701.1  -5239.5  10479.1    10401
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -10.8482  -0.6261  -0.2147   0.6507  25.9272
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.09482  0.3079
# ...

# %% [markdown]
# ### 3.2b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2))
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.00337816 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 23 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) +
#     scale(d) + scale(x0) + scale(reflection) * scale(BNT) + scale(NFC) +
#     scale(FI) + scale(reflection):scale(noise)):treatment + (1 |      subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10515.1  10689.2  -5233.6  10467.1    10401
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -10.8086  -0.6230  -0.2129   0.6487  25.5724
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.09584  0.3096
# ...

# %% [markdown]
# ## 4 Predicting choice with the full set of DDM paramerters and psychometric measurements, except the reflection
# In this analysis, reflection is removed becuase it correlates with the noise level.

# %% [markdown]
# ### 4.1 whole dataset

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) +
#     scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16955.2  17092.3  -8459.6  16919.2    14969
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7150 -0.7563 -0.2354  0.7478 11.1526
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.1495   0.3867
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.199439   0.051639  -3.862 0.000112 ***
# ...

# %% [markdown]
# ### 4.1b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) +
#     scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16953.7  17090.8  -8458.9  16917.7    14969
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7980 -0.7558 -0.2349  0.7467 11.1691
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.1499   0.3871
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.199467   0.051690  -3.859 0.000114 ***
# ...

# %% [markdown]
# ### 4.2 without the low-effort group

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) +
#     scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10536.7  10667.3  -5250.4  10500.7    10407
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.0166  -0.6270  -0.2137   0.6488  26.5604
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.1636   0.4045
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.480463   0.066663  -7.207 5.70e-13 ***
# ...

# %% [markdown]
# ### 4.2b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) + scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(noise) +
#     scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10524.9  10655.5  -5244.5  10488.9    10407
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -10.9808  -0.6243  -0.2118   0.6479  26.1962
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.1656   0.407
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.4829345  0.0670254  -7.205 5.79e-13 ***
# ...

# %% [markdown]
# ## 5 Predicting choice using psychometrics (without DDM parameters)

# %% [markdown]
# ### 5.1 who dataset

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17054.1  17175.9  -8511.0  17022.1    14971
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7208 -0.7542 -0.2386  0.7465 11.2809
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.7143   0.8452
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             -0.10357    0.12201  -0.849  0.39596
# ...

# %% [markdown]
# ### 5.1b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17052.4  17174.3  -8510.2  17020.4    14971
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.8033 -0.7540 -0.2384  0.7471 11.2923
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.7144   0.8452
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             -0.103251   0.122024  -0.846  0.39747
# ...

# %% [markdown]
# ### 5.2 without the low-effort group

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10605.8  10721.8  -5286.9  10573.8    10409
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.4882  -0.6268  -0.2149   0.6496  25.4192
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8237   0.9076
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             -0.31219    0.19249  -1.622   0.1048
# ...

# %% [markdown]
# ### 5.2b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.00145287 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10593.2  10709.2  -5280.6  10561.2    10409
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.4641  -0.6225  -0.2141   0.6495  24.9855
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8196   0.9053
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
# ...

# %% [markdown]
# ## 6 Predicting choice using psychometrics but drop BNT

# %% [markdown]
# ### 6.1 whole dataset

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17049.7  17141.1  -8512.8  17025.7    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.7339 -0.7547 -0.2382  0.7463 11.3528
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.7522   0.8673
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.17524    0.10483  -1.672  0.09458 .
# scale(lottery_favour):treatmentA  1.01330    0.03721  27.233  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.09113    0.03755  29.054  < 2e-16 ***
# ...

# %% [markdown]
# ### 6.1b logRt

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17048.1  17139.5  -8512.1  17024.1    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.8161 -0.7539 -0.2380  0.7471 11.3664
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.753    0.8678
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.17535    0.10488  -1.672  0.09454 .
# scale(lottery_favour):treatmentA  1.01354    0.03721  27.235  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.09069    0.03756  29.037  < 2e-16 ***
# ...

# %% [markdown]
# ### 6.2 without the low-effort group

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#    10604    10691    -5290    10580    10413
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.5507  -0.6278  -0.2145   0.6501  25.8390
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.9384   0.9687
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.4519428  0.1407615  -3.211 0.001324 **
# scale(lottery_favour):treatmentA  1.5809932  0.0599370  26.378  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.4967098  0.0511218  29.277  < 2e-16 ***
# ...

# %% [markdown]
# ### 6.2b logRT

# %%
summary(glmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data2, family=binomial(link = "logit")))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ (scale(lottery_favour) + scale(logRT) + scale(reflection) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10591.6  10678.6  -5283.8  10567.6    10413
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -11.5252  -0.6228  -0.2134   0.6504  25.4143
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.9372   0.9681
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.454908   0.140677  -3.234 0.001222 **
# scale(lottery_favour):treatmentA  1.580573   0.059984  26.350  < 2e-16 ***
# scale(lottery_favour):treatmentE  1.495663   0.051180  29.223  < 2e-16 ***
# ...
