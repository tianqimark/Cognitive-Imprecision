# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)

# %% [markdown]
# # This analysis is for the version AM_n001_10s_B1, SNR, risk division

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1 Dataset_AU/trialsAUM_10s_B1.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# create another dataset in wh subjects with error_choice > 5 are rejected
data2 <- subset(data1, error_choice <= 5)

# %%
names(data1)
# Out:
#  [1] "subject"        "trial"          "treatment"      "lot_code"
#  [5] "risk"           "reward"         "WTP"            "certainty"
#  [9] "RT"             "choice"         "slc_lot"        "display"
# [13] "correct"        "decmode"        "reflection"     "intuition"
# [17] "BNT"            "NFC"            "FI"             "value_diff"
# [21] "value_sum"      "lottery_favour" "lot_correct"    "d"
# [25] "noise"          "x0"             "nondectime"     "error_choice"
# [29] "accuracy"       "risk_level"     "SNR"            "logRT"

# %% [markdown]
# # Predicting choice with the full set of DDM paramerters (SNR, x0)

# %% [markdown]
# ###  All continuous variables are scaled due to the inclusion of interactive terms and to avoid the error "Model failed to converge with max|grad|".
# Interactive effects between the "lottery_favour and WTP".

# %%
# All subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0)):treatment + (1|subject), data1))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17924.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4850 -0.9170  0.0362  0.8622  3.1730
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007579 0.08706
#  Residual             0.190629 0.43661
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.905e-01  1.121e-02  6.865e+01
# scale(lottery_favour):treatmentA             1.809e-01  6.021e-03  1.453e+04
# scale(lottery_favour):treatmentE             2.347e-01  6.723e-03  1.425e+04
# scale(WTP):treatmentA                       -4.254e-03  6.505e-03  1.413e+04
# scale(WTP):treatmentE                       -3.082e-02  6.190e-03  1.485e+04
# scale(SNR):treatmentA                        1.552e-02  1.561e-02  6.479e+01
# scale(SNR):treatmentE                        6.396e-02  1.573e-02  6.497e+01
# scale(x0):treatmentA                         1.414e-01  1.420e-02  6.490e+01
# scale(x0):treatmentE                         1.493e-01  1.808e-02  6.462e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.238e-02  5.151e-03  1.182e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.469e-02  5.277e-03  1.329e+04
#                                             t value Pr(>|t|)
# (Intercept)                                  43.739  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.048  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.910  < 2e-16 ***
# scale(WTP):treatmentA                        -0.654 0.513195
# scale(WTP):treatmentE                        -4.979 6.47e-07 ***
# scale(SNR):treatmentA                         0.995 0.323670
# scale(SNR):treatmentE                         4.065 0.000132 ***
# scale(x0):treatmentA                          9.959 1.07e-14 ***
# scale(x0):treatmentE                          8.256 1.07e-11 ***
# scale(lottery_favour):scale(WTP):treatmentA  -4.346 1.40e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.469  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E s(SNR):A s(SNR):E s(0):A
# scl(ltt_):A   0.028
# scl(ltt_):E   0.003  0.000
# scl(WTP):tA   0.061 -0.359  0.000
# scl(WTP):tE   0.010  0.000 -0.288  0.001
# scl(SNR):tA   0.003  0.010  0.000  0.001    0.000
# scl(SNR):tE   0.029  0.001  0.000  0.002   -0.005    0.000
# scl(x0):trA  -0.104 -0.012  0.000 -0.003   -0.001   -0.250   -0.003
# scl(x0):trE   0.142  0.004 -0.006  0.009   -0.007    0.000    0.026   -0.015
# s(_):(WTP):A -0.131  0.007  0.000 -0.273   -0.001    0.029   -0.004   -0.020
# s(_):(WTP):E -0.093 -0.003 -0.318 -0.006   -0.304    0.000    0.050    0.010
#              s(0):E s(_):(WTP):A
# scl(ltt_):A
# scl(ltt_):E
# scl(WTP):tA
# scl(WTP):tE
# scl(SNR):tA
# scl(SNR):tE
# scl(x0):trA
# scl(x0):trE
# s(_):(WTP):A -0.019
# s(_):(WTP):E  0.016  0.012

# %%
# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0)):treatment + (1|subject), data2))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11175.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4600 -0.8687 -0.0501  0.8387  3.7803
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006371 0.07982
#  Residual             0.168106 0.41001
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.495e-01  1.236e-02  4.632e+01
# scale(lottery_favour):treatmentA             2.383e-01  7.019e-03  1.020e+04
# scale(lottery_favour):treatmentE             2.871e-01  7.221e-03  9.703e+03
# scale(WTP):treatmentA                       -4.240e-02  7.583e-03  1.003e+04
# scale(WTP):treatmentE                       -7.641e-02  6.725e-03  1.026e+04
# scale(SNR):treatmentA                        2.097e-02  2.149e-02  4.365e+01
# scale(SNR):treatmentE                        5.746e-02  1.661e-02  4.400e+01
# scale(x0):treatmentA                         1.307e-01  1.765e-02  4.364e+01
# scale(x0):treatmentE                         1.786e-01  2.118e-02  4.373e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.176e-02  6.095e-03  8.016e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.539e-02  5.597e-03  9.088e+03
#                                             t value Pr(>|t|)
# (Intercept)                                  36.365  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.944  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.759  < 2e-16 ***
# scale(WTP):treatmentA                        -5.592 2.31e-08 ***
# scale(WTP):treatmentE                       -11.362  < 2e-16 ***
# scale(SNR):treatmentA                         0.976  0.33444
# scale(SNR):treatmentE                         3.460  0.00121 **
# scale(x0):treatmentA                          7.401 3.11e-09 ***
# scale(x0):treatmentE                          8.434 1.02e-10 ***
# scale(lottery_favour):scale(WTP):treatmentA  -1.930  0.05360 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.323 2.69e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E s(SNR):A s(SNR):E s(0):A
# scl(ltt_):A   0.032
# scl(ltt_):E   0.006  0.000
# scl(WTP):tA   0.060 -0.357  0.000
# scl(WTP):tE   0.014  0.000 -0.288  0.001
# scl(SNR):tA  -0.079  0.003  0.000 -0.009   -0.001
# scl(SNR):tE   0.082  0.003 -0.021  0.005   -0.022   -0.006
# scl(x0):trA  -0.018 -0.008  0.000  0.004    0.000   -0.562   -0.001
# scl(x0):trE   0.100  0.003  0.019  0.006    0.012   -0.008   -0.113   -0.002
# s(_):(WTP):A -0.127 -0.009 -0.001 -0.257   -0.002    0.049   -0.010   -0.032
# s(_):(WTP):E -0.101 -0.003 -0.320 -0.006   -0.318    0.008    0.076    0.002
#              s(0):E s(_):(WTP):A
# scl(ltt_):A
# scl(ltt_):E
# scl(WTP):tA
# scl(WTP):tE
# scl(SNR):tA
# scl(SNR):tE
# scl(x0):trA
# scl(x0):trE
# s(_):(WTP):A -0.013
# s(_):(WTP):E -0.018  0.013

# %% [markdown]
# #  Predicting choice with the DDM paramerters and psychometric measurements
# Interactive effects between the "lottery_favour and WTP" are included.

# %%
# All subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17964.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4872 -0.9163  0.0366  0.8608  3.1712
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007188 0.08478
#  Residual             0.190629 0.43661
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.859e-01  1.121e-02  6.002e+01
# scale(lottery_favour):treatmentA             1.809e-01  6.022e-03  1.445e+04
# scale(lottery_favour):treatmentE             2.350e-01  6.733e-03  1.438e+04
# scale(WTP):treatmentA                       -4.405e-03  6.508e-03  1.403e+04
# scale(WTP):treatmentE                       -3.058e-02  6.196e-03  1.488e+04
# scale(SNR):treatmentA                        1.180e-02  1.704e-02  5.684e+01
# scale(SNR):treatmentE                        5.774e-02  1.773e-02  5.731e+01
# scale(x0):treatmentA                         1.431e-01  1.437e-02  5.694e+01
# scale(x0):treatmentE                         1.455e-01  1.958e-02  5.677e+01
# scale(reflection):treatmentA                 5.878e-03  2.002e-02  5.690e+01
# scale(reflection):treatmentE                 4.430e-02  1.911e-02  5.766e+01
# scale(BNT):treatmentA                        1.047e-02  2.204e-02  5.694e+01
# scale(BNT):treatmentE                       -3.870e-02  1.664e-02  5.679e+01
# scale(NFC):treatmentA                        1.557e-02  1.920e-02  5.701e+01
# scale(NFC):treatmentE                       -7.152e-03  1.394e-02  5.702e+01
# scale(FI):treatmentA                        -6.750e-03  1.537e-02  5.678e+01
# scale(FI):treatmentE                         2.471e-02  1.801e-02  5.707e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.213e-02  5.152e-03  1.146e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.557e-02  5.292e-03  1.376e+04
#                                             t value Pr(>|t|)
# (Intercept)                                  43.337  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.033  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.899  < 2e-16 ***
# scale(WTP):treatmentA                        -0.677   0.4985
# scale(WTP):treatmentE                        -4.935 8.09e-07 ***
# scale(SNR):treatmentA                         0.693   0.4912
# scale(SNR):treatmentE                         3.256   0.0019 **
# scale(x0):treatmentA                          9.961 4.38e-14 ***
# scale(x0):treatmentE                          7.434 6.14e-10 ***
# scale(reflection):treatmentA                  0.294   0.7702
# scale(reflection):treatmentE                  2.318   0.0240 *
# scale(BNT):treatmentA                         0.475   0.6366
# scale(BNT):treatmentE                        -2.326   0.0236 *
# scale(NFC):treatmentA                         0.811   0.4206
# scale(NFC):treatmentE                        -0.513   0.6100
# scale(FI):treatmentA                         -0.439   0.6621
# scale(FI):treatmentE                          1.372   0.1754
# scale(lottery_favour):scale(WTP):treatmentA  -4.295 1.76e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.610  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11205.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4766 -0.8719 -0.0405  0.8384  3.7983
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004848 0.06963
#  Residual             0.168104 0.41001
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.414e-01  1.208e-02  3.796e+01
# scale(lottery_favour):treatmentA             2.385e-01  7.016e-03  1.006e+04
# scale(lottery_favour):treatmentE             2.875e-01  7.232e-03  9.716e+03
# scale(WTP):treatmentA                       -4.242e-02  7.580e-03  9.828e+03
# scale(WTP):treatmentE                       -7.608e-02  6.731e-03  1.027e+04
# scale(SNR):treatmentA                       -1.017e-02  2.346e-02  3.578e+01
# scale(SNR):treatmentE                        4.762e-02  1.681e-02  3.673e+01
# scale(x0):treatmentA                         1.592e-01  1.931e-02  3.589e+01
# scale(x0):treatmentE                         1.492e-01  2.171e-02  3.593e+01
# scale(reflection):treatmentA                 3.133e-02  2.468e-02  3.606e+01
# scale(reflection):treatmentE                 6.705e-02  2.126e-02  3.681e+01
# scale(BNT):treatmentA                        3.472e-04  2.639e-02  3.611e+01
# scale(BNT):treatmentE                       -3.373e-02  1.692e-02  3.591e+01
# scale(NFC):treatmentA                       -7.594e-03  2.036e-02  3.587e+01
# scale(NFC):treatmentE                       -1.926e-02  1.350e-02  3.598e+01
# scale(FI):treatmentA                         4.394e-02  1.860e-02  3.634e+01
# scale(FI):treatmentE                         4.333e-02  1.875e-02  3.645e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.102e-02  6.092e-03  7.440e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.644e-02  5.611e-03  9.225e+03
#                                             t value Pr(>|t|)
# (Intercept)                                  36.526  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.991  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.752  < 2e-16 ***
# scale(WTP):treatmentA                        -5.597 2.24e-08 ***
# scale(WTP):treatmentE                       -11.303  < 2e-16 ***
# scale(SNR):treatmentA                        -0.434  0.66722
# scale(SNR):treatmentE                         2.832  0.00746 **
# scale(x0):treatmentA                          8.242 8.49e-10 ***
# scale(x0):treatmentE                          6.871 4.91e-08 ***
# scale(reflection):treatmentA                  1.270  0.21240
# scale(reflection):treatmentE                  3.154  0.00320 **
# scale(BNT):treatmentA                         0.013  0.98958
# scale(BNT):treatmentE                        -1.994  0.05383 .
# scale(NFC):treatmentA                        -0.373  0.71134
# scale(NFC):treatmentE                        -1.427  0.16225
# scale(FI):treatmentA                          2.362  0.02364 *
# scale(FI):treatmentE                          2.312  0.02656 *
# scale(lottery_favour):scale(WTP):treatmentA  -1.809  0.07046 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.495 8.70e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Predicting choice with psychometric measurements alone

# %%
# all subjects
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18025.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4841 -0.9171  0.0361  0.8613  3.1753
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.0297   0.1723
#  Residual             0.1906   0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.879e-01  2.123e-02  6.380e+01
# scale(lottery_favour):treatmentA             1.827e-01  6.057e-03  1.497e+04
# scale(lottery_favour):treatmentE             2.378e-01  6.773e-03  1.497e+04
# scale(WTP):treatmentA                       -2.141e-03  6.557e-03  1.496e+04
# scale(WTP):treatmentE                       -2.867e-02  6.215e-03  1.496e+04
# scale(reflection):treatmentA                -7.892e-03  3.756e-02  6.283e+01
# scale(reflection):treatmentE                 6.530e-02  3.523e-02  6.296e+01
# scale(BNT):treatmentA                        2.384e-02  4.236e-02  6.286e+01
# scale(BNT):treatmentE                       -9.304e-03  3.141e-02  6.284e+01
# scale(NFC):treatmentA                       -3.302e-03  3.679e-02  6.288e+01
# scale(NFC):treatmentE                        6.073e-03  2.630e-02  6.288e+01
# scale(FI):treatmentA                        -2.916e-02  2.891e-02  6.281e+01
# scale(FI):treatmentE                         8.691e-02  3.115e-02  6.282e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.361e-02  5.226e-03  1.482e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.721e-02  5.331e-03  1.493e+04
#                                             t value Pr(>|t|)
# (Intercept)                                  22.987  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.168  < 2e-16 ***
# scale(lottery_favour):treatmentE             35.104  < 2e-16 ***
# scale(WTP):treatmentA                        -0.327  0.74399
# scale(WTP):treatmentE                        -4.613 4.00e-06 ***
# scale(reflection):treatmentA                 -0.210  0.83426
# scale(reflection):treatmentE                  1.854  0.06846 .
# scale(BNT):treatmentA                         0.563  0.57560
# scale(BNT):treatmentE                        -0.296  0.76804
# scale(NFC):treatmentA                        -0.090  0.92877
# scale(NFC):treatmentE                         0.231  0.81815
# scale(FI):treatmentA                         -1.009  0.31700
# scale(FI):treatmentE                          2.790  0.00697 **
# scale(lottery_favour):scale(WTP):treatmentA  -4.519 6.27e-06 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.856  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# without low-attention individuals
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11251.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4779 -0.8729 -0.0518  0.8370  3.7854
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02827  0.1681
#  Residual             0.16810  0.4100
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.331e-01  2.653e-02  4.143e+01
# scale(lottery_favour):treatmentA             2.394e-01  7.058e-03  1.041e+04
# scale(lottery_favour):treatmentE             2.905e-01  7.286e-03  1.041e+04
# scale(WTP):treatmentA                       -4.123e-02  7.636e-03  1.041e+04
# scale(WTP):treatmentE                       -7.391e-02  6.758e-03  1.041e+04
# scale(reflection):treatmentA                -2.386e-02  5.028e-02  4.104e+01
# scale(reflection):treatmentE                 1.191e-01  4.467e-02  4.109e+01
# scale(BNT):treatmentA                        5.453e-02  5.893e-02  4.101e+01
# scale(BNT):treatmentE                       -3.139e-02  3.782e-02  4.098e+01
# scale(NFC):treatmentA                       -1.829e-02  4.559e-02  4.097e+01
# scale(NFC):treatmentE                       -1.088e-02  2.978e-02  4.096e+01
# scale(FI):treatmentA                        -2.010e-02  3.633e-02  4.105e+01
# scale(FI):treatmentE                         1.184e-01  3.482e-02  4.101e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.229e-02  6.193e-03  1.035e+04
# scale(lottery_favour):scale(WTP):treatmentE -3.846e-02  5.660e-03  1.038e+04
#                                             t value Pr(>|t|)
# (Intercept)                                  16.322  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.919  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.877  < 2e-16 ***
# scale(WTP):treatmentA                        -5.400 6.81e-08 ***
# scale(WTP):treatmentE                       -10.936  < 2e-16 ***
# scale(reflection):treatmentA                 -0.474  0.63769
# scale(reflection):treatmentE                  2.666  0.01093 *
# scale(BNT):treatmentA                         0.925  0.36020
# scale(BNT):treatmentE                        -0.830  0.41132
# scale(NFC):treatmentA                        -0.401  0.69031
# scale(NFC):treatmentE                        -0.365  0.71682
# scale(FI):treatmentA                         -0.553  0.58317
# scale(FI):treatmentE                          3.401  0.00151 **
# scale(lottery_favour):scale(WTP):treatmentA  -1.984  0.04730 *
# scale(lottery_favour):scale(WTP):treatmentE  -6.796 1.13e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Others

# %% [markdown]
# ### Is RT affected by treatments?
# No difference for RT per trial, but choosing lottery takes longer time only in the treatment E.

# %%
# all subjects
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45378.7  45439.6 -22681.4  45362.7    14979
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4641 -0.6078 -0.2815  0.2766 12.8588
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2449   0.4949
#  Residual             0.3978   0.6307
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.319506   0.127346  18.214  < 2e-16 ***
# scale(value_diff)            -0.047105   0.008963  -5.256 1.48e-07 ***
# scale(WTP)                   -0.014622   0.010495  -1.393   0.1635
# slc_lot                       0.045320   0.018174   2.494   0.0126 *
# treatmentE                    0.194103   0.179439   1.082   0.2794
# scale(value_diff):scale(WTP)  0.029356   0.007086   4.143 3.43e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt trtmnE
# scl(vl_dff) -0.010
# scale(WTP)   0.016 -0.247
# slc_lot     -0.066  0.059 -0.023
# treatmentE  -0.707  0.008 -0.018  0.002
# sc(_):(WTP) -0.001 -0.177 -0.175 -0.126 -0.005
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot):treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45365.3  45449.0 -22671.6  45343.3    14976
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4657 -0.6080 -0.2821  0.2771 12.9894
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2477   0.4976
#  Residual             0.3967   0.6299
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.408276   0.090727  26.544  < 2e-16
# scale(value_diff):treatmentA            -0.027843   0.011680  -2.384  0.01714
# scale(value_diff):treatmentE            -0.095729   0.015094  -6.342 2.27e-10
# scale(WTP):treatmentA                   -0.040189   0.014954  -2.687  0.00720
# scale(WTP):treatmentE                    0.014635   0.014612   1.002  0.31654
# slc_lot:treatmentA                       0.026117   0.024462   1.068  0.28568
# slc_lot:treatmentE                       0.074382   0.027223   2.732  0.00629
# scale(value_diff):scale(WTP):treatmentA  0.023461   0.009495   2.471  0.01348
# scale(value_diff):scale(WTP):treatmentE  0.053261   0.011513   4.626 3.73e-06
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      **
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E slc_:A slc_:E s(_):(WTP):A
# scl(vl_d):A  -0.010
# scl(vl_d):E   0.004  0.000
# scl(WTP):tA   0.015 -0.229  0.000
# scl(WTP):tE  -0.007  0.000 -0.248  0.000
# slc_lt:trtA  -0.064  0.103  0.000 -0.041    0.000
# slc_lt:trtE  -0.064  0.001  0.012 -0.001   -0.010    0.004
# s(_):(WTP):A -0.004 -0.029  0.000 -0.203    0.000   -0.110  0.000
# s(_):(WTP):E -0.008  0.000 -0.409  0.000   -0.119    0.000 -0.123  0.000

# %%
# without low-attention individuals
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + treatment + (1|subject), data2, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot):treatment + (1|subject), data2, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + treatment + (1 |
#     subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#    31904    31962   -15944    31888    10417
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.5540 -0.6314 -0.2898  0.2860  9.6850
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.1784   0.4224
#  Residual             0.3525   0.5937
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.311736   0.142510  16.222  < 2e-16 ***
# scale(value_diff)            -0.075203   0.010458  -7.191 6.45e-13 ***
# scale(WTP)                    0.008714   0.012691   0.687 0.492305
# slc_lot                       0.141208   0.023632   5.975 2.30e-09 ***
# treatmentE                    0.296418   0.193039   1.536 0.124653
# scale(value_diff):scale(WTP)  0.032326   0.008480   3.812 0.000138 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt trtmnE
# scl(vl_dff) -0.014
# scale(WTP)   0.017 -0.253
# slc_lot     -0.064  0.067  0.025
# treatmentE  -0.735  0.009 -0.020  0.000
# sc(_):(WTP)  0.006 -0.088 -0.218 -0.231 -0.005
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot):treatment + (1 |
#     subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  31893.8  31973.6 -15935.9  31871.8    10414
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.5552 -0.6302 -0.2888  0.2841  9.6825
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.1876   0.4331
#  Residual             0.3514   0.5928
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                         Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.46409    0.09929  24.816  < 2e-16
# scale(value_diff):treatmentA            -0.04637    0.01536  -3.019  0.00254
# scale(value_diff):treatmentE            -0.13035    0.01625  -8.022 1.04e-15
# scale(WTP):treatmentA                   -0.01490    0.01995  -0.747  0.45515
# scale(WTP):treatmentE                    0.03120    0.01652   1.889  0.05886
# slc_lot:treatmentA                       0.14056    0.03433   4.095 4.23e-05
# slc_lot:treatmentE                       0.15569    0.03276   4.753 2.00e-06
# scale(value_diff):scale(WTP):treatmentA  0.02442    0.01384   1.765  0.07765
# scale(value_diff):scale(WTP):treatmentE  0.05881    0.01219   4.824 1.41e-06
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            **
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA
# scale(WTP):treatmentE                   .
# slc_lot:treatmentA                      ***
# slc_lot:treatmentE                      ***
# scale(value_diff):scale(WTP):treatmentA .
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E slc_:A slc_:E s(_):(WTP):A
# scl(vl_d):A  -0.014
# scl(vl_d):E   0.000  0.000
# scl(WTP):tA   0.020 -0.224  0.000
# scl(WTP):tE  -0.012  0.000 -0.242  0.000
# slc_lt:trtA  -0.062  0.111  0.000 -0.063    0.001
# slc_lt:trtE  -0.069  0.001  0.005 -0.001    0.089    0.004
# s(_):(WTP):A  0.002  0.184  0.000 -0.189    0.000   -0.232  0.000
# s(_):(WTP):E  0.001  0.000 -0.367  0.000   -0.194    0.000 -0.198  0.000

# %% [markdown]
# ### Is chance of choosing lottery affected by treatments?
# NO (marginal significance with all subjects)

# %%
# All subjects
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16845.0  16890.7  -8416.5  16833.0    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1540 -0.7438 -0.1979  0.7181 17.7393
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8703   0.9329
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.12833    0.15838   0.810 0.417785
# scale(lottery_favour)             1.24103    0.03118  39.801  < 2e-16 ***
# scale(WTP)                       -0.08056    0.02384  -3.379 0.000728 ***
# treatmentE                       -0.40199    0.22348  -1.799 0.072048 .
# scale(lottery_favour):scale(WTP) -0.27586    0.02244 -12.292  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE
# scl(lttry_)  0.025
# scale(WTP)   0.038 -0.233
# treatmentE  -0.707 -0.031 -0.022
# sc(_):(WTP) -0.068 -0.371 -0.314  0.019

# %%
# without low-attention individuals
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data2
#
#      AIC      BIC   logLik deviance df.resid
#  10178.5  10222.0  -5083.2  10166.5    10419
#
# Scaled residuals:
#    Min     1Q Median     3Q    Max
# -4.637 -0.603 -0.159  0.584 72.646
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 1.311    1.145
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                      -0.19176    0.24217  -0.792    0.428
# scale(lottery_favour)             2.03704    0.04979  40.914   <2e-16 ***
# scale(WTP)                       -0.37003    0.03263 -11.339   <2e-16 ***
# treatmentE                       -0.34282    0.32906  -1.042    0.298
# scale(lottery_favour):scale(WTP) -0.39882    0.03187 -12.513   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE
# scl(lttry_)  0.005
# scale(WTP)   0.039 -0.251
# treatmentE  -0.734 -0.026 -0.015
# sc(_):(WTP) -0.050 -0.441 -0.354  0.013

# %% [markdown]
# # Split by the pre-evaluation bias

# %%
# split data by whether the subject has a positive or negative pre-evaluation bias
# L: risk-lover; H: risk-hater
data1L <- subset(data1, x0 > 0)
data1H <- subset(data1, x0 < 0)

# data2L <- subset(data2, x0 > 0)
# data2H <- subset(data2, x0 < 0)

# %% [markdown]
# ### With additional interaction between the SNR and x0:

# %%
# All subjects (without psychometrics)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR)*scale(x0)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR)*scale(x0)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7199.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4424 -1.0520  0.3678  0.7735  3.1064
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007491 0.08655
#  Residual             0.197043 0.44390
# Number of obs: 5826, groups:  subject, 28
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.589e-01  2.282e-02  2.089e+01
# scale(lottery_favour):treatmentA             1.977e-01  8.657e-03  5.555e+03
# scale(lottery_favour):treatmentE             2.286e-01  1.424e-02  5.452e+03
# scale(WTP):treatmentA                        1.193e-02  9.049e-03  5.614e+03
# scale(WTP):treatmentE                        2.242e-02  1.245e-02  5.784e+03
# scale(SNR):treatmentA                        1.058e-02  2.556e-02  2.002e+01
# scale(SNR):treatmentE                        1.433e-01  4.456e-02  2.039e+01
# scale(x0):treatmentA                         8.968e-02  2.262e-02  1.998e+01
# scale(x0):treatmentE                         5.906e-02  4.870e-02  2.002e+01
# scale(lottery_favour):scale(WTP):treatmentA -4.899e-02  7.450e-03  5.428e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.156e-02  1.021e-02  4.936e+03
# scale(SNR):scale(x0):treatmentA             -3.326e-02  2.610e-02  2.004e+01
# scale(SNR):scale(x0):treatmentE             -1.225e-01  5.043e-02  2.044e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  28.875  < 2e-16 ***
# scale(lottery_favour):treatmentA             22.833  < 2e-16 ***
# scale(lottery_favour):treatmentE             16.057  < 2e-16 ***
# scale(WTP):treatmentA                         1.319 0.187272
# scale(WTP):treatmentE                         1.801 0.071811 .
# scale(SNR):treatmentA                         0.414 0.683349
# scale(SNR):treatmentE                         3.217 0.004250 **
# scale(x0):treatmentA                          3.964 0.000766 ***
# scale(x0):treatmentE                          1.213 0.239351
# scale(lottery_favour):scale(WTP):treatmentA  -6.576 5.28e-11 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.012 2.66e-12 ***
# scale(SNR):scale(x0):treatmentA              -1.274 0.217188
# scale(SNR):scale(x0):treatmentE              -2.429 0.024495 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 10719.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1856 -0.8560 -0.2680  0.9282  3.1649
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005685 0.0754
#  Residual             0.185288 0.4305
# Number of obs: 9161, groups:  subject, 44
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.019e-01  1.280e-02  3.888e+01
# scale(lottery_favour):treatmentA             1.658e-01  8.417e-03  8.841e+03
# scale(lottery_favour):treatmentE             2.365e-01  7.540e-03  8.442e+03
# scale(WTP):treatmentA                       -2.345e-02  9.430e-03  7.990e+03
# scale(WTP):treatmentE                       -4.937e-02  7.058e-03  8.944e+03
# scale(SNR):treatmentA                        2.456e-02  2.391e-02  3.638e+01
# scale(SNR):treatmentE                        5.615e-02  1.630e-02  3.617e+01
# scale(x0):treatmentA                         1.042e-01  1.863e-02  3.644e+01
# scale(x0):treatmentE                         1.324e-01  2.307e-02  3.632e+01
# scale(lottery_favour):scale(WTP):treatmentA  3.088e-03  7.195e-03  4.937e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.322e-02  6.084e-03  7.698e+03
# scale(SNR):scale(x0):treatmentA             -3.479e-02  2.374e-02  3.657e+01
# scale(SNR):scale(x0):treatmentE              6.804e-04  2.876e-02  3.642e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  31.396  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.703  < 2e-16 ***
# scale(lottery_favour):treatmentE             31.364  < 2e-16 ***
# scale(WTP):treatmentA                        -2.487  0.01290 *
# scale(WTP):treatmentE                        -6.995 2.84e-12 ***
# scale(SNR):treatmentA                         1.027  0.31100
# scale(SNR):treatmentE                         3.444  0.00147 **
# scale(x0):treatmentA                          5.596 2.32e-06 ***
# scale(x0):treatmentE                          5.738 1.51e-06 ***
# scale(lottery_favour):scale(WTP):treatmentA   0.429  0.66776
# scale(lottery_favour):scale(WTP):treatmentE  -5.460 4.91e-08 ***
# scale(SNR):scale(x0):treatmentA              -1.465  0.15143
# scale(SNR):scale(x0):treatmentE               0.024  0.98126
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# All subjects (with psychometrics)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7228.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4507 -1.0480  0.3644  0.7743  3.1089
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006219 0.07886
#  Residual             0.197034 0.44388
# Number of obs: 5826, groups:  subject, 28
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.678e-01  2.530e-02  1.309e+01
# scale(lottery_favour):treatmentA             1.994e-01  8.712e-03  5.796e+03
# scale(lottery_favour):treatmentE             2.312e-01  1.431e-02  5.703e+03
# scale(WTP):treatmentA                        1.379e-02  9.101e-03  5.799e+03
# scale(WTP):treatmentE                        2.395e-02  1.248e-02  5.802e+03
# scale(SNR):treatmentA                        1.630e-02  2.546e-02  1.277e+01
# scale(SNR):treatmentE                        2.220e-01  6.228e-02  1.319e+01
# scale(x0):treatmentA                         9.636e-02  2.418e-02  1.280e+01
# scale(x0):treatmentE                         8.308e-02  4.896e-02  1.262e+01
# scale(reflection):treatmentA                 9.437e-03  2.467e-02  1.260e+01
# scale(reflection):treatmentE                 5.890e-03  4.937e-02  1.300e+01
# scale(BNT):treatmentA                       -2.137e-03  2.642e-02  1.272e+01
# scale(BNT):treatmentE                       -7.710e-02  4.461e-02  1.273e+01
# scale(NFC):treatmentA                        4.482e-02  2.337e-02  1.352e+01
# scale(NFC):treatmentE                       -6.667e-03  5.344e-02  1.286e+01
# scale(FI):treatmentA                        -9.877e-03  1.997e-02  1.267e+01
# scale(FI):treatmentE                         1.744e-01  7.019e-02  1.302e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.038e-02  7.475e-03  5.523e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.282e-02  1.027e-02  5.310e+03
# scale(SNR):scale(x0):treatmentA             -2.976e-02  2.787e-02  1.275e+01
# scale(SNR):scale(x0):treatmentE             -2.379e-01  1.093e-01  1.272e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  26.395 9.80e-13 ***
# scale(lottery_favour):treatmentA             22.886  < 2e-16 ***
# scale(lottery_favour):treatmentE             16.155  < 2e-16 ***
# scale(WTP):treatmentA                         1.515  0.12980
# scale(WTP):treatmentE                         1.919  0.05499 .
# scale(SNR):treatmentA                         0.640  0.53330
# scale(SNR):treatmentE                         3.565  0.00338 **
# scale(x0):treatmentA                          3.985  0.00160 **
# scale(x0):treatmentE                          1.697  0.11421
# scale(reflection):treatmentA                  0.382  0.70851
# scale(reflection):treatmentE                  0.119  0.90685
# scale(BNT):treatmentA                        -0.081  0.93679
# scale(BNT):treatmentE                        -1.728  0.10810
# scale(NFC):treatmentA                         1.917  0.07656 .
# scale(NFC):treatmentE                        -0.125  0.90263
# scale(FI):treatmentA                         -0.495  0.62931
# scale(FI):treatmentE                          2.484  0.02736 *
# scale(lottery_favour):scale(WTP):treatmentA  -6.739 1.76e-11 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.093 1.49e-12 ***
# scale(SNR):scale(x0):treatmentA              -1.068  0.30540
# scale(SNR):scale(x0):treatmentE              -2.177  0.04894 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 10751.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1856 -0.8548 -0.2633  0.9290  3.1540
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004474 0.06689
#  Residual             0.185285 0.43045
# Number of obs: 9161, groups:  subject, 44
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.049e-01  1.278e-02  3.080e+01
# scale(lottery_favour):treatmentA             1.659e-01  8.416e-03  8.680e+03
# scale(lottery_favour):treatmentE             2.377e-01  7.565e-03  8.690e+03
# scale(WTP):treatmentA                       -2.357e-02  9.421e-03  7.459e+03
# scale(WTP):treatmentE                       -4.843e-02  7.073e-03  9.020e+03
# scale(SNR):treatmentA                        1.120e-02  2.801e-02  2.869e+01
# scale(SNR):treatmentE                        4.949e-02  1.664e-02  2.872e+01
# scale(x0):treatmentA                         1.074e-01  1.869e-02  2.862e+01
# scale(x0):treatmentE                         8.892e-02  2.690e-02  2.864e+01
# scale(reflection):treatmentA                 2.332e-02  3.072e-02  2.895e+01
# scale(reflection):treatmentE                 6.617e-02  1.983e-02  2.938e+01
# scale(BNT):treatmentA                        7.711e-03  3.025e-02  2.914e+01
# scale(BNT):treatmentE                       -3.701e-02  1.740e-02  2.832e+01
# scale(NFC):treatmentA                       -3.065e-02  3.245e-02  2.879e+01
# scale(NFC):treatmentE                       -2.484e-02  1.477e-02  2.820e+01
# scale(FI):treatmentA                        -6.113e-03  2.011e-02  2.853e+01
# scale(FI):treatmentE                         4.452e-02  1.988e-02  2.885e+01
# scale(lottery_favour):scale(WTP):treatmentA  3.439e-03  7.186e-03  4.173e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.465e-02  6.098e-03  7.766e+03
# scale(SNR):scale(x0):treatmentA             -3.116e-02  2.277e-02  2.877e+01
# scale(SNR):scale(x0):treatmentE             -3.443e-02  3.169e-02  2.859e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  31.695  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.713  < 2e-16 ***
# scale(lottery_favour):treatmentE             31.426  < 2e-16 ***
# scale(WTP):treatmentA                        -2.502  0.01237 *
# scale(WTP):treatmentE                        -6.848 8.00e-12 ***
# scale(SNR):treatmentA                         0.400  0.69214
# scale(SNR):treatmentE                         2.974  0.00590 **
# scale(x0):treatmentA                          5.748 3.34e-06 ***
# scale(x0):treatmentE                          3.305  0.00256 **
# scale(reflection):treatmentA                  0.759  0.45385
# scale(reflection):treatmentE                  3.336  0.00231 **
# scale(BNT):treatmentA                         0.255  0.80056
# scale(BNT):treatmentE                        -2.127  0.04223 *
# scale(NFC):treatmentA                        -0.944  0.35284
# scale(NFC):treatmentE                        -1.682  0.10368
# scale(FI):treatmentA                         -0.304  0.76332
# scale(FI):treatmentE                          2.239  0.03304 *
# scale(lottery_favour):scale(WTP):treatmentA   0.479  0.63227
# scale(lottery_favour):scale(WTP):treatmentE  -5.682 1.38e-08 ***
# scale(SNR):scale(x0):treatmentA              -1.369  0.18163
# scale(SNR):scale(x0):treatmentE              -1.086  0.28638
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Without the additional interaction:

# %%
# All subjects (without psychometrics)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0)):treatment + (1|subject), data1H))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7196.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4442 -1.0511  0.3643  0.7771  3.1070
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.009171 0.09577
#  Residual             0.197044 0.44390
# Number of obs: 5826, groups:  subject, 28
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.308e-01  1.959e-02  2.305e+01
# scale(lottery_favour):treatmentA             1.979e-01  8.669e-03  5.670e+03
# scale(lottery_favour):treatmentE             2.281e-01  1.424e-02  5.528e+03
# scale(WTP):treatmentA                        1.201e-02  9.059e-03  5.701e+03
# scale(WTP):treatmentE                        2.216e-02  1.245e-02  5.797e+03
# scale(SNR):treatmentA                        2.485e-02  2.562e-02  2.191e+01
# scale(SNR):treatmentE                        1.040e-01  4.576e-02  2.210e+01
# scale(x0):treatmentA                         8.591e-02  2.464e-02  2.189e+01
# scale(x0):treatmentE                         8.611e-02  5.208e-02  2.199e+01
# scale(lottery_favour):scale(WTP):treatmentA -4.852e-02  7.457e-03  5.540e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.195e-02  1.022e-02  5.168e+03
#                                             t value Pr(>|t|)
# (Intercept)                                  32.194  < 2e-16 ***
# scale(lottery_favour):treatmentA             22.831  < 2e-16 ***
# scale(lottery_favour):treatmentE             16.011  < 2e-16 ***
# scale(WTP):treatmentA                         1.326   0.1848
# scale(WTP):treatmentE                         1.780   0.0752 .
# scale(SNR):treatmentA                         0.970   0.3428
# scale(SNR):treatmentE                         2.274   0.0330 *
# scale(x0):treatmentA                          3.487   0.0021 **
# scale(x0):treatmentE                          1.653   0.1124
# scale(lottery_favour):scale(WTP):treatmentA  -6.507 8.32e-11 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.041 2.16e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E s(SNR):A s(SNR):E s(0):A
# scl(ltt_):A   0.023
# scl(ltt_):E  -0.002  0.000
# scl(WTP):tA   0.054 -0.349  0.000
# scl(WTP):tE  -0.002  0.000 -0.316  0.000
# scl(SNR):tA  -0.078  0.020  0.000  0.021    0.000
# scl(SNR):tE   0.158  0.004  0.015  0.009    0.008   -0.012
# scl(x0):trA   0.058  0.014  0.000  0.013    0.000   -0.533    0.009
# scl(x0):trE  -0.088 -0.002  0.034 -0.005    0.021    0.007   -0.442   -0.005
# s(_):(WTP):A -0.136 -0.008  0.000 -0.264    0.000   -0.019   -0.022   -0.001
# s(_):(WTP):E -0.064 -0.001 -0.371 -0.004   -0.245    0.005    0.050   -0.004
#              s(0):E s(_):(WTP):A
# scl(ltt_):A
# scl(ltt_):E
# scl(WTP):tA
# scl(WTP):tE
# scl(SNR):tA
# scl(SNR):tE
# scl(x0):trA
# scl(x0):trE
# s(_):(WTP):A  0.012
# s(_):(WTP):E -0.022  0.009
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 10711.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1849 -0.8539 -0.2692  0.9283  3.1368
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00569  0.07543
#  Residual             0.18529  0.43045
# Number of obs: 9161, groups:  subject, 44
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.987e-01  1.257e-02  4.070e+01
# scale(lottery_favour):treatmentA             1.654e-01  8.412e-03  8.807e+03
# scale(lottery_favour):treatmentE             2.365e-01  7.539e-03  8.479e+03
# scale(WTP):treatmentA                       -2.404e-02  9.422e-03  7.923e+03
# scale(WTP):treatmentE                       -4.941e-02  7.059e-03  8.964e+03
# scale(SNR):treatmentA                        6.446e-03  2.047e-02  3.843e+01
# scale(SNR):treatmentE                        5.628e-02  1.560e-02  3.789e+01
# scale(x0):treatmentA                         1.177e-01  1.622e-02  3.821e+01
# scale(x0):treatmentE                         1.325e-01  1.915e-02  3.776e+01
# scale(lottery_favour):scale(WTP):treatmentA  3.308e-03  7.193e-03  5.028e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.303e-02  6.080e-03  7.671e+03
#                                             t value Pr(>|t|)
# (Intercept)                                  31.723  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.662  < 2e-16 ***
# scale(lottery_favour):treatmentE             31.365  < 2e-16 ***
# scale(WTP):treatmentA                        -2.551  0.01076 *
# scale(WTP):treatmentE                        -7.000 2.75e-12 ***
# scale(SNR):treatmentA                         0.315  0.75456
# scale(SNR):treatmentE                         3.608  0.00089 ***
# scale(x0):treatmentA                          7.257 1.07e-08 ***
# scale(x0):treatmentE                          6.919 3.28e-08 ***
# scale(lottery_favour):scale(WTP):treatmentA   0.460  0.64560
# scale(lottery_favour):scale(WTP):treatmentE  -5.433 5.72e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E s(SNR):A s(SNR):E s(0):A
# scl(ltt_):A   0.030
# scl(ltt_):E   0.005  0.000
# scl(WTP):tA   0.070 -0.374  0.000
# scl(WTP):tE   0.019  0.001 -0.276  0.001
# scl(SNR):tA  -0.028 -0.016  0.000 -0.041   -0.001
# scl(SNR):tE  -0.004  0.000 -0.011  0.000   -0.015    0.000
# scl(x0):trA   0.081 -0.018  0.000 -0.008    0.002   -0.226    0.000
# scl(x0):trE  -0.095 -0.003  0.001 -0.007   -0.002    0.003   -0.023   -0.008
# s(_):(WTP):A -0.139  0.031 -0.001 -0.271   -0.003    0.091    0.001   -0.033
# s(_):(WTP):E -0.118 -0.004 -0.304 -0.008   -0.330    0.003    0.057   -0.010
#              s(0):E s(_):(WTP):A
# scl(ltt_):A
# scl(ltt_):E
# scl(WTP):tA
# scl(WTP):tE
# scl(SNR):tA
# scl(SNR):tE
# scl(x0):trA
# scl(x0):trE
# s(_):(WTP):A  0.013
# s(_):(WTP):E  0.007  0.016

# %%
# All subjects (with psychometrics)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(SNR) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7225.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4490 -1.0508  0.3641  0.7768  3.1076
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007758 0.08808
#  Residual             0.197033 0.44388
# Number of obs: 5826, groups:  subject, 28
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.417e-01  2.047e-02  1.535e+01
# scale(lottery_favour):treatmentA             1.997e-01  8.710e-03  5.798e+03
# scale(lottery_favour):treatmentE             2.311e-01  1.432e-02  5.745e+03
# scale(WTP):treatmentA                        1.393e-02  9.098e-03  5.801e+03
# scale(WTP):treatmentE                        2.385e-02  1.248e-02  5.806e+03
# scale(SNR):treatmentA                        3.018e-02  2.440e-02  1.470e+01
# scale(SNR):treatmentE                        1.552e-01  5.969e-02  1.520e+01
# scale(x0):treatmentA                         9.669e-02  2.662e-02  1.483e+01
# scale(x0):treatmentE                         7.856e-02  5.377e-02  1.465e+01
# scale(reflection):treatmentA                 1.486e-03  2.640e-02  1.461e+01
# scale(reflection):treatmentE                -5.527e-02  4.087e-02  1.551e+01
# scale(BNT):treatmentA                        3.583e-04  2.877e-02  1.479e+01
# scale(BNT):treatmentE                       -4.270e-02  4.612e-02  1.473e+01
# scale(NFC):treatmentA                        5.370e-02  2.407e-02  1.540e+01
# scale(NFC):treatmentE                        7.160e-02  4.365e-02  1.508e+01
# scale(FI):treatmentA                        -1.048e-02  2.197e-02  1.471e+01
# scale(FI):treatmentE                         7.121e-02  5.818e-02  1.528e+01
# scale(lottery_favour):scale(WTP):treatmentA -4.985e-02  7.479e-03  5.621e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.331e-02  1.027e-02  5.394e+03
#                                             t value Pr(>|t|)
# (Intercept)                                  31.346 2.45e-15 ***
# scale(lottery_favour):treatmentA             22.930  < 2e-16 ***
# scale(lottery_favour):treatmentE             16.140  < 2e-16 ***
# scale(WTP):treatmentA                         1.531   0.1258
# scale(WTP):treatmentE                         1.911   0.0560 .
# scale(SNR):treatmentA                         1.237   0.2356
# scale(SNR):treatmentE                         2.600   0.0199 *
# scale(x0):treatmentA                          3.632   0.0025 **
# scale(x0):treatmentE                          1.461   0.1651
# scale(reflection):treatmentA                  0.056   0.9559
# scale(reflection):treatmentE                 -1.352   0.1957
# scale(BNT):treatmentA                         0.012   0.9902
# scale(BNT):treatmentE                        -0.926   0.3695
# scale(NFC):treatmentA                         2.231   0.0409 *
# scale(NFC):treatmentE                         1.640   0.1216
# scale(FI):treatmentA                         -0.477   0.6404
# scale(FI):treatmentE                          1.224   0.2395
# scale(lottery_favour):scale(WTP):treatmentA  -6.665 2.91e-11 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.140 1.06e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(SNR) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 10743.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.1968 -0.8516 -0.2644  0.9271  3.1273
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004615 0.06793
#  Residual             0.185288 0.43045
# Number of obs: 9161, groups:  subject, 44
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.995e-01  1.253e-02  3.248e+01
# scale(lottery_favour):treatmentA             1.656e-01  8.413e-03  8.688e+03
# scale(lottery_favour):treatmentE             2.374e-01  7.562e-03  8.673e+03
# scale(WTP):treatmentA                       -2.416e-02  9.415e-03  7.447e+03
# scale(WTP):treatmentE                       -4.863e-02  7.072e-03  9.029e+03
# scale(SNR):treatmentA                       -1.003e-02  2.378e-02  3.074e+01
# scale(SNR):treatmentE                        4.544e-02  1.632e-02  3.054e+01
# scale(x0):treatmentA                         1.215e-01  1.573e-02  3.040e+01
# scale(x0):treatmentE                         1.083e-01  2.111e-02  3.003e+01
# scale(reflection):treatmentA                 3.027e-02  3.061e-02  3.063e+01
# scale(reflection):treatmentE                 6.047e-02  1.945e-02  3.099e+01
# scale(BNT):treatmentA                        7.682e-03  3.060e-02  3.087e+01
# scale(BNT):treatmentE                       -4.030e-02  1.744e-02  3.005e+01
# scale(NFC):treatmentA                       -3.948e-02  3.215e-02  3.064e+01
# scale(NFC):treatmentE                       -1.724e-02  1.309e-02  3.009e+01
# scale(FI):treatmentA                         1.762e-04  1.991e-02  3.024e+01
# scale(FI):treatmentE                         3.813e-02  1.949e-02  3.043e+01
# scale(lottery_favour):scale(WTP):treatmentA  3.922e-03  7.185e-03  4.294e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.443e-02  6.098e-03  7.840e+03
#                                             t value Pr(>|t|)
# (Intercept)                                  31.881  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.677  < 2e-16 ***
# scale(lottery_favour):treatmentE             31.399  < 2e-16 ***
# scale(WTP):treatmentA                        -2.566  0.01030 *
# scale(WTP):treatmentE                        -6.876 6.54e-12 ***
# scale(SNR):treatmentA                        -0.422  0.67598
# scale(SNR):treatmentE                         2.785  0.00912 **
# scale(x0):treatmentA                          7.721 1.19e-08 ***
# scale(x0):treatmentE                          5.129 1.61e-05 ***
# scale(reflection):treatmentA                  0.989  0.33048
# scale(reflection):treatmentE                  3.109  0.00401 **
# scale(BNT):treatmentA                         0.251  0.80347
# scale(BNT):treatmentE                        -2.310  0.02791 *
# scale(NFC):treatmentA                        -1.228  0.22887
# scale(NFC):treatmentE                        -1.317  0.19776
# scale(FI):treatmentA                          0.009  0.99300
# scale(FI):treatmentE                          1.956  0.05972 .
# scale(lottery_favour):scale(WTP):treatmentA   0.546  0.58514
# scale(lottery_favour):scale(WTP):treatmentE  -5.646 1.70e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
