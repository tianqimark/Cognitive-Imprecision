# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)

# %% [markdown]
# # This analysis is for the version AM_n001_10s_B1

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1 Dataset_AU/trialsAUM_10s_B1.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# create another dataset in wh subjects with error_choice > 5 are rejected
data2 <- subset(data1, error_choice <= 5)

# # split the dataset by treatment
# data1_A <- subset(data1, treatment == 'A')
# data1_E <- subset(data1, treatment == 'E')

# data2_A <- subset(data2, treatment == 'A')
# data2_E <- subset(data2, treatment == 'E')

# %% [markdown]
# ## 1 Predicting choice with RT and value difference alone

# %%
summary(lmer(slc_lot ~ (lottery_favour + RT):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (lottery_favour + RT):treatment + (1|subject), data2))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (lottery_favour + RT):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18141.5
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57785 -0.90411 -0.04839  0.87875  3.07439
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.03071  0.1752
#  Residual             0.19258  0.4388
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                            Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)               4.382e-01  2.174e-02 8.165e+01  20.155   <2e-16 ***
# lottery_favour:treatmentA 3.685e-02  1.169e-03 1.493e+04  31.509   <2e-16 ***
# lottery_favour:treatmentE 4.054e-02  1.204e-03 1.495e+04  33.667   <2e-16 ***
# RT:treatmentA             8.104e-03  3.329e-03 1.217e+04   2.434   0.0149 *
# RT:treatmentE             7.219e-04  3.267e-03 1.162e+04   0.221   0.8251
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ltt_:A ltt_:E RT:trA
# lttry_fvr:A  0.003
# lttry_fvr:E -0.028  0.000
# RT:tretmntA -0.185  0.004  0.005
# RT:tretmntE -0.193 -0.001 -0.055  0.036
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (lottery_favour + RT):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11478.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8267 -0.8445 -0.1079  0.8620  3.4767
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.03399  0.1844
#  Residual             0.17225  0.4150
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                            Estimate Std. Error        df t value Pr(>|t|)
# (Intercept)               3.860e-01  2.724e-02 5.544e+01  14.172  < 2e-16 ***
# lottery_favour:treatmentA 4.603e-02  1.379e-03 1.042e+04  33.387  < 2e-16 ***
# lottery_favour:treatmentE 4.807e-02  1.307e-03 1.041e+04  36.781  < 2e-16 ***
# RT:treatmentA             1.719e-02  3.925e-03 9.067e+03   4.378 1.21e-05 ***
# RT:treatmentE             4.975e-03  3.550e-03 8.762e+03   1.401    0.161
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) ltt_:A ltt_:E RT:trA
# lttry_fvr:A  0.016
# lttry_fvr:E -0.017  0.000
# RT:tretmntA -0.162 -0.036  0.003
# RT:tretmntE -0.189 -0.003 -0.073  0.031

# %% [markdown]
# ## 2 Predicting choice with the full set of DDM paramerters (noise level, drift rate,  initial bias x0)

# %% [markdown]
# ### Henceforward all continuous variables are scaled due to the inclusion of interactive terms and to avoid the error "Model failed to converge with max|grad|".
# Interactive effects between the "drift rate and noise level" are included.

# %%
# With interaction between the drift rate and noise
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18080
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57252 -0.90516 -0.04315  0.87826  3.07029
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00708  0.08414
#  Residual             0.19259  0.43885
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.740e-01  1.081e-02  6.227e+01  43.843
# scale(lottery_favour):treatmentA  1.769e-01  5.629e-03  1.295e+04  31.423
# scale(lottery_favour):treatmentE  1.949e-01  5.798e-03  1.323e+04  33.612
# scale(RT):treatmentA              1.202e-02  5.640e-03  1.497e+04   2.132
# scale(RT):treatmentE              2.525e-03  5.541e-03  1.495e+04   0.456
# scale(noise):treatmentA          -1.989e-02  1.466e-02  6.348e+01  -1.356
# scale(noise):treatmentE          -4.077e-02  1.845e-02  6.417e+01  -2.210
# scale(d):treatmentA               1.141e-02  1.611e-02  6.203e+01   0.708
# scale(d):treatmentE               7.146e-02  1.624e-02  6.179e+01   4.399
# scale(x0):treatmentA              1.474e-01  1.441e-02  6.197e+01  10.225
# scale(x0):treatmentE              1.494e-01  1.778e-02  6.168e+01   8.401
# scale(noise):scale(d):treatmentA  2.139e-03  1.404e-02  6.208e+01   0.152
# scale(noise):scale(d):treatmentE -2.916e-02  1.753e-02  6.175e+01  -1.663
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA               0.0330 *
# scale(RT):treatmentE               0.6486
# scale(noise):treatmentA            0.1798
# scale(noise):treatmentE            0.0307 *
# scale(d):treatmentA                0.4817
# scale(d):treatmentE              4.37e-05 ***
# scale(x0):treatmentA             6.30e-15 ***
# scale(x0):treatmentE             8.31e-12 ***
# scale(noise):scale(d):treatmentA   0.8794
# scale(noise):scale(d):treatmentE   0.1013
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11436.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8043 -0.8469 -0.1106  0.8589  3.4623
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006696 0.08183
#  Residual             0.172261 0.41504
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.396e-01  1.336e-02  4.019e+01  32.901
# scale(lottery_favour):treatmentA  2.205e-01  6.624e-03  9.681e+03  33.283
# scale(lottery_favour):treatmentE  2.305e-01  6.261e-03  9.124e+03  36.817
# scale(RT):treatmentA              2.815e-02  6.567e-03  1.040e+04   4.287
# scale(RT):treatmentE              8.152e-03  5.935e-03  1.039e+04   1.374
# scale(noise):treatmentA          -9.214e-03  2.017e-02  4.046e+01  -0.457
# scale(noise):treatmentE          -5.974e-02  1.973e-02  4.112e+01  -3.028
# scale(d):treatmentA               2.565e-02  2.574e-02  4.003e+01   0.996
# scale(d):treatmentE               7.437e-02  1.921e-02  4.011e+01   3.872
# scale(x0):treatmentA              1.326e-01  2.077e-02  4.004e+01   6.384
# scale(x0):treatmentE              1.756e-01  2.181e-02  4.025e+01   8.053
# scale(noise):scale(d):treatmentA -1.290e-03  2.142e-02  4.052e+01  -0.060
# scale(noise):scale(d):treatmentE -2.817e-02  1.518e-02  4.010e+01  -1.856
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA             1.83e-05 ***
# scale(RT):treatmentE             0.169611
# scale(noise):treatmentA          0.650248
# scale(noise):treatmentE          0.004240 **
# scale(d):treatmentA              0.325030
# scale(d):treatmentE              0.000389 ***
# scale(x0):treatmentA             1.36e-07 ***
# scale(x0):treatmentE             6.40e-10 ***
# scale(noise):scale(d):treatmentA 0.952273
# scale(noise):scale(d):treatmentE 0.070804 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## 3 Predicting choice with the full set of DDM paramerters and psychometric measurements
# Interactive effects between the "drift rate and noise level", "reflection and BNT" and "reflection and noise level" are included.

# %%
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 25 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0) + scale(reflection) * scale(BNT) + scale(NFC) +
#     scale(FI) + scale(reflection):scale(noise)):treatment + (1 |      subject)
#    Data: data1
#
# REML criterion at convergence: 18140.1
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.58272 -0.90680 -0.04333  0.87896  3.07724
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006794 0.08242
#  Residual             0.192585 0.43884
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                             Estimate Std. Error         df
# (Intercept)                                4.575e-01  1.414e-02  5.013e+01
# scale(lottery_favour):treatmentA           1.771e-01  5.634e-03  1.268e+04
# scale(lottery_favour):treatmentE           1.951e-01  5.814e-03  1.356e+04
# scale(RT):treatmentA                       1.208e-02  5.642e-03  1.495e+04
# scale(RT):treatmentE                       2.527e-03  5.543e-03  1.493e+04
# scale(noise):treatmentA                   -1.041e-02  1.814e-02  5.156e+01
# scale(noise):treatmentE                   -4.852e-02  2.100e-02  5.119e+01
# scale(d):treatmentA                        4.300e-03  1.875e-02  4.999e+01
# scale(d):treatmentE                        6.589e-02  1.784e-02  4.989e+01
# scale(x0):treatmentA                       1.574e-01  1.560e-02  5.004e+01
# scale(x0):treatmentE                       1.384e-01  2.013e-02  4.990e+01
# scale(reflection):treatmentA              -1.841e-02  2.324e-02  4.988e+01
# scale(reflection):treatmentE               2.440e-02  2.006e-02  4.998e+01
# scale(BNT):treatmentA                      1.092e-02  2.335e-02  5.016e+01
# scale(BNT):treatmentE                     -3.275e-02  1.819e-02  4.999e+01
# scale(NFC):treatmentA                      1.495e-02  2.121e-02  4.996e+01
# scale(NFC):treatmentE                     -1.101e-02  1.482e-02  5.028e+01
# scale(FI):treatmentA                      -1.592e-02  1.818e-02  4.992e+01
# scale(FI):treatmentE                       3.007e-02  1.836e-02  5.010e+01
# scale(noise):scale(d):treatmentA          -1.793e-03  1.867e-02  4.990e+01
# scale(noise):scale(d):treatmentE          -1.030e-02  1.975e-02  5.011e+01
# scale(reflection):scale(BNT):treatmentA    4.077e-02  2.133e-02  5.004e+01
# scale(reflection):scale(BNT):treatmentE   -1.970e-02  1.534e-02  5.000e+01
# scale(noise):scale(reflection):treatmentA  2.140e-02  1.908e-02  5.033e+01
# scale(noise):scale(reflection):treatmentE -3.011e-02  2.652e-02  5.022e+01
#                                           t value Pr(>|t|)
# (Intercept)                                32.347  < 2e-16 ***
# scale(lottery_favour):treatmentA           31.432  < 2e-16 ***
# scale(lottery_favour):treatmentE           33.548  < 2e-16 ***
# scale(RT):treatmentA                        2.141 0.032299 *
# scale(RT):treatmentE                        0.456 0.648414
# scale(noise):treatmentA                    -0.574 0.568627
# scale(noise):treatmentE                    -2.310 0.024961 *
# scale(d):treatmentA                         0.229 0.819564
# scale(d):treatmentE                         3.694 0.000548 ***
# scale(x0):treatmentA                       10.087 1.19e-13 ***
# scale(x0):treatmentE                        6.876 9.49e-09 ***
# scale(reflection):treatmentA               -0.792 0.432052
# scale(reflection):treatmentE                1.216 0.229543
# scale(BNT):treatmentA                       0.468 0.641955
# scale(BNT):treatmentE                      -1.800 0.077905 .
# scale(NFC):treatmentA                       0.705 0.484055
# scale(NFC):treatmentE                      -0.743 0.461120
# scale(FI):treatmentA                       -0.875 0.385520
# scale(FI):treatmentE                        1.637 0.107821
# scale(noise):scale(d):treatmentA           -0.096 0.923879
# scale(noise):scale(d):treatmentE           -0.522 0.604281
# scale(reflection):scale(BNT):treatmentA     1.912 0.061637 .
# scale(reflection):scale(BNT):treatmentE    -1.284 0.205212
# scale(noise):scale(reflection):treatmentA   1.121 0.267472
# scale(noise):scale(reflection):treatmentE  -1.135 0.261558
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 25 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0) + scale(reflection) * scale(BNT) + scale(NFC) +
#     scale(FI) + scale(reflection):scale(noise)):treatment + (1 |      subject)
#    Data: data2
#
# REML criterion at convergence: 11480.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8042 -0.8445 -0.1028  0.8570  3.4808
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004191 0.06474
#  Residual             0.172260 0.41504
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                             Estimate Std. Error         df
# (Intercept)                                4.335e-01  1.573e-02  2.826e+01
# scale(lottery_favour):treatmentA           2.214e-01  6.632e-03  9.541e+03
# scale(lottery_favour):treatmentE           2.308e-01  6.266e-03  8.747e+03
# scale(RT):treatmentA                       2.823e-02  6.565e-03  1.040e+04
# scale(RT):treatmentE                       7.950e-03  5.937e-03  1.035e+04
# scale(noise):treatmentA                    1.828e-02  2.672e-02  2.830e+01
# scale(noise):treatmentE                   -5.920e-02  1.739e-02  2.897e+01
# scale(d):treatmentA                       -1.278e-02  2.458e-02  2.819e+01
# scale(d):treatmentE                        4.445e-02  1.821e-02  2.840e+01
# scale(x0):treatmentA                       1.627e-01  2.025e-02  2.832e+01
# scale(x0):treatmentE                       1.308e-01  2.125e-02  2.832e+01
# scale(reflection):treatmentA               4.212e-02  2.851e-02  2.839e+01
# scale(reflection):treatmentE               4.906e-02  2.158e-02  2.832e+01
# scale(BNT):treatmentA                     -2.183e-03  2.713e-02  2.833e+01
# scale(BNT):treatmentE                     -9.371e-03  2.042e-02  2.838e+01
# scale(NFC):treatmentA                     -2.294e-02  2.461e-02  2.823e+01
# scale(NFC):treatmentE                     -3.420e-02  1.456e-02  2.844e+01
# scale(FI):treatmentA                       4.855e-02  2.070e-02  2.873e+01
# scale(FI):treatmentE                       7.557e-02  2.052e-02  2.867e+01
# scale(noise):scale(d):treatmentA           1.885e-02  2.046e-02  2.891e+01
# scale(noise):scale(d):treatmentE          -2.189e-03  1.516e-02  2.848e+01
# scale(reflection):scale(BNT):treatmentA    1.263e-02  2.167e-02  2.823e+01
# scale(reflection):scale(BNT):treatmentE   -5.416e-02  2.283e-02  2.829e+01
# scale(noise):scale(reflection):treatmentA  1.144e-03  2.137e-02  2.814e+01
# scale(noise):scale(reflection):treatmentE -2.501e-02  2.634e-02  2.875e+01
#                                           t value Pr(>|t|)
# (Intercept)                                27.561  < 2e-16 ***
# scale(lottery_favour):treatmentA           33.384  < 2e-16 ***
# scale(lottery_favour):treatmentE           36.824  < 2e-16 ***
# scale(RT):treatmentA                        4.301 1.72e-05 ***
# scale(RT):treatmentE                        1.339 0.180527
# scale(noise):treatmentA                     0.684 0.499375
# scale(noise):treatmentE                    -3.404 0.001963 **
# scale(d):treatmentA                        -0.520 0.607228
# scale(d):treatmentE                         2.441 0.021114 *
# scale(x0):treatmentA                        8.034 8.74e-09 ***
# scale(x0):treatmentE                        6.153 1.16e-06 ***
# scale(reflection):treatmentA                1.477 0.150633
# scale(reflection):treatmentE                2.274 0.030764 *
# scale(BNT):treatmentA                      -0.080 0.936416
# scale(BNT):treatmentE                      -0.459 0.649776
# scale(NFC):treatmentA                      -0.932 0.359213
# scale(NFC):treatmentE                      -2.349 0.025975 *
# scale(FI):treatmentA                        2.346 0.026101 *
# scale(FI):treatmentE                        3.682 0.000954 ***
# scale(noise):scale(d):treatmentA            0.921 0.364544
# scale(noise):scale(d):treatmentE           -0.144 0.886179
# scale(reflection):scale(BNT):treatmentA     0.583 0.564664
# scale(reflection):scale(BNT):treatmentE    -2.372 0.024717 *
# scale(noise):scale(reflection):treatmentA   0.054 0.957670
# scale(noise):scale(reflection):treatmentE  -0.949 0.350362
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Check VIF

func1 <- lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1)
func2 <- lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2)

vif(func1)
vif(func2)
# Out:
#                                          GVIF     Df GVIF^(1/(2*Df))
# scale(lottery_favour):treatment          1.020128 2  1.004994
# scale(RT):treatment                      1.046548 2  1.011439
# scale(noise):treatment                   2.798626 2  1.293410
# scale(d):treatment                       2.391544 2  1.243568
# scale(x0):treatment                      1.935309 2  1.179472
# scale(reflection):treatment              4.653429 2  1.468734
# scale(BNT):treatment                     3.835213 2  1.399418
# scale(NFC):treatment                     1.901736 2  1.174323
# scale(FI):treatment                      2.411046 2  1.246096
# scale(noise):scale(d):treatment          3.718642 2  1.388661
# scale(reflection):scale(BNT):treatment   3.579767 2  1.375510
# scale(noise):scale(reflection):treatment 3.105180 2  1.327461
#                                          GVIF     Df GVIF^(1/(2*Df))
# scale(lottery_favour):treatment          1.047651 2  1.011705
# scale(RT):treatment                      1.054725 2  1.013409
# scale(noise):treatment                   5.246590 2  1.513454
# scale(d):treatment                       4.680622 2  1.470875
# scale(x0):treatment                      4.014607 2  1.415503
# scale(reflection):treatment              9.033421 2  1.733657
# scale(BNT):treatment                     7.068407 2  1.630536
# scale(NFC):treatment                     2.718348 2  1.284033
# scale(FI):treatment                      4.397851 2  1.448139
# scale(noise):scale(d):treatment          3.529520 2  1.370657
# scale(reflection):scale(BNT):treatment   6.236560 2  1.580288
# scale(noise):scale(reflection):treatment 6.414297 2  1.591429

# %% [markdown]
# ## 4 Predicting choice with the full set of DDM paramerters and psychometric measurements, except the reflection / BNT

# %%
# In this analysis, reflection is removed becuase it correlates with the noise level.
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18112
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57578 -0.90639 -0.04447  0.87745  3.07171
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007079 0.08414
#  Residual             0.192586 0.43885
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.702e-01  1.098e-02  5.600e+01  42.805
# scale(lottery_favour):treatmentA  1.770e-01  5.631e-03  1.279e+04  31.427
# scale(lottery_favour):treatmentE  1.946e-01  5.810e-03  1.356e+04  33.486
# scale(RT):treatmentA              1.200e-02  5.642e-03  1.496e+04   2.127
# scale(RT):treatmentE              2.643e-03  5.542e-03  1.494e+04   0.477
# scale(noise):treatmentA          -1.706e-02  1.594e-02  5.730e+01  -1.071
# scale(noise):treatmentE          -5.439e-02  2.005e-02  5.737e+01  -2.713
# scale(d):treatmentA               6.478e-03  1.786e-02  5.574e+01   0.363
# scale(d):treatmentE               7.536e-02  1.737e-02  5.556e+01   4.339
# scale(x0):treatmentA              1.496e-01  1.500e-02  5.576e+01   9.977
# scale(x0):treatmentE              1.501e-01  1.975e-02  5.562e+01   7.602
# scale(BNT):treatmentA             1.938e-02  2.022e-02  5.584e+01   0.959
# scale(BNT):treatmentE            -2.746e-02  1.642e-02  5.572e+01  -1.672
# scale(NFC):treatmentA             1.229e-02  2.100e-02  5.572e+01   0.585
# scale(NFC):treatmentE            -8.107e-03  1.505e-02  5.606e+01  -0.539
# scale(FI):treatmentA              1.198e-04  1.625e-02  5.569e+01   0.007
# scale(FI):treatmentE              1.380e-02  1.716e-02  5.568e+01   0.804
# scale(noise):scale(d):treatmentA  5.171e-03  1.768e-02  5.573e+01   0.293
# scale(noise):scale(d):treatmentE -2.077e-02  1.854e-02  5.573e+01  -1.120
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA              0.03345 *
# scale(RT):treatmentE              0.63340
# scale(noise):treatmentA           0.28883
# scale(noise):treatmentE           0.00879 **
# scale(d):treatmentA               0.71824
# scale(d):treatmentE              6.10e-05 ***
# scale(x0):treatmentA             5.21e-14 ***
# scale(x0):treatmentE             3.64e-10 ***
# scale(BNT):treatmentA             0.34184
# scale(BNT):treatmentE             0.10008
# scale(NFC):treatmentA             0.56061
# scale(NFC):treatmentE             0.59223
# scale(FI):treatmentA              0.99414
# scale(FI):treatmentE              0.42484
# scale(noise):scale(d):treatmentA  0.77093
# scale(noise):scale(d):treatmentE  0.26757
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0) + scale(BNT) + scale(NFC) + scale(FI)):treatment +
#     (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11462.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8030 -0.8478 -0.1065  0.8588  3.4816
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005997 0.07744
#  Residual             0.172261 0.41504
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.289e-01  1.359e-02  3.415e+01  31.560
# scale(lottery_favour):treatmentA  2.214e-01  6.639e-03  9.878e+03  33.347
# scale(lottery_favour):treatmentE  2.301e-01  6.271e-03  9.213e+03  36.690
# scale(RT):treatmentA              2.818e-02  6.567e-03  1.040e+04   4.291
# scale(RT):treatmentE              8.174e-03  5.936e-03  1.038e+04   1.377
# scale(noise):treatmentA           8.092e-04  2.290e-02  3.426e+01   0.035
# scale(noise):treatmentE          -7.252e-02  1.981e-02  3.481e+01  -3.661
# scale(d):treatmentA               5.757e-03  2.626e-02  3.396e+01   0.219
# scale(d):treatmentE               6.970e-02  1.971e-02  3.403e+01   3.536
# scale(x0):treatmentA              1.517e-01  2.226e-02  3.403e+01   6.817
# scale(x0):treatmentE              1.604e-01  2.296e-02  3.419e+01   6.987
# scale(BNT):treatmentA             2.861e-02  2.417e-02  3.421e+01   1.184
# scale(BNT):treatmentE            -1.480e-02  1.744e-02  3.423e+01  -0.849
# scale(NFC):treatmentA            -9.405e-03  2.672e-02  3.398e+01  -0.352
# scale(NFC):treatmentE            -1.957e-02  1.607e-02  3.428e+01  -1.218
# scale(FI):treatmentA              4.519e-02  2.019e-02  3.446e+01   2.239
# scale(FI):treatmentE              3.250e-02  1.932e-02  3.411e+01   1.682
# scale(noise):scale(d):treatmentA  1.316e-02  2.154e-02  3.468e+01   0.611
# scale(noise):scale(d):treatmentE -1.737e-02  1.527e-02  3.410e+01  -1.137
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA             1.79e-05 ***
# scale(RT):treatmentE             0.168550
# scale(noise):treatmentA          0.972011
# scale(noise):treatmentE          0.000826 ***
# scale(d):treatmentA              0.827763
# scale(d):treatmentE              0.001194 **
# scale(x0):treatmentA             7.60e-08 ***
# scale(x0):treatmentE             4.50e-08 ***
# scale(BNT):treatmentA            0.244767
# scale(BNT):treatmentE            0.402054
# scale(NFC):treatmentA            0.727052
# scale(NFC):treatmentE            0.231542
# scale(FI):treatmentA             0.031741 *
# scale(FI):treatmentE             0.101675
# scale(noise):scale(d):treatmentA 0.545323
# scale(noise):scale(d):treatmentE 0.263279
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# In this analysis, BNT is removed becuase it correlates with the reflection.
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(reflection) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise)*scale(d) + scale(x0) + scale(reflection) + scale(NFC) + scale(FI) + scale(reflection):scale(noise)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0) + scale(reflection) + scale(NFC) + scale(FI) +
#     scale(reflection):scale(noise)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18126.3
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57665 -0.90712 -0.04179  0.87711  3.07598
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007794 0.08828
#  Residual             0.192584 0.43884
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                             Estimate Std. Error         df
# (Intercept)                                4.729e-01  1.267e-02  5.444e+01
# scale(lottery_favour):treatmentA           1.772e-01  5.641e-03  1.323e+04
# scale(lottery_favour):treatmentE           1.954e-01  5.815e-03  1.372e+04
# scale(RT):treatmentA                       1.192e-02  5.642e-03  1.496e+04
# scale(RT):treatmentE                       2.465e-03  5.545e-03  1.495e+04
# scale(noise):treatmentA                   -1.760e-02  1.881e-02  5.561e+01
# scale(noise):treatmentE                   -3.585e-02  2.183e-02  5.541e+01
# scale(d):treatmentA                        1.022e-02  1.956e-02  5.415e+01
# scale(d):treatmentE                        6.303e-02  1.867e-02  5.404e+01
# scale(x0):treatmentA                       1.484e-01  1.592e-02  5.417e+01
# scale(x0):treatmentE                       1.400e-01  2.040e-02  5.397e+01
# scale(reflection):treatmentA               9.291e-03  1.955e-02  5.408e+01
# scale(reflection):treatmentE               1.558e-02  2.061e-02  5.417e+01
# scale(NFC):treatmentA                      1.765e-02  2.179e-02  5.406e+01
# scale(NFC):treatmentE                      1.433e-03  1.480e-02  5.437e+01
# scale(FI):treatmentA                      -3.107e-03  1.696e-02  5.406e+01
# scale(FI):treatmentE                       2.156e-02  1.884e-02  5.419e+01
# scale(noise):scale(d):treatmentA           7.158e-04  1.877e-02  5.409e+01
# scale(noise):scale(d):treatmentE          -2.645e-02  2.003e-02  5.423e+01
# scale(noise):scale(reflection):treatmentA  1.916e-03  1.752e-02  5.450e+01
# scale(noise):scale(reflection):treatmentE -6.420e-04  2.631e-02  5.450e+01
#                                           t value Pr(>|t|)
# (Intercept)                                37.327  < 2e-16 ***
# scale(lottery_favour):treatmentA           31.405  < 2e-16 ***
# scale(lottery_favour):treatmentE           33.603  < 2e-16 ***
# scale(RT):treatmentA                        2.112  0.03469 *
# scale(RT):treatmentE                        0.445  0.65657
# scale(noise):treatmentA                    -0.935  0.35374
# scale(noise):treatmentE                    -1.643  0.10612
# scale(d):treatmentA                         0.523  0.60327
# scale(d):treatmentE                         3.376  0.00137 **
# scale(x0):treatmentA                        9.320 7.55e-13 ***
# scale(x0):treatmentE                        6.864 6.87e-09 ***
# scale(reflection):treatmentA                0.475  0.63646
# scale(reflection):treatmentE                0.756  0.45285
# scale(NFC):treatmentA                       0.810  0.42147
# scale(NFC):treatmentE                       0.097  0.92319
# scale(FI):treatmentA                       -0.183  0.85534
# scale(FI):treatmentE                        1.144  0.25746
# scale(noise):scale(d):treatmentA            0.038  0.96971
# scale(noise):scale(d):treatmentE           -1.321  0.19218
# scale(noise):scale(reflection):treatmentA   0.109  0.91330
# scale(noise):scale(reflection):treatmentE  -0.024  0.98062
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(noise) *
#     scale(d) + scale(x0) + scale(reflection) + scale(NFC) + scale(FI) +
#     scale(reflection):scale(noise)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11468.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7990 -0.8471 -0.1072  0.8579  3.4853
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005323 0.07296
#  Residual             0.172258 0.41504
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                             Estimate Std. Error         df
# (Intercept)                                4.301e-01  1.352e-02  3.247e+01
# scale(lottery_favour):treatmentA           2.218e-01  6.643e-03  9.941e+03
# scale(lottery_favour):treatmentE           2.309e-01  6.268e-03  9.040e+03
# scale(RT):treatmentA                       2.811e-02  6.566e-03  1.040e+04
# scale(RT):treatmentE                       7.973e-03  5.937e-03  1.037e+04
# scale(noise):treatmentA                    1.145e-02  2.723e-02  3.248e+01
# scale(noise):treatmentE                   -5.919e-02  1.895e-02  3.326e+01
# scale(d):treatmentA                       -1.100e-02  2.702e-02  3.235e+01
# scale(d):treatmentE                        5.543e-02  1.914e-02  3.244e+01
# scale(x0):treatmentA                       1.621e-01  2.175e-02  3.246e+01
# scale(x0):treatmentE                       1.459e-01  2.279e-02  3.249e+01
# scale(reflection):treatmentA               4.661e-02  2.439e-02  3.260e+01
# scale(reflection):treatmentE               4.256e-02  2.088e-02  3.269e+01
# scale(NFC):treatmentA                     -2.457e-02  2.672e-02  3.241e+01
# scale(NFC):treatmentE                     -1.702e-02  1.504e-02  3.273e+01
# scale(FI):treatmentA                       5.584e-02  2.029e-02  3.299e+01
# scale(FI):treatmentE                       5.145e-02  2.002e-02  3.265e+01
# scale(noise):scale(d):treatmentA           2.371e-02  2.217e-02  3.308e+01
# scale(noise):scale(d):treatmentE          -1.957e-02  1.571e-02  3.267e+01
# scale(noise):scale(reflection):treatmentA -8.223e-03  1.786e-02  3.230e+01
# scale(noise):scale(reflection):treatmentE  7.815e-03  2.521e-02  3.302e+01
#                                           t value Pr(>|t|)
# (Intercept)                                31.817  < 2e-16 ***
# scale(lottery_favour):treatmentA           33.383  < 2e-16 ***
# scale(lottery_favour):treatmentE           36.837  < 2e-16 ***
# scale(RT):treatmentA                        4.282 1.87e-05 ***
# scale(RT):treatmentE                        1.343  0.17930
# scale(noise):treatmentA                     0.420  0.67701
# scale(noise):treatmentE                    -3.124  0.00369 **
# scale(d):treatmentA                        -0.407  0.68658
# scale(d):treatmentE                         2.896  0.00672 **
# scale(x0):treatmentA                        7.453 1.60e-08 ***
# scale(x0):treatmentE                        6.402 3.18e-07 ***
# scale(reflection):treatmentA                1.911  0.06488 .
# scale(reflection):treatmentE                2.038  0.04966 *
# scale(NFC):treatmentA                      -0.920  0.36456
# scale(NFC):treatmentE                      -1.132  0.26590
# scale(FI):treatmentA                        2.752  0.00955 **
# scale(FI):treatmentE                        2.569  0.01494 *
# scale(noise):scale(d):treatmentA            1.070  0.29252
# scale(noise):scale(d):treatmentE           -1.246  0.22155
# scale(noise):scale(reflection):treatmentA  -0.460  0.64840
# scale(noise):scale(reflection):treatmentE   0.310  0.75847
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## 5 Predicting choice using psychometrics (without DDM parameters)

# %%
# Full set of psychometric variables
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection)*scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18172
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57391 -0.90529 -0.04571  0.87660  3.07782
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02985  0.1728
#  Residual             0.19258  0.4388
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              4.876e-01  2.489e-02  6.096e+01
# scale(lottery_favour):treatmentA         1.790e-01  5.690e-03  1.491e+04
# scale(lottery_favour):treatmentE         1.976e-01  5.862e-03  1.496e+04
# scale(RT):treatmentA                     1.184e-02  5.638e-03  1.496e+04
# scale(RT):treatmentE                     2.649e-03  5.545e-03  1.497e+04
# scale(reflection):treatmentA             6.298e-04  3.997e-02  6.094e+01
# scale(reflection):treatmentE             5.905e-02  3.536e-02  6.099e+01
# scale(BNT):treatmentA                    2.964e-02  4.380e-02  6.100e+01
# scale(BNT):treatmentE                    1.308e-02  3.302e-02  6.091e+01
# scale(NFC):treatmentA                   -3.829e-03  3.713e-02  6.092e+01
# scale(NFC):treatmentE                    6.100e-03  2.646e-02  6.096e+01
# scale(FI):treatmentA                    -2.175e-02  3.138e-02  6.095e+01
# scale(FI):treatmentE                     9.292e-02  3.161e-02  6.092e+01
# scale(reflection):scale(BNT):treatmentA -1.760e-02  3.380e-02  6.097e+01
# scale(reflection):scale(BNT):treatmentE -4.632e-02  2.872e-02  6.096e+01
#                                         t value Pr(>|t|)
# (Intercept)                              19.593  < 2e-16 ***
# scale(lottery_favour):treatmentA         31.459  < 2e-16 ***
# scale(lottery_favour):treatmentE         33.718  < 2e-16 ***
# scale(RT):treatmentA                      2.099  0.03579 *
# scale(RT):treatmentE                      0.478  0.63281
# scale(reflection):treatmentA              0.016  0.98748
# scale(reflection):treatmentE              1.670  0.10011
# scale(BNT):treatmentA                     0.677  0.50107
# scale(BNT):treatmentE                     0.396  0.69345
# scale(NFC):treatmentA                    -0.103  0.91820
# scale(NFC):treatmentE                     0.231  0.81841
# scale(FI):treatmentA                     -0.693  0.49077
# scale(FI):treatmentE                      2.940  0.00463 **
# scale(reflection):scale(BNT):treatmentA  -0.521  0.60432
# scale(reflection):scale(BNT):treatmentE  -1.613  0.11197
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) *
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11498.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8188 -0.8440 -0.1053  0.8601  3.4741
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02838  0.1685
#  Residual             0.17225  0.4150
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              4.570e-01  3.563e-02  3.897e+01
# scale(lottery_favour):treatmentA         2.226e-01  6.674e-03  1.040e+04
# scale(lottery_favour):treatmentE         2.335e-01  6.331e-03  1.040e+04
# scale(RT):treatmentA                     2.733e-02  6.567e-03  1.040e+04
# scale(RT):treatmentE                     9.016e-03  5.938e-03  1.040e+04
# scale(reflection):treatmentA            -9.759e-03  5.281e-02  3.895e+01
# scale(reflection):treatmentE             9.497e-02  4.605e-02  3.899e+01
# scale(BNT):treatmentA                    4.263e-02  6.050e-02  3.896e+01
# scale(BNT):treatmentE                    1.924e-02  4.405e-02  3.896e+01
# scale(NFC):treatmentA                   -1.401e-02  4.603e-02  3.892e+01
# scale(NFC):treatmentE                   -2.575e-02  3.126e-02  3.893e+01
# scale(FI):treatmentA                    -1.371e-02  4.024e-02  3.898e+01
# scale(FI):treatmentE                     1.401e-01  3.628e-02  3.899e+01
# scale(reflection):scale(BNT):treatmentA -1.486e-02  4.002e-02  3.894e+01
# scale(reflection):scale(BNT):treatmentE -9.173e-02  4.543e-02  3.895e+01
#                                         t value Pr(>|t|)
# (Intercept)                              12.827 1.45e-15 ***
# scale(lottery_favour):treatmentA         33.349  < 2e-16 ***
# scale(lottery_favour):treatmentE         36.879  < 2e-16 ***
# scale(RT):treatmentA                      4.161 3.19e-05 ***
# scale(RT):treatmentE                      1.518 0.128998
# scale(reflection):treatmentA             -0.185 0.854334
# scale(reflection):treatmentE              2.062 0.045886 *
# scale(BNT):treatmentA                     0.705 0.485196
# scale(BNT):treatmentE                     0.437 0.664671
# scale(NFC):treatmentA                    -0.304 0.762388
# scale(NFC):treatmentE                    -0.824 0.415045
# scale(FI):treatmentA                     -0.341 0.735102
# scale(FI):treatmentE                      3.861 0.000415 ***
# scale(reflection):scale(BNT):treatmentA  -0.371 0.712385
# scale(reflection):scale(BNT):treatmentE  -2.019 0.050406 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Predicting choice using psychometrics but drop BNT
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18155.3
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57340 -0.90554 -0.04591  0.87712  3.07852
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02943  0.1715
#  Residual             0.19258  0.4388
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.736e-01  2.069e-02  6.502e+01  22.894
# scale(lottery_favour):treatmentA  1.790e-01  5.688e-03  1.489e+04  31.478
# scale(lottery_favour):treatmentE  1.975e-01  5.860e-03  1.496e+04  33.705
# scale(RT):treatmentA              1.177e-02  5.637e-03  1.496e+04   2.088
# scale(RT):treatmentE              2.549e-03  5.544e-03  1.497e+04   0.460
# scale(reflection):treatmentA      6.769e-03  2.869e-02  6.490e+01   0.236
# scale(reflection):treatmentE      5.611e-02  3.131e-02  6.515e+01   1.792
# scale(NFC):treatmentA            -8.627e-04  3.593e-02  6.494e+01  -0.024
# scale(NFC):treatmentE             9.691e-03  2.550e-02  6.498e+01   0.380
# scale(FI):treatmentA             -2.932e-02  2.861e-02  6.494e+01  -1.025
# scale(FI):treatmentE              8.483e-02  3.092e-02  6.493e+01   2.744
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA              0.03685 *
# scale(RT):treatmentE              0.64566
# scale(reflection):treatmentA      0.81425
# scale(reflection):treatmentE      0.07777 .
# scale(NFC):treatmentA             0.98092
# scale(NFC):treatmentE             0.70517
# scale(FI):treatmentA              0.30929
# scale(FI):treatmentE              0.00785 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) s(_):A s(_):E s(RT):A s(RT):E sc():A sc():E s(NFC):A
# scl(ltt_):A  0.020
# scl(ltt_):E -0.021  0.000
# scl(RT):trA  0.006  0.003  0.000
# scl(RT):trE -0.006  0.000 -0.050  0.000
# scl(rflc):A  0.049 -0.009 -0.001 -0.013   0.000
# scl(rflc):E -0.056 -0.001  0.022  0.000  -0.033  -0.003
# scl(NFC):tA -0.068  0.022  0.001 -0.006   0.000  -0.142  0.004
# scl(NFC):tE  0.048  0.001  0.025  0.000  -0.007   0.002 -0.089 -0.003
# scl(FI):trA -0.037 -0.003  0.001  0.011   0.000   0.094  0.002  0.094
# scl(FI):trE  0.024  0.000  0.011  0.000   0.003   0.001  0.256 -0.002
#             s(NFC):E s(FI):A
# scl(ltt_):A
# scl(ltt_):E
# scl(RT):trA
# scl(RT):trE
# scl(rflc):A
# scl(rflc):E
# scl(NFC):tA
# scl(NFC):tE
# scl(FI):trA -0.002
# scl(FI):trE  0.012   -0.001
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(reflection) +
#     scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11486
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8181 -0.8441 -0.1054  0.8605  3.4764
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02945  0.1716
#  Residual             0.17225  0.4150
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.328e-01  2.486e-02  4.302e+01  17.410
# scale(lottery_favour):treatmentA  2.225e-01  6.674e-03  1.041e+04  33.342
# scale(lottery_favour):treatmentE  2.332e-01  6.329e-03  1.041e+04  36.852
# scale(RT):treatmentA              2.730e-02  6.567e-03  1.040e+04   4.157
# scale(RT):treatmentE              8.873e-03  5.937e-03  1.041e+04   1.494
# scale(reflection):treatmentA      8.424e-03  3.448e-02  4.298e+01   0.244
# scale(reflection):treatmentE      9.940e-02  3.978e-02  4.309e+01   2.499
# scale(NFC):treatmentA            -9.166e-03  4.580e-02  4.294e+01  -0.200
# scale(NFC):treatmentE            -4.783e-03  3.024e-02  4.297e+01  -0.158
# scale(FI):treatmentA             -2.075e-02  3.685e-02  4.303e+01  -0.563
# scale(FI):treatmentE              1.212e-01  3.551e-02  4.300e+01   3.411
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA             3.26e-05 ***
# scale(RT):treatmentE              0.13511
# scale(reflection):treatmentA      0.80814
# scale(reflection):treatmentE      0.01636 *
# scale(NFC):treatmentA             0.84232
# scale(NFC):treatmentE             0.87506
# scale(FI):treatmentA              0.57617
# scale(FI):treatmentE              0.00142 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) s(_):A s(_):E s(RT):A s(RT):E sc():A sc():E s(NFC):A
# scl(ltt_):A  0.020
# scl(ltt_):E -0.021  0.000
# scl(RT):trA  0.008 -0.038  0.000
# scl(RT):trE -0.008  0.000 -0.070  0.000
# scl(rflc):A  0.064  0.005 -0.001 -0.028  -0.001
# scl(rflc):E -0.078 -0.002  0.030 -0.001  -0.019  -0.005
# scl(NFC):tA -0.036  0.004  0.001  0.019   0.000  -0.277  0.003
# scl(NFC):tE  0.023  0.000  0.017  0.000  -0.006   0.001 -0.133 -0.001
# scl(FI):trA -0.056  0.031  0.001 -0.009   0.000   0.148  0.004 -0.040
# scl(FI):trE  0.032  0.001  0.021  0.000   0.007   0.002  0.313 -0.001
#             s(NFC):E s(FI):A
# scl(ltt_):A
# scl(ltt_):E
# scl(RT):trA
# scl(RT):trE
# scl(rflc):A
# scl(rflc):E
# scl(NFC):tA
# scl(NFC):tE
# scl(FI):trA -0.001
# scl(FI):trE -0.134   -0.002

# %%
# Predicting choice using psychometrics but drop reflection
summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))

summary(lmer(slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18157.6
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.57504 -0.90533 -0.04701  0.87649  3.07926
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.03052  0.1747
#  Residual             0.19258  0.4388
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.755e-01  2.113e-02  6.501e+01  22.500
# scale(lottery_favour):treatmentA  1.791e-01  5.689e-03  1.490e+04  31.477
# scale(lottery_favour):treatmentE  1.974e-01  5.861e-03  1.496e+04  33.685
# scale(RT):treatmentA              1.181e-02  5.637e-03  1.496e+04   2.095
# scale(RT):treatmentE              2.747e-03  5.544e-03  1.497e+04   0.495
# scale(BNT):treatmentA             2.050e-02  3.293e-02  6.493e+01   0.622
# scale(BNT):treatmentE             2.012e-02  2.842e-02  6.504e+01   0.708
# scale(NFC):treatmentA            -5.503e-03  3.727e-02  6.493e+01  -0.148
# scale(NFC):treatmentE             1.679e-02  2.622e-02  6.498e+01   0.640
# scale(FI):treatmentA             -2.750e-02  2.930e-02  6.492e+01  -0.939
# scale(FI):treatmentE              7.157e-02  3.045e-02  6.489e+01   2.350
#                                  Pr(>|t|)
# (Intercept)                        <2e-16 ***
# scale(lottery_favour):treatmentA   <2e-16 ***
# scale(lottery_favour):treatmentE   <2e-16 ***
# scale(RT):treatmentA               0.0362 *
# scale(RT):treatmentE               0.6203
# scale(BNT):treatmentA              0.5359
# scale(BNT):treatmentE              0.4816
# scale(NFC):treatmentA              0.8831
# scale(NFC):treatmentE              0.5243
# scale(FI):treatmentA               0.3513
# scale(FI):treatmentE               0.0218 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) s(_):A s(_):E s(RT):A s(RT):E s(BNT):A s(BNT):E s(NFC):A
# scl(ltt_):A  0.021
# scl(ltt_):E -0.018  0.000
# scl(RT):trA  0.006  0.003  0.000
# scl(RT):trE -0.010  0.000 -0.050  0.000
# scl(BNT):tA -0.083 -0.008  0.002  0.004   0.001
# scl(BNT):tE  0.079  0.002  0.022  0.000  -0.029  -0.007
# scl(NFC):tA -0.040  0.022  0.001 -0.008   0.000  -0.237   -0.003
# scl(NFC):tE  0.056  0.001  0.030  0.000  -0.014  -0.005    0.167   -0.002
# scl(FI):trA -0.054 -0.003  0.001  0.013   0.001   0.145   -0.004    0.071
# scl(FI):trE  0.043  0.001  0.006  0.000   0.010  -0.004    0.047   -0.002
#             s(NFC):E s(FI):A
# scl(ltt_):A
# scl(ltt_):E
# scl(RT):trA
# scl(RT):trE
# scl(BNT):tA
# scl(BNT):tE
# scl(NFC):tA
# scl(NFC):tE
# scl(FI):trA -0.003
# scl(FI):trE  0.044   -0.002
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# slc_lot ~ (scale(lottery_favour) + scale(RT) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11490.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.8177 -0.8449 -0.1078  0.8601  3.4793
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.03307  0.1819
#  Residual             0.17225  0.4150
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                    Estimate Std. Error         df t value
# (Intercept)                       4.361e-01  2.693e-02  4.300e+01  16.195
# scale(lottery_favour):treatmentA  2.226e-01  6.676e-03  1.041e+04  33.351
# scale(lottery_favour):treatmentE  2.330e-01  6.331e-03  1.041e+04  36.806
# scale(RT):treatmentA              2.732e-02  6.566e-03  1.040e+04   4.161
# scale(RT):treatmentE              8.988e-03  5.941e-03  1.041e+04   1.513
# scale(BNT):treatmentA             3.207e-02  4.274e-02  4.295e+01   0.750
# scale(BNT):treatmentE             2.362e-02  3.563e-02  4.304e+01   0.663
# scale(NFC):treatmentA            -1.807e-02  4.913e-02  4.291e+01  -0.368
# scale(NFC):treatmentE             5.653e-03  3.172e-02  4.295e+01   0.178
# scale(FI):treatmentA             -1.749e-02  3.920e-02  4.299e+01  -0.446
# scale(FI):treatmentE              9.732e-02  3.627e-02  4.294e+01   2.683
#                                  Pr(>|t|)
# (Intercept)                       < 2e-16 ***
# scale(lottery_favour):treatmentA  < 2e-16 ***
# scale(lottery_favour):treatmentE  < 2e-16 ***
# scale(RT):treatmentA              3.2e-05 ***
# scale(RT):treatmentE               0.1303
# scale(BNT):treatmentA              0.4571
# scale(BNT):treatmentE              0.5108
# scale(NFC):treatmentA              0.7149
# scale(NFC):treatmentE              0.8594
# scale(FI):treatmentA               0.6578
# scale(FI):treatmentE               0.0103 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) s(_):A s(_):E s(RT):A s(RT):E s(BNT):A s(BNT):E s(NFC):A
# scl(ltt_):A  0.017
# scl(ltt_):E -0.014  0.000
# scl(RT):trA  0.012 -0.038  0.000
# scl(RT):trE -0.014  0.000 -0.070  0.000
# scl(BNT):tA -0.187  0.003  0.003 -0.017   0.003
# scl(BNT):tE  0.149  0.003  0.024  0.002  -0.027  -0.028
# scl(NFC):tA  0.042  0.004 -0.001  0.016  -0.001  -0.319    0.006
# scl(NFC):tE  0.016  0.000  0.020  0.000  -0.009  -0.003    0.020    0.001
# scl(FI):trA -0.099  0.029  0.001 -0.008   0.001   0.181   -0.015   -0.057
# scl(FI):trE  0.086  0.002  0.016  0.001   0.008  -0.016    0.178    0.004
#             s(NFC):E s(FI):A
# scl(ltt_):A
# scl(ltt_):E
# scl(RT):trA
# scl(RT):trE
# scl(BNT):tA
# scl(BNT):tE
# scl(NFC):tA
# scl(NFC):tE
# scl(FI):trA -0.002
# scl(FI):trE -0.092   -0.009
