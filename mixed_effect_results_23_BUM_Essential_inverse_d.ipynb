# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)
library(tidyr)
library(broom)

# %% [markdown]
# # Results to be presented in the paper (DDM parameters from  AM_n001_10s_B1)

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1C Dataset_BU/trialsBUM_10s.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# create another dataset in wh subjects with error_choice > 5 are rejected
data2 <- subset(data1, error_choice <= 5)

# split data by whether the subject has a positive or negative pre-evaluation bias
# L: risk-lover; H: risk-hater
data1L <- subset(data1, x0 > 0)
data1H <- subset(data1, x0 < 0)

data2L <- subset(data2, x0 > 0)
data2H <- subset(data2, x0 < 0)

# %%
names(data1)
# Out:
#  [1] "subject"        "trial"          "treatment"      "lot_code"
#  [5] "risk"           "reward"         "WTP"            "certainty"
#  [9] "RT"             "choice"         "slc_lot"        "display"
# [13] "correct"        "incorrect"      "decmode"        "reflection"
# [17] "intuition"      "BNT"            "NFC"            "FI"
# [21] "value_diff"     "value_sum"      "lottery_favour" "lot_correct"
# [25] "error_choice"   "accuracy"       "risk_level"     "d"
# [29] "B"              "x0"             "nondectime"     "inv_d"
# [33] "logRT"

# %% [markdown]
# ###  All continuous variables are scaled due to the inclusion of interactive terms and to avoid the error "Model failed to converge with max|grad|".

# %% [markdown]
# # Split by the pre-evaluation bias

# %%
# Split the dataset; Baseline
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7992.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4058 -1.0550  0.3716  0.7843  3.0776
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.008056 0.08976
#  Residual             0.198296 0.44530
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.495e-01  2.128e-02  2.387e+01
# scale(lottery_favour):treatmentA             1.894e-01  8.284e-03  6.159e+03
# scale(lottery_favour):treatmentE             2.429e-01  1.378e-02  5.995e+03
# scale(WTP):treatmentA                        2.154e-02  8.716e-03  6.174e+03
# scale(WTP):treatmentE                        8.686e-03  1.179e-02  6.392e+03
# scale(inv_d):treatmentA                     -1.886e-02  2.432e-02  2.284e+01
# scale(inv_d):treatmentE                     -1.363e-01  4.033e-02  2.300e+01
# scale(x0):treatmentA                         8.345e-02  2.304e-02  2.280e+01
# scale(x0):treatmentE                         8.603e-02  4.084e-02  2.305e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.311e-02  7.265e-03  6.011e+03
# scale(lottery_favour):scale(WTP):treatmentE -6.818e-02  9.672e-03  5.576e+03
# scale(inv_d):scale(x0):treatmentA            2.956e-02  2.546e-02  2.291e+01
# scale(inv_d):scale(x0):treatmentE            1.127e-01  4.905e-02  2.305e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  30.518  < 2e-16 ***
# scale(lottery_favour):treatmentA             22.861  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.634  < 2e-16 ***
# scale(WTP):treatmentA                         2.471  0.01349 *
# scale(WTP):treatmentE                         0.736  0.46148
# scale(inv_d):treatmentA                      -0.775  0.44608
# scale(inv_d):treatmentE                      -3.380  0.00258 **
# scale(x0):treatmentA                          3.621  0.00145 **
# scale(x0):treatmentE                          2.107  0.04623 *
# scale(lottery_favour):scale(WTP):treatmentA  -7.310 3.02e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.049 2.02e-12 ***
# scale(inv_d):scale(x0):treatmentA             1.161  0.25769
# scale(inv_d):scale(x0):treatmentE             2.297  0.03101 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9918.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2327 -0.8432 -0.2912  0.9344  3.2436
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00603  0.07765
#  Residual             0.18330  0.42814
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.870e-01  1.398e-02  3.586e+01
# scale(lottery_favour):treatmentA             1.738e-01  8.849e-03  8.353e+03
# scale(lottery_favour):treatmentE             2.327e-01  7.596e-03  8.014e+03
# scale(WTP):treatmentA                       -3.897e-02  9.862e-03  7.779e+03
# scale(WTP):treatmentE                       -4.639e-02  7.190e-03  8.382e+03
# scale(inv_d):treatmentA                     -2.391e-02  2.724e-02  3.367e+01
# scale(inv_d):treatmentE                     -5.892e-02  1.796e-02  3.343e+01
# scale(x0):treatmentA                         1.021e-01  2.090e-02  3.368e+01
# scale(x0):treatmentE                         1.231e-01  2.448e-02  3.374e+01
# scale(lottery_favour):scale(WTP):treatmentA  1.112e-02  7.378e-03  4.916e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.446e-02  6.250e-03  7.401e+03
# scale(inv_d):scale(x0):treatmentA            2.890e-02  2.332e-02  3.378e+01
# scale(inv_d):scale(x0):treatmentE            4.698e-03  2.960e-02  3.368e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  27.671  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.638  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.637  < 2e-16 ***
# scale(WTP):treatmentA                        -3.952 7.82e-05 ***
# scale(WTP):treatmentE                        -6.452 1.16e-10 ***
# scale(inv_d):treatmentA                      -0.878  0.38625
# scale(inv_d):treatmentE                      -3.281  0.00243 **
# scale(x0):treatmentA                          4.884 2.48e-05 ***
# scale(x0):treatmentE                          5.030 1.60e-05 ***
# scale(lottery_favour):scale(WTP):treatmentA   1.507  0.13189
# scale(lottery_favour):scale(WTP):treatmentE  -5.514 3.63e-08 ***
# scale(inv_d):scale(x0):treatmentA             1.239  0.22380
# scale(inv_d):scale(x0):treatmentE             0.159  0.87485
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the dataset; with psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8027.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4184 -1.0542  0.3703  0.7848  3.0775
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.009944 0.09972
#  Residual             0.198285 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.401e-01  2.505e-02  1.599e+01
# scale(lottery_favour):treatmentA             1.909e-01  8.330e-03  6.392e+03
# scale(lottery_favour):treatmentE             2.450e-01  1.384e-02  6.275e+03
# scale(WTP):treatmentA                        2.301e-02  8.763e-03  6.396e+03
# scale(WTP):treatmentE                        9.818e-03  1.182e-02  6.411e+03
# scale(inv_d):treatmentA                     -3.070e-02  2.836e-02  1.570e+01
# scale(inv_d):treatmentE                     -1.171e-01  4.873e-02  1.577e+01
# scale(x0):treatmentA                         8.218e-02  2.714e-02  1.565e+01
# scale(x0):treatmentE                         9.063e-02  6.426e-02  1.558e+01
# scale(reflection):treatmentA                 1.392e-02  2.669e-02  1.557e+01
# scale(reflection):treatmentE                -1.363e-02  6.186e-02  1.599e+01
# scale(BNT):treatmentA                        5.445e-03  3.275e-02  1.563e+01
# scale(BNT):treatmentE                       -7.270e-03  4.378e-02  1.562e+01
# scale(NFC):treatmentA                        4.385e-02  2.672e-02  1.621e+01
# scale(NFC):treatmentE                        4.716e-02  5.771e-02  1.612e+01
# scale(FI):treatmentA                        -4.876e-03  2.382e-02  1.561e+01
# scale(FI):treatmentE                         2.147e-02  4.694e-02  1.570e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.355e-02  7.296e-03  6.226e+03
# scale(lottery_favour):scale(WTP):treatmentE -6.960e-02  9.750e-03  6.220e+03
# scale(inv_d):scale(x0):treatmentA            1.487e-02  3.094e-02  1.568e+01
# scale(inv_d):scale(x0):treatmentE            6.301e-02  1.061e-01  1.577e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  25.554 2.14e-14 ***
# scale(lottery_favour):treatmentA             22.919  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.696  < 2e-16 ***
# scale(WTP):treatmentA                         2.626  0.00866 **
# scale(WTP):treatmentE                         0.831  0.40617
# scale(inv_d):treatmentA                      -1.083  0.29534
# scale(inv_d):treatmentE                      -2.403  0.02892 *
# scale(x0):treatmentA                          3.029  0.00815 **
# scale(x0):treatmentE                          1.410  0.17813
# scale(reflection):treatmentA                  0.521  0.60938
# scale(reflection):treatmentE                 -0.220  0.82834
# scale(BNT):treatmentA                         0.166  0.87009
# scale(BNT):treatmentE                        -0.166  0.87024
# scale(NFC):treatmentA                         1.641  0.12006
# scale(NFC):treatmentE                         0.817  0.42574
# scale(FI):treatmentA                         -0.205  0.84048
# scale(FI):treatmentE                          0.457  0.65369
# scale(lottery_favour):scale(WTP):treatmentA  -7.340 2.41e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.138 1.05e-12 ***
# scale(inv_d):scale(x0):treatmentA             0.481  0.63742
# scale(inv_d):scale(x0):treatmentE             0.594  0.56102
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9946.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2563 -0.8429 -0.2856  0.9354  3.2342
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004301 0.06558
#  Residual             0.183298 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.951e-01  1.370e-02  2.810e+01
# scale(lottery_favour):treatmentA             1.740e-01  8.845e-03  8.194e+03
# scale(lottery_favour):treatmentE             2.339e-01  7.611e-03  8.078e+03
# scale(WTP):treatmentA                       -3.894e-02  9.843e-03  7.192e+03
# scale(WTP):treatmentE                       -4.545e-02  7.201e-03  8.402e+03
# scale(inv_d):treatmentA                      2.200e-02  4.130e-02  2.578e+01
# scale(inv_d):treatmentE                     -5.371e-02  1.737e-02  2.602e+01
# scale(x0):treatmentA                         1.263e-01  2.607e-02  2.572e+01
# scale(x0):treatmentE                         8.183e-02  2.677e-02  2.606e+01
# scale(reflection):treatmentA                 6.244e-02  4.274e-02  2.584e+01
# scale(reflection):treatmentE                 6.867e-02  1.997e-02  2.661e+01
# scale(BNT):treatmentA                       -1.125e-02  3.239e-02  2.618e+01
# scale(BNT):treatmentE                       -3.686e-02  1.827e-02  2.556e+01
# scale(NFC):treatmentA                       -5.772e-02  3.787e-02  2.603e+01
# scale(NFC):treatmentE                       -2.562e-02  1.465e-02  2.557e+01
# scale(FI):treatmentA                         3.821e-03  2.304e-02  2.566e+01
# scale(FI):treatmentE                         4.611e-02  1.956e-02  2.618e+01
# scale(lottery_favour):scale(WTP):treatmentA  1.154e-02  7.339e-03  3.615e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.623e-02  6.263e-03  7.421e+03
# scale(inv_d):scale(x0):treatmentA            1.991e-02  2.191e-02  2.593e+01
# scale(inv_d):scale(x0):treatmentE            3.667e-02  3.261e-02  2.588e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  28.846  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.676  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.724  < 2e-16 ***
# scale(WTP):treatmentA                        -3.956 7.69e-05 ***
# scale(WTP):treatmentE                        -6.312 2.90e-10 ***
# scale(inv_d):treatmentA                       0.533  0.59881
# scale(inv_d):treatmentE                      -3.093  0.00469 **
# scale(x0):treatmentA                          4.844 5.21e-05 ***
# scale(x0):treatmentE                          3.056  0.00512 **
# scale(reflection):treatmentA                  1.461  0.15604
# scale(reflection):treatmentE                  3.439  0.00194 **
# scale(BNT):treatmentA                        -0.347  0.73101
# scale(BNT):treatmentE                        -2.018  0.05421 .
# scale(NFC):treatmentA                        -1.524  0.13960
# scale(NFC):treatmentE                        -1.748  0.09241 .
# scale(FI):treatmentA                          0.166  0.86959
# scale(FI):treatmentE                          2.357  0.02618 *
# scale(lottery_favour):scale(WTP):treatmentA   1.572  0.11607
# scale(lottery_favour):scale(WTP):treatmentE  -5.784 7.58e-09 ***
# scale(inv_d):scale(x0):treatmentA             0.909  0.37174
# scale(inv_d):scale(x0):treatmentE             1.124  0.27124
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the dataset; with psychometrics; with interaction
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1H))
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# Correlation matrix not shown by default, as p = 28 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8039.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4296 -1.0518  0.3695  0.7852  3.0813
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003926 0.06266
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.524e-01  2.386e-02  9.222e+00
# scale(lottery_favour):treatmentA             1.903e-01  8.306e-03  6.006e+03
# scale(lottery_favour):treatmentE             2.491e-01  1.392e-02  6.401e+03
# scale(WTP):treatmentA                        2.236e-02  8.745e-03  6.132e+03
# scale(WTP):treatmentE                        1.206e-02  1.184e-02  6.401e+03
# scale(inv_d):treatmentA                     -3.720e-02  2.362e-02  8.963e+00
# scale(inv_d):treatmentE                     -1.795e-02  1.261e-01  9.451e+00
# scale(x0):treatmentA                         7.540e-02  2.082e-02  8.873e+00
# scale(x0):treatmentE                        -4.258e-02  1.155e-01  9.236e+00
# scale(reflection):treatmentA                 2.297e-02  1.901e-02  8.836e+00
# scale(reflection):treatmentE                -2.938e-02  5.405e-02  9.589e+00
# scale(BNT):treatmentA                        1.769e-02  2.493e-02  8.873e+00
# scale(BNT):treatmentE                        2.297e-01  7.648e-02  9.415e+00
# scale(NFC):treatmentA                        4.113e-02  2.015e-02  9.452e+00
# scale(NFC):treatmentE                        1.354e-01  5.023e-02  9.955e+00
# scale(FI):treatmentA                         7.185e-03  1.920e-02  8.793e+00
# scale(FI):treatmentE                         2.015e-01  5.664e-02  9.471e+00
# scale(lottery_favour):scale(WTP):treatmentA -5.326e-02  7.325e-03  6.391e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.127e-02  9.806e-03  6.401e+03
# scale(inv_d):scale(x0):treatmentA            2.058e-02  3.178e-02  8.877e+00
# scale(inv_d):scale(x0):treatmentE            2.123e-01  1.399e-01  9.244e+00
# scale(inv_d):scale(reflection):treatmentA    1.209e-02  2.968e-02  8.991e+00
# scale(inv_d):scale(reflection):treatmentE    5.572e-01  1.739e-01  9.325e+00
# scale(inv_d):scale(BNT):treatmentA          -2.330e-02  2.980e-02  8.864e+00
# scale(inv_d):scale(BNT):treatmentE          -4.071e-01  1.080e-01  9.369e+00
# scale(inv_d):scale(NFC):treatmentA           2.000e-02  1.792e-02  8.967e+00
# scale(inv_d):scale(NFC):treatmentE           6.073e-02  1.008e-01  9.296e+00
# scale(inv_d):scale(FI):treatmentA           -2.959e-02  2.110e-02  8.872e+00
#                                             t value Pr(>|t|)
# (Intercept)                                  27.341 3.84e-10 ***
# scale(lottery_favour):treatmentA             22.911  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.901  < 2e-16 ***
# scale(WTP):treatmentA                         2.557  0.01057 *
# scale(WTP):treatmentE                         1.018  0.30850
# scale(inv_d):treatmentA                      -1.575  0.14989
# scale(inv_d):treatmentE                      -0.142  0.88986
# scale(x0):treatmentA                          3.621  0.00569 **
# scale(x0):treatmentE                         -0.369  0.72062
# scale(reflection):treatmentA                  1.208  0.25823
# scale(reflection):treatmentE                 -0.544  0.59911
# scale(BNT):treatmentA                         0.710  0.49621
# scale(BNT):treatmentE                         3.004  0.01415 *
# scale(NFC):treatmentA                         2.041  0.07012 .
# scale(NFC):treatmentE                         2.696  0.02257 *
# scale(FI):treatmentA                          0.374  0.71703
# scale(FI):treatmentE                          3.557  0.00567 **
# scale(lottery_favour):scale(WTP):treatmentA  -7.272 3.98e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.268 4.08e-13 ***
# scale(inv_d):scale(x0):treatmentA             0.648  0.53354
# scale(inv_d):scale(x0):treatmentE             1.518  0.16249
# scale(inv_d):scale(reflection):treatmentA     0.407  0.69341
# scale(inv_d):scale(reflection):treatmentE     3.204  0.01028 *
# scale(inv_d):scale(BNT):treatmentA           -0.782  0.45472
# scale(inv_d):scale(BNT):treatmentE           -3.768  0.00412 **
# scale(inv_d):scale(NFC):treatmentA            1.116  0.29336
# scale(inv_d):scale(NFC):treatmentE            0.603  0.56115
# scale(inv_d):scale(FI):treatmentA            -1.402  0.19485
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9976.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2449 -0.8424 -0.2871  0.9322  3.2374
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003803 0.06167
#  Residual             0.183295 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.036e-01  1.619e-02  1.898e+01
# scale(lottery_favour):treatmentA             1.757e-01  8.902e-03  8.520e+03
# scale(lottery_favour):treatmentE             2.341e-01  7.632e-03  8.228e+03
# scale(WTP):treatmentA                       -3.625e-02  9.959e-03  8.480e+03
# scale(WTP):treatmentE                       -4.544e-02  7.212e-03  8.432e+03
# scale(inv_d):treatmentA                     -5.045e-03  7.419e-02  1.855e+01
# scale(inv_d):treatmentE                     -5.670e-02  1.827e-02  1.841e+01
# scale(x0):treatmentA                         1.190e-01  2.694e-02  1.818e+01
# scale(x0):treatmentE                         1.069e-01  3.484e-02  1.810e+01
# scale(reflection):treatmentA                 6.622e-02  4.226e-02  1.820e+01
# scale(reflection):treatmentE                 3.490e-02  2.364e-02  1.819e+01
# scale(BNT):treatmentA                       -3.598e-02  4.612e-02  1.858e+01
# scale(BNT):treatmentE                       -2.585e-02  1.965e-02  1.789e+01
# scale(NFC):treatmentA                       -4.223e-02  5.072e-02  1.822e+01
# scale(NFC):treatmentE                       -1.572e-02  1.631e-02  1.802e+01
# scale(FI):treatmentA                         3.091e-02  3.494e-02  1.816e+01
# scale(FI):treatmentE                         2.443e-02  2.542e-02  1.799e+01
# scale(lottery_favour):scale(WTP):treatmentA  9.039e-03  7.468e-03  5.636e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.543e-02  6.279e-03  7.416e+03
# scale(inv_d):scale(x0):treatmentA            3.103e-02  3.228e-02  1.924e+01
# scale(inv_d):scale(x0):treatmentE           -3.386e-03  4.807e-02  1.816e+01
# scale(inv_d):scale(reflection):treatmentA   -2.785e-02  6.539e-02  1.820e+01
# scale(inv_d):scale(reflection):treatmentE    3.953e-02  2.150e-02  1.809e+01
# scale(inv_d):scale(BNT):treatmentA           5.152e-02  1.080e-01  1.823e+01
# scale(inv_d):scale(BNT):treatmentE          -2.521e-03  1.753e-02  1.816e+01
# scale(inv_d):scale(NFC):treatmentA           5.827e-03  7.476e-02  1.843e+01
# scale(inv_d):scale(NFC):treatmentE           2.280e-02  1.469e-02  1.795e+01
# scale(inv_d):scale(FI):treatmentA           -5.972e-02  6.406e-02  1.818e+01
# scale(inv_d):scale(FI):treatmentE            4.748e-02  4.122e-02  1.845e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  24.932 5.75e-16 ***
# scale(lottery_favour):treatmentA             19.731  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.668  < 2e-16 ***
# scale(WTP):treatmentA                        -3.640 0.000274 ***
# scale(WTP):treatmentE                        -6.301 3.11e-10 ***
# scale(inv_d):treatmentA                      -0.068 0.946515
# scale(inv_d):treatmentE                      -3.104 0.006009 **
# scale(x0):treatmentA                          4.416 0.000327 ***
# scale(x0):treatmentE                          3.069 0.006587 **
# scale(reflection):treatmentA                  1.567 0.134380
# scale(reflection):treatmentE                  1.476 0.157000
# scale(BNT):treatmentA                        -0.780 0.445181
# scale(BNT):treatmentE                        -1.315 0.204950
# scale(NFC):treatmentA                        -0.833 0.415809
# scale(NFC):treatmentE                        -0.964 0.347888
# scale(FI):treatmentA                          0.885 0.387916
# scale(FI):treatmentE                          0.961 0.349276
# scale(lottery_favour):scale(WTP):treatmentA   1.210 0.226222
# scale(lottery_favour):scale(WTP):treatmentE  -5.643 1.73e-08 ***
# scale(inv_d):scale(x0):treatmentA             0.961 0.348237
# scale(inv_d):scale(x0):treatmentE            -0.070 0.944605
# scale(inv_d):scale(reflection):treatmentA    -0.426 0.675202
# scale(inv_d):scale(reflection):treatmentE     1.839 0.082398 .
# scale(inv_d):scale(BNT):treatmentA            0.477 0.639052
# scale(inv_d):scale(BNT):treatmentE           -0.144 0.887216
# scale(inv_d):scale(NFC):treatmentA            0.078 0.938717
# scale(inv_d):scale(NFC):treatmentE            1.552 0.138099
# scale(inv_d):scale(FI):treatmentA            -0.932 0.363427
# scale(inv_d):scale(FI):treatmentE             1.152 0.264125
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the datasets; with psychometrics; with interaction; change order (a different variable is droped due to rank difficiency)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(FI) + scale(NFC) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(FI) + scale(inv_d):scale(NFC)):treatment + (1|subject), data1L))
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# Correlation matrix not shown by default, as p = 28 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(FI) +
#     scale(NFC) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(FI) + scale(inv_d):scale(NFC)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8039.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4296 -1.0518  0.3695  0.7852  3.0813
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003926 0.06266
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.524e-01  2.386e-02  9.222e+00
# scale(lottery_favour):treatmentA             1.903e-01  8.306e-03  6.006e+03
# scale(lottery_favour):treatmentE             2.491e-01  1.392e-02  6.401e+03
# scale(WTP):treatmentA                        2.236e-02  8.745e-03  6.132e+03
# scale(WTP):treatmentE                        1.206e-02  1.184e-02  6.401e+03
# scale(inv_d):treatmentA                     -3.720e-02  2.362e-02  8.963e+00
# scale(inv_d):treatmentE                     -1.431e-02  1.318e-01  9.446e+00
# scale(x0):treatmentA                         7.540e-02  2.082e-02  8.873e+00
# scale(x0):treatmentE                        -2.343e-02  9.192e-02  9.145e+00
# scale(reflection):treatmentA                 2.297e-02  1.901e-02  8.836e+00
# scale(reflection):treatmentE                -4.517e-02  4.618e-02  9.552e+00
# scale(BNT):treatmentA                        1.769e-02  2.493e-02  8.873e+00
# scale(BNT):treatmentE                        2.503e-01  9.887e-02  9.423e+00
# scale(FI):treatmentA                         7.185e-03  1.920e-02  8.793e+00
# scale(FI):treatmentE                         2.104e-01  6.334e-02  9.505e+00
# scale(NFC):treatmentA                        4.113e-02  2.015e-02  9.452e+00
# scale(NFC):treatmentE                        1.649e-01  7.033e-02  9.740e+00
# scale(lottery_favour):scale(WTP):treatmentA -5.326e-02  7.325e-03  6.391e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.127e-02  9.806e-03  6.401e+03
# scale(inv_d):scale(x0):treatmentA            2.058e-02  3.178e-02  8.877e+00
# scale(inv_d):scale(x0):treatmentE            1.120e-01  1.032e-01  8.829e+00
# scale(inv_d):scale(reflection):treatmentA    1.209e-02  2.968e-02  8.991e+00
# scale(inv_d):scale(reflection):treatmentE    6.446e-01  1.470e-01  9.590e+00
# scale(inv_d):scale(BNT):treatmentA          -2.330e-02  2.980e-02  8.864e+00
# scale(inv_d):scale(BNT):treatmentE          -4.067e-01  1.081e-01  9.367e+00
# scale(inv_d):scale(FI):treatmentA           -2.959e-02  2.110e-02  8.872e+00
# scale(inv_d):scale(FI):treatmentE           -9.213e-02  1.529e-01  9.296e+00
# scale(inv_d):scale(NFC):treatmentA           2.000e-02  1.792e-02  8.967e+00
#                                             t value Pr(>|t|)
# (Intercept)                                  27.341 3.84e-10 ***
# scale(lottery_favour):treatmentA             22.911  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.901  < 2e-16 ***
# scale(WTP):treatmentA                         2.557  0.01057 *
# scale(WTP):treatmentE                         1.018  0.30850
# scale(inv_d):treatmentA                      -1.575  0.14989
# scale(inv_d):treatmentE                      -0.109  0.91580
# scale(x0):treatmentA                          3.621  0.00569 **
# scale(x0):treatmentE                         -0.255  0.80446
# scale(reflection):treatmentA                  1.208  0.25823
# scale(reflection):treatmentE                 -0.978  0.35206
# scale(BNT):treatmentA                         0.710  0.49621
# scale(BNT):treatmentE                         2.532  0.03106 *
# scale(FI):treatmentA                          0.374  0.71703
# scale(FI):treatmentE                          3.322  0.00827 **
# scale(NFC):treatmentA                         2.041  0.07012 .
# scale(NFC):treatmentE                         2.344  0.04169 *
# scale(lottery_favour):scale(WTP):treatmentA  -7.272 3.98e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.268 4.08e-13 ***
# scale(inv_d):scale(x0):treatmentA             0.648  0.53354
# scale(inv_d):scale(x0):treatmentE             1.085  0.30682
# scale(inv_d):scale(reflection):treatmentA     0.407  0.69341
# scale(inv_d):scale(reflection):treatmentE     4.384  0.00151 **
# scale(inv_d):scale(BNT):treatmentA           -0.782  0.45472
# scale(inv_d):scale(BNT):treatmentE           -3.760  0.00417 **
# scale(inv_d):scale(FI):treatmentA            -1.402  0.19485
# scale(inv_d):scale(FI):treatmentE            -0.603  0.56115
# scale(inv_d):scale(NFC):treatmentA            1.116  0.29336
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
# Split the dataset; with psychometrics; with interaction; BNT is dropped
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 25 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(NFC) + scale(FI) +
#     scale(inv_d):scale(reflection) + scale(inv_d):scale(NFC) +
#     scale(inv_d):scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8035.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4243 -1.0519  0.3676  0.7842  3.0818
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.009237 0.09611
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.395e-01  3.283e-02  1.202e+01
# scale(lottery_favour):treatmentA             1.912e-01  8.330e-03  6.365e+03
# scale(lottery_favour):treatmentE             2.459e-01  1.386e-02  6.296e+03
# scale(WTP):treatmentA                        2.325e-02  8.765e-03  6.382e+03
# scale(WTP):treatmentE                        1.027e-02  1.182e-02  6.406e+03
# scale(inv_d):treatmentA                     -3.674e-02  3.342e-02  1.188e+01
# scale(inv_d):treatmentE                     -3.786e-02  1.669e-01  1.217e+01
# scale(x0):treatmentA                         7.797e-02  2.837e-02  1.180e+01
# scale(x0):treatmentE                         3.433e-02  2.278e-01  1.199e+01
# scale(reflection):treatmentA                 2.876e-02  2.612e-02  1.177e+01
# scale(reflection):treatmentE                 6.527e-02  1.085e-01  1.214e+01
# scale(NFC):treatmentA                        4.743e-02  2.775e-02  1.225e+01
# scale(NFC):treatmentE                       -1.845e-02  1.125e-01  1.201e+01
# scale(FI):treatmentA                        -1.674e-03  2.652e-02  1.175e+01
# scale(FI):treatmentE                         3.681e-02  5.023e-02  1.185e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.351e-02  7.327e-03  6.409e+03
# scale(lottery_favour):scale(WTP):treatmentE -6.959e-02  9.785e-03  6.395e+03
# scale(inv_d):scale(x0):treatmentA            7.891e-03  3.910e-02  1.183e+01
# scale(inv_d):scale(x0):treatmentE            2.742e-01  5.528e-01  1.199e+01
# scale(inv_d):scale(reflection):treatmentA    1.100e-02  4.222e-02  1.187e+01
# scale(inv_d):scale(reflection):treatmentE   -9.630e-02  4.594e-01  1.199e+01
# scale(inv_d):scale(NFC):treatmentA           1.738e-02  2.551e-02  1.184e+01
# scale(inv_d):scale(NFC):treatmentE           2.018e-01  3.627e-01  1.202e+01
# scale(inv_d):scale(FI):treatmentA           -2.537e-02  2.971e-02  1.182e+01
# scale(inv_d):scale(FI):treatmentE            1.418e-01  3.560e-01  1.195e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  19.477 1.86e-10 ***
# scale(lottery_favour):treatmentA             22.954  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.737  < 2e-16 ***
# scale(WTP):treatmentA                         2.653  0.00801 **
# scale(WTP):treatmentE                         0.869  0.38504
# scale(inv_d):treatmentA                      -1.099  0.29343
# scale(inv_d):treatmentE                      -0.227  0.82434
# scale(x0):treatmentA                          2.748  0.01790 *
# scale(x0):treatmentE                          0.151  0.88273
# scale(reflection):treatmentA                  1.101  0.29297
# scale(reflection):treatmentE                  0.602  0.55838
# scale(NFC):treatmentA                         1.709  0.11257
# scale(NFC):treatmentE                        -0.164  0.87240
# scale(FI):treatmentA                         -0.063  0.95074
# scale(FI):treatmentE                          0.733  0.47786
# scale(lottery_favour):scale(WTP):treatmentA  -7.304 3.13e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.112 1.27e-12 ***
# scale(inv_d):scale(x0):treatmentA             0.202  0.84351
# scale(inv_d):scale(x0):treatmentE             0.496  0.62885
# scale(inv_d):scale(reflection):treatmentA     0.261  0.79892
# scale(inv_d):scale(reflection):treatmentE    -0.210  0.83750
# scale(inv_d):scale(NFC):treatmentA            0.681  0.50881
# scale(inv_d):scale(NFC):treatmentE            0.556  0.58810
# scale(inv_d):scale(FI):treatmentA            -0.854  0.41016
# scale(inv_d):scale(FI):treatmentE             0.398  0.69745
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 25 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(NFC) + scale(FI) +
#     scale(inv_d):scale(reflection) + scale(inv_d):scale(NFC) +
#     scale(inv_d):scale(FI)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9959.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2413 -0.8441 -0.2895  0.9335  3.2441
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003497 0.05914
#  Residual             0.183295 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.095e-01  1.449e-02  2.356e+01
# scale(lottery_favour):treatmentA             1.759e-01  8.888e-03  8.504e+03
# scale(lottery_favour):treatmentE             2.341e-01  7.615e-03  8.040e+03
# scale(WTP):treatmentA                       -3.560e-02  9.933e-03  8.337e+03
# scale(WTP):treatmentE                       -4.543e-02  7.203e-03  8.389e+03
# scale(inv_d):treatmentA                      2.797e-02  5.088e-02  2.238e+01
# scale(inv_d):treatmentE                     -5.727e-02  1.762e-02  2.255e+01
# scale(x0):treatmentA                         1.210e-01  2.574e-02  2.211e+01
# scale(x0):treatmentE                         1.002e-01  3.328e-02  2.215e+01
# scale(reflection):treatmentA                 5.406e-02  3.302e-02  2.199e+01
# scale(reflection):treatmentE                 2.554e-02  2.184e-02  2.229e+01
# scale(NFC):treatmentA                       -6.817e-02  4.321e-02  2.222e+01
# scale(NFC):treatmentE                       -1.431e-02  1.568e-02  2.204e+01
# scale(FI):treatmentA                         9.895e-03  2.676e-02  2.287e+01
# scale(FI):treatmentE                         2.563e-02  2.363e-02  2.195e+01
# scale(lottery_favour):scale(WTP):treatmentA  8.145e-03  7.422e-03  4.867e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.516e-02  6.272e-03  7.445e+03
# scale(inv_d):scale(x0):treatmentA            4.599e-02  2.504e-02  2.360e+01
# scale(inv_d):scale(x0):treatmentE            9.601e-03  4.450e-02  2.215e+01
# scale(inv_d):scale(reflection):treatmentA   -1.059e-02  2.881e-02  2.256e+01
# scale(inv_d):scale(reflection):treatmentE    4.038e-02  1.998e-02  2.199e+01
# scale(inv_d):scale(NFC):treatmentA          -3.507e-02  3.523e-02  2.310e+01
# scale(inv_d):scale(NFC):treatmentE           2.843e-02  1.353e-02  2.193e+01
# scale(inv_d):scale(FI):treatmentA           -1.863e-02  4.724e-02  2.279e+01
# scale(inv_d):scale(FI):treatmentE            4.906e-02  3.660e-02  2.224e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  28.261  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.795  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.739  < 2e-16 ***
# scale(WTP):treatmentA                        -3.584 0.000340 ***
# scale(WTP):treatmentE                        -6.307 2.99e-10 ***
# scale(inv_d):treatmentA                       0.550 0.587980
# scale(inv_d):treatmentE                      -3.250 0.003588 **
# scale(x0):treatmentA                          4.700 0.000108 ***
# scale(x0):treatmentE                          3.010 0.006412 **
# scale(reflection):treatmentA                  1.637 0.115808
# scale(reflection):treatmentE                  1.170 0.254557
# scale(NFC):treatmentA                        -1.577 0.128815
# scale(NFC):treatmentE                        -0.913 0.371365
# scale(FI):treatmentA                          0.370 0.714953
# scale(FI):treatmentE                          1.085 0.289899
# scale(lottery_favour):scale(WTP):treatmentA   1.097 0.272547
# scale(lottery_favour):scale(WTP):treatmentE  -5.607 2.14e-08 ***
# scale(inv_d):scale(x0):treatmentA             1.837 0.078840 .
# scale(inv_d):scale(x0):treatmentE             0.216 0.831162
# scale(inv_d):scale(reflection):treatmentA    -0.367 0.716727
# scale(inv_d):scale(reflection):treatmentE     2.021 0.055595 .
# scale(inv_d):scale(NFC):treatmentA           -0.996 0.329734
# scale(inv_d):scale(NFC):treatmentE            2.101 0.047314 *
# scale(inv_d):scale(FI):treatmentA            -0.394 0.696920
# scale(inv_d):scale(FI):treatmentE             1.341 0.193613
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the dataset; with psychometrics; with interaction; no interaction between d and x0
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8035.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4276 -1.0539  0.3702  0.7870  3.0782
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003645 0.06037
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.416e-01  1.663e-02  1.106e+01
# scale(lottery_favour):treatmentA             1.904e-01  8.299e-03  5.932e+03
# scale(lottery_favour):treatmentE             2.491e-01  1.392e-02  6.401e+03
# scale(WTP):treatmentA                        2.244e-02  8.738e-03  6.073e+03
# scale(WTP):treatmentE                        1.206e-02  1.184e-02  6.401e+03
# scale(inv_d):treatmentA                     -4.188e-02  2.183e-02  9.993e+00
# scale(inv_d):treatmentE                      2.679e-02  1.138e-01  1.082e+01
# scale(x0):treatmentA                         7.353e-02  2.003e-02  9.897e+00
# scale(x0):treatmentE                        -2.314e-02  8.807e-02  1.035e+01
# scale(reflection):treatmentA                 2.276e-02  1.845e-02  9.847e+00
# scale(reflection):treatmentE                -5.990e-02  4.384e-02  1.073e+01
# scale(BNT):treatmentA                        2.431e-02  2.211e-02  9.915e+00
# scale(BNT):treatmentE                        2.885e-01  9.255e-02  1.051e+01
# scale(NFC):treatmentA                        4.755e-02  1.698e-02  1.058e+01
# scale(NFC):treatmentE                        2.080e-01  6.061e-02  1.097e+01
# scale(FI):treatmentA                         6.181e-03  1.857e-02  9.782e+00
# scale(FI):treatmentE                         2.289e-01  6.115e-02  1.058e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.329e-02  7.323e-03  6.390e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.127e-02  9.806e-03  6.401e+03
# scale(inv_d):scale(reflection):treatmentA    1.845e-02  2.720e-02  9.957e+00
# scale(inv_d):scale(reflection):treatmentE    7.283e-01  1.682e-01  1.038e+01
# scale(inv_d):scale(BNT):treatmentA          -1.508e-02  2.621e-02  9.872e+00
# scale(inv_d):scale(BNT):treatmentE          -3.980e-01  1.042e-01  1.049e+01
# scale(inv_d):scale(NFC):treatmentA           1.690e-02  1.677e-02  1.000e+01
# scale(inv_d):scale(NFC):treatmentE          -6.074e-02  5.974e-02  9.843e+00
# scale(inv_d):scale(FI):treatmentA           -3.133e-02  2.031e-02  9.893e+00
# scale(inv_d):scale(FI):treatmentE           -2.238e-01  1.171e-01  1.043e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  38.583 3.83e-13 ***
# scale(lottery_favour):treatmentA             22.940  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.901  < 2e-16 ***
# scale(WTP):treatmentA                         2.568  0.01024 *
# scale(WTP):treatmentE                         1.018  0.30850
# scale(inv_d):treatmentA                      -1.919  0.08401 .
# scale(inv_d):treatmentE                       0.235  0.81829
# scale(x0):treatmentA                          3.672  0.00438 **
# scale(x0):treatmentE                         -0.263  0.79787
# scale(reflection):treatmentA                  1.233  0.24605
# scale(reflection):treatmentE                 -1.366  0.19977
# scale(BNT):treatmentA                         1.099  0.29764
# scale(BNT):treatmentE                         3.117  0.01032 *
# scale(NFC):treatmentA                         2.800  0.01787 *
# scale(NFC):treatmentE                         3.432  0.00563 **
# scale(FI):treatmentA                          0.333  0.74630
# scale(FI):treatmentE                          3.743  0.00347 **
# scale(lottery_favour):scale(WTP):treatmentA  -7.277 3.83e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.268 4.08e-13 ***
# scale(inv_d):scale(reflection):treatmentA     0.678  0.51295
# scale(inv_d):scale(reflection):treatmentE     4.329  0.00137 **
# scale(inv_d):scale(BNT):treatmentA           -0.575  0.57788
# scale(inv_d):scale(BNT):treatmentE           -3.821  0.00309 **
# scale(inv_d):scale(NFC):treatmentA            1.007  0.33746
# scale(inv_d):scale(NFC):treatmentE           -1.017  0.33363
# scale(inv_d):scale(FI):treatmentA            -1.542  0.15440
# scale(inv_d):scale(FI):treatmentE            -1.911  0.08386 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9968.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2535 -0.8384 -0.2868  0.9312  3.2172
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.003554 0.05961
#  Residual             0.183295 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.042e-01  1.571e-02  2.116e+01
# scale(lottery_favour):treatmentA             1.750e-01  8.877e-03  8.427e+03
# scale(lottery_favour):treatmentE             2.340e-01  7.623e-03  8.126e+03
# scale(WTP):treatmentA                       -3.731e-02  9.898e-03  7.832e+03
# scale(WTP):treatmentE                       -4.550e-02  7.206e-03  8.396e+03
# scale(inv_d):treatmentA                     -2.431e-02  6.953e-02  2.037e+01
# scale(inv_d):treatmentE                     -5.730e-02  1.586e-02  2.035e+01
# scale(x0):treatmentA                         1.287e-01  2.429e-02  2.021e+01
# scale(x0):treatmentE                         1.049e-01  2.067e-02  1.992e+01
# scale(reflection):treatmentA                 7.809e-02  3.934e-02  2.014e+01
# scale(reflection):treatmentE                 3.547e-02  2.057e-02  2.052e+01
# scale(BNT):treatmentA                       -5.878e-02  3.851e-02  2.020e+01
# scale(BNT):treatmentE                       -2.528e-02  1.857e-02  1.988e+01
# scale(NFC):treatmentA                       -3.479e-02  4.876e-02  2.006e+01
# scale(NFC):treatmentE                       -1.634e-02  1.287e-02  1.993e+01
# scale(FI):treatmentA                         4.408e-02  3.127e-02  2.072e+01
# scale(FI):treatmentE                         2.558e-02  1.966e-02  2.002e+01
# scale(lottery_favour):scale(WTP):treatmentA  9.955e-03  7.403e-03  4.222e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.539e-02  6.273e-03  7.370e+03
# scale(inv_d):scale(reflection):treatmentA   -4.706e-02  6.060e-02  2.062e+01
# scale(inv_d):scale(reflection):treatmentE    3.902e-02  1.839e-02  1.998e+01
# scale(inv_d):scale(BNT):treatmentA           1.040e-01  9.075e-02  2.069e+01
# scale(inv_d):scale(BNT):treatmentE          -2.152e-03  1.661e-02  2.003e+01
# scale(inv_d):scale(NFC):treatmentA           5.616e-02  5.194e-02  2.016e+01
# scale(inv_d):scale(NFC):treatmentE           2.332e-02  1.328e-02  1.988e+01
# scale(inv_d):scale(FI):treatmentA           -7.949e-02  5.903e-02  2.043e+01
# scale(inv_d):scale(FI):treatmentE            4.558e-02  2.742e-02  2.038e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  25.734  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.715  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.694  < 2e-16 ***
# scale(WTP):treatmentA                        -3.769 0.000165 ***
# scale(WTP):treatmentE                        -6.313 2.87e-10 ***
# scale(inv_d):treatmentA                      -0.350 0.730265
# scale(inv_d):treatmentE                      -3.614 0.001694 **
# scale(x0):treatmentA                          5.301 3.35e-05 ***
# scale(x0):treatmentE                          5.074 5.88e-05 ***
# scale(reflection):treatmentA                  1.985 0.060912 .
# scale(reflection):treatmentE                  1.724 0.099733 .
# scale(BNT):treatmentA                        -1.527 0.142362
# scale(BNT):treatmentE                        -1.362 0.188494
# scale(NFC):treatmentA                        -0.713 0.483830
# scale(NFC):treatmentE                        -1.269 0.218902
# scale(FI):treatmentA                          1.409 0.173559
# scale(FI):treatmentE                          1.301 0.208009
# scale(lottery_favour):scale(WTP):treatmentA   1.345 0.178827
# scale(lottery_favour):scale(WTP):treatmentE  -5.642 1.74e-08 ***
# scale(inv_d):scale(reflection):treatmentA    -0.777 0.446214
# scale(inv_d):scale(reflection):treatmentE     2.122 0.046506 *
# scale(inv_d):scale(BNT):treatmentA            1.146 0.265038
# scale(inv_d):scale(BNT):treatmentE           -0.130 0.898178
# scale(inv_d):scale(NFC):treatmentA            1.081 0.292383
# scale(inv_d):scale(NFC):treatmentE            1.756 0.094506 .
# scale(inv_d):scale(FI):treatmentA            -1.347 0.192843
# scale(inv_d):scale(FI):treatmentE             1.662 0.111789
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Whole Dataset

# %%
# All subjects; Baseline
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17936.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4829 -0.9171  0.0379  0.8632  3.1904
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00776  0.08809
#  Residual             0.19063  0.43661
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.933e-01  1.166e-02  6.606e+01
# scale(lottery_favour):treatmentA             1.809e-01  6.022e-03  1.454e+04
# scale(lottery_favour):treatmentE             2.347e-01  6.724e-03  1.425e+04
# scale(WTP):treatmentA                       -4.327e-03  6.508e-03  1.416e+04
# scale(WTP):treatmentE                       -3.077e-02  6.191e-03  1.485e+04
# scale(inv_d):treatmentA                     -2.040e-02  1.644e-02  6.282e+01
# scale(inv_d):treatmentE                     -6.500e-02  1.694e-02  6.293e+01
# scale(x0):treatmentA                         1.412e-01  1.432e-02  6.287e+01
# scale(x0):treatmentE                         1.511e-01  1.858e-02  6.260e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.223e-02  5.155e-03  1.197e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.478e-02  5.280e-03  1.336e+04
# scale(inv_d):scale(x0):treatmentA            1.929e-02  1.917e-02  6.298e+01
# scale(inv_d):scale(x0):treatmentE           -4.541e-03  2.209e-02  6.254e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  42.330  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.038  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.908  < 2e-16 ***
# scale(WTP):treatmentA                        -0.665 0.506151
# scale(WTP):treatmentE                        -4.971 6.74e-07 ***
# scale(inv_d):treatmentA                      -1.241 0.219237
# scale(inv_d):treatmentE                      -3.836 0.000292 ***
# scale(x0):treatmentA                          9.855 2.25e-14 ***
# scale(x0):treatmentE                          8.135 2.16e-11 ***
# scale(lottery_favour):scale(WTP):treatmentA  -4.312 1.63e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.481  < 2e-16 ***
# scale(inv_d):scale(x0):treatmentA             1.006 0.318087
# scale(inv_d):scale(x0):treatmentE            -0.206 0.837829
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# All subjects; with psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17975.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4829 -0.9169  0.0398  0.8620  3.1841
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007385 0.08594
#  Residual             0.190629 0.43661
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.889e-01  1.186e-02  5.732e+01
# scale(lottery_favour):treatmentA             1.808e-01  6.024e-03  1.447e+04
# scale(lottery_favour):treatmentE             2.350e-01  6.735e-03  1.439e+04
# scale(WTP):treatmentA                       -4.461e-03  6.511e-03  1.408e+04
# scale(WTP):treatmentE                       -3.055e-02  6.197e-03  1.488e+04
# scale(inv_d):treatmentA                     -1.815e-02  1.843e-02  5.484e+01
# scale(inv_d):treatmentE                     -6.094e-02  1.971e-02  5.527e+01
# scale(x0):treatmentA                         1.409e-01  1.445e-02  5.488e+01
# scale(x0):treatmentE                         1.500e-01  2.049e-02  5.477e+01
# scale(reflection):treatmentA                 2.132e-03  2.027e-02  5.483e+01
# scale(reflection):treatmentE                 4.345e-02  1.977e-02  5.562e+01
# scale(BNT):treatmentA                        9.393e-03  2.247e-02  5.494e+01
# scale(BNT):treatmentE                       -4.184e-02  1.727e-02  5.475e+01
# scale(NFC):treatmentA                        9.045e-03  1.998e-02  5.509e+01
# scale(NFC):treatmentE                       -5.589e-03  1.430e-02  5.499e+01
# scale(FI):treatmentA                        -1.290e-02  1.605e-02  5.477e+01
# scale(FI):treatmentE                         2.286e-02  1.830e-02  5.505e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.200e-02  5.158e-03  1.170e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.562e-02  5.296e-03  1.386e+04
# scale(inv_d):scale(x0):treatmentA            1.589e-02  2.039e-02  5.510e+01
# scale(inv_d):scale(x0):treatmentE           -8.702e-03  2.371e-02  5.468e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  41.233  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.021  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.898  < 2e-16 ***
# scale(WTP):treatmentA                        -0.685  0.49323
# scale(WTP):treatmentE                        -4.929 8.34e-07 ***
# scale(inv_d):treatmentA                      -0.984  0.32920
# scale(inv_d):treatmentE                      -3.092  0.00312 **
# scale(x0):treatmentA                          9.753 1.39e-13 ***
# scale(x0):treatmentE                          7.320 1.15e-09 ***
# scale(reflection):treatmentA                  0.105  0.91660
# scale(reflection):treatmentE                  2.198  0.03211 *
# scale(BNT):treatmentA                         0.418  0.67757
# scale(BNT):treatmentE                        -2.422  0.01877 *
# scale(NFC):treatmentA                         0.453  0.65261
# scale(NFC):treatmentE                        -0.391  0.69747
# scale(FI):treatmentA                         -0.804  0.42497
# scale(FI):treatmentE                          1.249  0.21682
# scale(lottery_favour):scale(WTP):treatmentA  -4.265 2.02e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.615  < 2e-16 ***
# scale(inv_d):scale(x0):treatmentA             0.779  0.43907
# scale(inv_d):scale(x0):treatmentE            -0.367  0.71500
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# All subjects; with psychometrics; with interaction
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18006.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4898 -0.9161  0.0363  0.8595  3.1740
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006115 0.0782
#  Residual             0.190625 0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  5.016e-01  1.328e-02  4.929e+01
# scale(lottery_favour):treatmentA             1.813e-01  6.022e-03  1.426e+04
# scale(lottery_favour):treatmentE             2.352e-01  6.734e-03  1.421e+04
# scale(WTP):treatmentA                       -3.805e-03  6.510e-03  1.385e+04
# scale(WTP):treatmentE                       -3.052e-02  6.195e-03  1.481e+04
# scale(inv_d):treatmentA                     -2.381e-02  1.877e-02  4.761e+01
# scale(inv_d):treatmentE                     -7.617e-02  2.224e-02  4.774e+01
# scale(x0):treatmentA                         1.409e-01  1.412e-02  4.749e+01
# scale(x0):treatmentE                         1.403e-01  2.079e-02  4.743e+01
# scale(reflection):treatmentA                 1.584e-02  1.950e-02  4.742e+01
# scale(reflection):treatmentE                 2.423e-02  1.969e-02  4.804e+01
# scale(BNT):treatmentA                        6.093e-04  2.091e-02  4.757e+01
# scale(BNT):treatmentE                       -2.742e-02  1.749e-02  4.741e+01
# scale(NFC):treatmentA                        1.266e-02  1.885e-02  4.775e+01
# scale(NFC):treatmentE                       -4.531e-03  1.375e-02  4.756e+01
# scale(FI):treatmentA                        -2.293e-04  1.659e-02  4.732e+01
# scale(FI):treatmentE                         1.919e-02  2.043e-02  4.743e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.279e-02  5.160e-03  1.133e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.503e-02  5.291e-03  1.337e+04
# scale(inv_d):scale(x0):treatmentA            1.859e-02  2.055e-02  4.784e+01
# scale(inv_d):scale(x0):treatmentE           -1.048e-02  3.041e-02  4.732e+01
# scale(inv_d):scale(reflection):treatmentA    8.920e-03  2.235e-02  4.737e+01
# scale(inv_d):scale(reflection):treatmentE    3.986e-02  1.947e-02  4.765e+01
# scale(inv_d):scale(BNT):treatmentA           2.180e-03  2.952e-02  4.750e+01
# scale(inv_d):scale(BNT):treatmentE          -7.783e-03  1.620e-02  4.747e+01
# scale(inv_d):scale(NFC):treatmentA           2.095e-02  1.893e-02  4.739e+01
# scale(inv_d):scale(NFC):treatmentE           3.462e-02  1.406e-02  4.736e+01
# scale(inv_d):scale(FI):treatmentA           -3.909e-02  1.799e-02  4.795e+01
# scale(inv_d):scale(FI):treatmentE            2.925e-02  3.144e-02  4.772e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  37.780  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.103  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.924  < 2e-16 ***
# scale(WTP):treatmentA                        -0.585  0.55887
# scale(WTP):treatmentE                        -4.926 8.47e-07 ***
# scale(inv_d):treatmentA                      -1.268  0.21082
# scale(inv_d):treatmentE                      -3.425  0.00127 **
# scale(x0):treatmentA                          9.981 3.04e-13 ***
# scale(x0):treatmentE                          6.747 1.90e-08 ***
# scale(reflection):treatmentA                  0.812  0.42072
# scale(reflection):treatmentE                  1.230  0.22455
# scale(BNT):treatmentA                         0.029  0.97687
# scale(BNT):treatmentE                        -1.568  0.12365
# scale(NFC):treatmentA                         0.671  0.50523
# scale(NFC):treatmentE                        -0.330  0.74322
# scale(FI):treatmentA                         -0.014  0.98903
# scale(FI):treatmentE                          0.939  0.35237
# scale(lottery_favour):scale(WTP):treatmentA  -4.416 1.01e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.512  < 2e-16 ***
# scale(inv_d):scale(x0):treatmentA             0.905  0.37010
# scale(inv_d):scale(x0):treatmentE            -0.345  0.73198
# scale(inv_d):scale(reflection):treatmentA     0.399  0.69166
# scale(inv_d):scale(reflection):treatmentE     2.047  0.04619 *
# scale(inv_d):scale(BNT):treatmentA            0.074  0.94144
# scale(inv_d):scale(BNT):treatmentE           -0.481  0.63301
# scale(inv_d):scale(NFC):treatmentA            1.106  0.27420
# scale(inv_d):scale(NFC):treatmentE            2.462  0.01752 *
# scale(inv_d):scale(FI):treatmentA            -2.173  0.03472 *
# scale(inv_d):scale(FI):treatmentE             0.930  0.35686
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Low-attention subjects removed

# %%
# Low-attention subjects removed; Baseline
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11184.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4624 -0.8669 -0.0513  0.8385  3.8008
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.006372 0.07983
#  Residual             0.168106 0.41001
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.559e-01  1.351e-02  4.375e+01
# scale(lottery_favour):treatmentA             2.382e-01  7.020e-03  1.019e+04
# scale(lottery_favour):treatmentE             2.871e-01  7.224e-03  9.707e+03
# scale(WTP):treatmentA                       -4.256e-02  7.585e-03  1.002e+04
# scale(WTP):treatmentE                       -7.637e-02  6.726e-03  1.025e+04
# scale(inv_d):treatmentA                     -2.273e-02  2.173e-02  4.168e+01
# scale(inv_d):treatmentE                     -5.371e-02  1.977e-02  4.197e+01
# scale(x0):treatmentA                         1.322e-01  1.773e-02  4.162e+01
# scale(x0):treatmentE                         1.746e-01  2.710e-02  4.164e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.155e-02  6.098e-03  8.023e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.560e-02  5.603e-03  9.192e+03
# scale(inv_d):scale(x0):treatmentA            2.084e-02  1.741e-02  4.198e+01
# scale(inv_d):scale(x0):treatmentE            1.325e-02  3.745e-02  4.173e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  33.742  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.927  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.748  < 2e-16 ***
# scale(WTP):treatmentA                        -5.611 2.07e-08 ***
# scale(WTP):treatmentE                       -11.355  < 2e-16 ***
# scale(inv_d):treatmentA                      -1.046  0.30138
# scale(inv_d):treatmentE                      -2.717  0.00954 **
# scale(x0):treatmentA                          7.458 3.42e-09 ***
# scale(x0):treatmentE                          6.444 9.47e-08 ***
# scale(lottery_favour):scale(WTP):treatmentA  -1.895  0.05819 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.355 2.19e-10 ***
# scale(inv_d):scale(x0):treatmentA             1.197  0.23793
# scale(inv_d):scale(x0):treatmentE             0.354  0.72533
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Low-attention subjects removed; with psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11216
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4732 -0.8706 -0.0462  0.8396  3.8077
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005042 0.071
#  Residual             0.168103 0.410
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.441e-01  1.352e-02  3.548e+01
# scale(lottery_favour):treatmentA             2.383e-01  7.021e-03  1.011e+04
# scale(lottery_favour):treatmentE             2.880e-01  7.248e-03  1.000e+04
# scale(WTP):treatmentA                       -4.261e-02  7.588e-03  9.928e+03
# scale(WTP):treatmentE                       -7.573e-02  6.739e-03  1.033e+04
# scale(inv_d):treatmentA                      3.986e-03  2.417e-02  3.403e+01
# scale(inv_d):treatmentE                     -3.254e-02  2.176e-02  3.520e+01
# scale(x0):treatmentA                         1.541e-01  1.938e-02  3.404e+01
# scale(x0):treatmentE                         1.279e-01  3.021e-02  3.434e+01
# scale(reflection):treatmentA                 2.603e-02  2.499e-02  3.415e+01
# scale(reflection):treatmentE                 7.306e-02  2.247e-02  3.516e+01
# scale(BNT):treatmentA                        1.288e-03  2.682e-02  3.425e+01
# scale(BNT):treatmentE                       -2.873e-02  1.808e-02  3.405e+01
# scale(NFC):treatmentA                       -1.308e-02  2.117e-02  3.413e+01
# scale(NFC):treatmentE                       -2.258e-02  1.413e-02  3.398e+01
# scale(FI):treatmentA                         3.593e-02  1.917e-02  3.464e+01
# scale(FI):treatmentE                         4.629e-02  1.962e-02  3.480e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.085e-02  6.105e-03  7.781e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.676e-02  5.622e-03  9.546e+03
# scale(inv_d):scale(x0):treatmentA            8.672e-03  1.685e-02  3.459e+01
# scale(inv_d):scale(x0):treatmentE            4.525e-02  3.953e-02  3.444e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  32.847  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.947  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.733  < 2e-16 ***
# scale(WTP):treatmentA                        -5.616 2.01e-08 ***
# scale(WTP):treatmentE                       -11.238  < 2e-16 ***
# scale(inv_d):treatmentA                       0.165 0.869986
# scale(inv_d):treatmentE                      -1.496 0.143675
# scale(x0):treatmentA                          7.952 2.87e-09 ***
# scale(x0):treatmentE                          4.234 0.000162 ***
# scale(reflection):treatmentA                  1.042 0.304956
# scale(reflection):treatmentE                  3.252 0.002531 **
# scale(BNT):treatmentA                         0.048 0.961983
# scale(BNT):treatmentE                        -1.589 0.121345
# scale(NFC):treatmentA                        -0.618 0.540661
# scale(NFC):treatmentE                        -1.598 0.119295
# scale(FI):treatmentA                          1.874 0.069335 .
# scale(FI):treatmentE                          2.359 0.024084 *
# scale(lottery_favour):scale(WTP):treatmentA  -1.777 0.075659 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.538 6.54e-11 ***
# scale(inv_d):scale(x0):treatmentA             0.515 0.610014
# scale(inv_d):scale(x0):treatmentE             1.145 0.260253
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Low-attention subjects removed; with psychometrics; with interaction
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(inv_d)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) + scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(inv_d) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(inv_d):scale(reflection) + scale(inv_d):scale(BNT) +
#     scale(inv_d):scale(NFC) + scale(inv_d):scale(FI)):treatment +
#     (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11248.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4799 -0.8653 -0.0444  0.8381  3.7969
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004095 0.06399
#  Residual             0.168102 0.41000
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.717e-01  1.540e-02  2.700e+01
# scale(lottery_favour):treatmentA             2.385e-01  7.019e-03  9.915e+03
# scale(lottery_favour):treatmentE             2.880e-01  7.247e-03  9.790e+03
# scale(WTP):treatmentA                       -4.235e-02  7.582e-03  9.567e+03
# scale(WTP):treatmentE                       -7.579e-02  6.738e-03  1.025e+04
# scale(inv_d):treatmentA                      2.347e-03  2.650e-02  2.620e+01
# scale(inv_d):treatmentE                     -5.295e-02  2.259e-02  2.661e+01
# scale(x0):treatmentA                         1.566e-01  2.199e-02  2.609e+01
# scale(x0):treatmentE                         1.479e-01  3.092e-02  2.605e+01
# scale(reflection):treatmentA                 4.783e-02  2.518e-02  2.613e+01
# scale(reflection):treatmentE                 2.597e-02  2.521e-02  2.651e+01
# scale(BNT):treatmentA                       -1.805e-02  2.831e-02  2.616e+01
# scale(BNT):treatmentE                       -1.165e-02  1.810e-02  2.615e+01
# scale(NFC):treatmentA                       -1.946e-02  2.133e-02  2.621e+01
# scale(NFC):treatmentE                       -2.264e-02  1.355e-02  2.608e+01
# scale(FI):treatmentA                         3.695e-02  2.350e-02  2.611e+01
# scale(FI):treatmentE                         1.945e-02  2.532e-02  2.609e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.116e-02  6.102e-03  7.026e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.652e-02  5.616e-03  8.976e+03
# scale(inv_d):scale(x0):treatmentA            1.676e-02  1.664e-02  2.641e+01
# scale(inv_d):scale(x0):treatmentE            7.032e-03  4.515e-02  2.594e+01
# scale(inv_d):scale(reflection):treatmentA    4.073e-02  3.701e-02  2.613e+01
# scale(inv_d):scale(reflection):treatmentE    4.972e-02  1.868e-02  2.606e+01
# scale(inv_d):scale(BNT):treatmentA          -2.703e-02  4.534e-02  2.606e+01
# scale(inv_d):scale(BNT):treatmentE           2.488e-03  1.604e-02  2.603e+01
# scale(inv_d):scale(NFC):treatmentA          -2.662e-02  2.945e-02  2.629e+01
# scale(inv_d):scale(NFC):treatmentE           2.169e-02  1.307e-02  2.595e+01
# scale(inv_d):scale(FI):treatmentA           -1.982e-02  2.735e-02  2.616e+01
# scale(inv_d):scale(FI):treatmentE            4.306e-02  3.124e-02  2.622e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  30.631  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.981  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.733  < 2e-16 ***
# scale(WTP):treatmentA                        -5.586 2.39e-08 ***
# scale(WTP):treatmentE                       -11.249  < 2e-16 ***
# scale(inv_d):treatmentA                       0.089   0.9301
# scale(inv_d):treatmentE                      -2.344   0.0268 *
# scale(x0):treatmentA                          7.119 1.44e-07 ***
# scale(x0):treatmentE                          4.782 5.95e-05 ***
# scale(reflection):treatmentA                  1.899   0.0686 .
# scale(reflection):treatmentE                  1.030   0.3122
# scale(BNT):treatmentA                        -0.638   0.5292
# scale(BNT):treatmentE                        -0.644   0.5254
# scale(NFC):treatmentA                        -0.912   0.3700
# scale(NFC):treatmentE                        -1.670   0.1069
# scale(FI):treatmentA                          1.572   0.1280
# scale(FI):treatmentE                          0.768   0.4492
# scale(lottery_favour):scale(WTP):treatmentA  -1.829   0.0674 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.502 8.35e-11 ***
# scale(inv_d):scale(x0):treatmentA             1.007   0.3230
# scale(inv_d):scale(x0):treatmentE             0.156   0.8774
# scale(inv_d):scale(reflection):treatmentA     1.101   0.2811
# scale(inv_d):scale(reflection):treatmentE     2.662   0.0131 *
# scale(inv_d):scale(BNT):treatmentA           -0.596   0.5562
# scale(inv_d):scale(BNT):treatmentE            0.155   0.8779
# scale(inv_d):scale(NFC):treatmentA           -0.904   0.3743
# scale(inv_d):scale(NFC):treatmentE            1.660   0.1089
# scale(inv_d):scale(FI):treatmentA            -0.725   0.4749
# scale(inv_d):scale(FI):treatmentE             1.378   0.1797
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # RT analysis

# %%
# all subjects 
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45378.7  45439.6 -22681.4  45362.7    14979
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4641 -0.6078 -0.2815  0.2766 12.8588
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2449   0.4949
#  Residual             0.3978   0.6307
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.319506   0.127422  18.203  < 2e-16 ***
# scale(value_diff)            -0.047105   0.008963  -5.255 1.48e-07 ***
# scale(WTP)                   -0.014622   0.010495  -1.393   0.1635
# slc_lot                       0.045320   0.018174   2.494   0.0126 *
# treatmentE                    0.194103   0.179544   1.081   0.2797
# scale(value_diff):scale(WTP)  0.029356   0.007086   4.143 3.43e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt trtmnE
# scl(vl_dff) -0.010
# scale(WTP)   0.016 -0.247
# slc_lot     -0.066  0.059 -0.023
# treatmentE  -0.707  0.008 -0.018  0.002
# sc(_):(WTP) -0.001 -0.177 -0.175 -0.126 -0.005
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot):treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45365.3  45449.0 -22671.6  45343.3    14976
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4657 -0.6080 -0.2821  0.2771 12.9894
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2477   0.4977
#  Residual             0.3967   0.6299
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.408254   0.090712  26.548  < 2e-16
# scale(value_diff):treatmentA            -0.027843   0.011680  -2.384  0.01713
# scale(value_diff):treatmentE            -0.095723   0.015094  -6.342 2.27e-10
# scale(WTP):treatmentA                   -0.040187   0.014954  -2.687  0.00720
# scale(WTP):treatmentE                    0.014633   0.014612   1.001  0.31661
# slc_lot:treatmentA                       0.026113   0.024462   1.067  0.28575
# slc_lot:treatmentE                       0.074381   0.027223   2.732  0.00629
# scale(value_diff):scale(WTP):treatmentA  0.023463   0.009495   2.471  0.01347
# scale(value_diff):scale(WTP):treatmentE  0.053258   0.011513   4.626 3.73e-06
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      **
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E slc_:A slc_:E s(_):(WTP):A
# scl(vl_d):A  -0.010
# scl(vl_d):E   0.005  0.000
# scl(WTP):tA   0.015 -0.229  0.000
# scl(WTP):tE  -0.007  0.000 -0.248  0.000
# slc_lt:trtA  -0.064  0.103  0.000 -0.041    0.000
# slc_lt:trtE  -0.064  0.001  0.012 -0.001   -0.010    0.004
# s(_):(WTP):A -0.004 -0.029  0.000 -0.203    0.000   -0.110  0.000
# s(_):(WTP):E -0.008  0.000 -0.409  0.000   -0.119    0.001 -0.123  0.000

# %%
# all subjects; with Psychometrics
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45380.1  45471.5 -22678.1  45356.1    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4646 -0.6088 -0.2814  0.2765 12.8728
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2236   0.4728
#  Residual             0.3975   0.6305
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.326496   0.122877  18.934  < 2e-16 ***
# scale(value_diff)            -0.047012   0.008964  -5.244 1.57e-07 ***
# scale(WTP)                   -0.014544   0.010495  -1.386    0.166
# slc_lot                       0.045162   0.018174   2.485    0.013 *
# scale(reflection)             0.168181   0.104273   1.613    0.107
# scale(BNT)                    0.031737   0.102258   0.310    0.756
# scale(NFC)                    0.046864   0.087230   0.537    0.591
# scale(FI)                    -0.078107   0.086947  -0.898    0.369
# treatmentE                    0.173590   0.175089   0.991    0.321
# scale(value_diff):scale(WTP)  0.029380   0.007087   4.145 3.39e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt scl(r) s(BNT) s(NFC) sc(FI) trtmnE
# scl(vl_dff) -0.010
# scale(WTP)   0.016 -0.247
# slc_lot     -0.069  0.059 -0.023
# scl(rflctn)  0.104  0.004  0.001 -0.006
# scale(BNT)  -0.131  0.003  0.001  0.000 -0.538
# scale(NFC)  -0.067 -0.003  0.010  0.002 -0.140  0.086
# scale(FI)   -0.031  0.001  0.002 -0.003  0.140  0.011  0.051
# treatmentE  -0.715  0.008 -0.018  0.003 -0.158  0.181  0.091  0.045
# sc(_):(WTP) -0.002 -0.177 -0.174 -0.126 -0.002  0.002  0.004  0.000 -0.005
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0020962 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45370.0  45514.7 -22666.0  45332.0    14968
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4668 -0.6086 -0.2822  0.2742 13.0036
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2121   0.4605
#  Residual             0.3966   0.6298
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.426198   0.085690  28.314  < 2e-16
# scale(value_diff):treatmentA            -0.027854   0.011681  -2.384  0.01710
# scale(value_diff):treatmentE            -0.095575   0.015102  -6.329 2.48e-10
# scale(WTP):treatmentA                   -0.040181   0.014951  -2.688  0.00720
# scale(WTP):treatmentE                    0.015097   0.014614   1.033  0.30156
# slc_lot:treatmentA                       0.026202   0.024459   1.071  0.28404
# slc_lot:treatmentE                       0.074095   0.027212   2.723  0.00647
# scale(reflection):treatmentA             0.231559   0.151878   1.525  0.12735
# scale(reflection):treatmentE             0.222120   0.141818   1.566  0.11729
# scale(BNT):treatmentA                   -0.223192   0.169947  -1.313  0.18908
# scale(BNT):treatmentE                    0.155500   0.126749   1.227  0.21988
# scale(NFC):treatmentA                    0.094572   0.148766   0.636  0.52496
# scale(NFC):treatmentE                    0.060253   0.106462   0.566  0.57142
# scale(FI):treatmentA                    -0.121755   0.116928  -1.041  0.29774
# scale(FI):treatmentE                    -0.043760   0.124674  -0.351  0.72559
# scale(value_diff):scale(WTP):treatmentA  0.023525   0.009498   2.477  0.01325
# scale(value_diff):scale(WTP):treatmentE  0.053246   0.011522   4.621 3.81e-06
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      **
# scale(reflection):treatmentA
# scale(reflection):treatmentE
# scale(BNT):treatmentA
# scale(BNT):treatmentE
# scale(NFC):treatmentA
# scale(NFC):treatmentE
# scale(FI):treatmentA
# scale(FI):treatmentE
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# convergence code: 0
# Model failed to converge with max|grad| = 0.0020962 (tol = 0.001, component 1)

# %%
# all subjects; adding the variable "correct" –– whether the higher values option is chosen.
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + correct + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + correct):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + correct + treatment +
#     (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45169.1  45237.6 -22575.5  45151.1    14918
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4652 -0.6064 -0.2789  0.2750 13.5606
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2460   0.4959
#  Residual             0.3979   0.6308
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.359132   0.128054  18.423  < 2e-16 ***
# scale(value_diff)            -0.042014   0.009099  -4.618 3.88e-06 ***
# scale(WTP)                   -0.018101   0.010520  -1.721 0.085322 .
# slc_lot                       0.061070   0.018830   3.243 0.001182 **
# correct                      -0.071648   0.019470  -3.680 0.000233 ***
# treatmentE                    0.193148   0.179735   1.075 0.282542
# scale(value_diff):scale(WTP)  0.027435   0.007175   3.824 0.000131 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt corrct trtmnE
# scl(vl_dff)  0.004
# scale(WTP)   0.011 -0.250
# slc_lot     -0.042  0.093 -0.045
# correct     -0.085 -0.152  0.063 -0.248
# treatmentE  -0.704  0.007 -0.018  0.001  0.001
# sc(_):(WTP) -0.009 -0.194 -0.168 -0.156  0.098 -0.005
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot + correct):treatment +
#     (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#    45156    45255   -22565    45130    14914
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4674 -0.6078 -0.2793  0.2723 13.4339
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2494   0.4994
#  Residual             0.3967   0.6298
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.449676   0.091729  26.706  < 2e-16
# scale(value_diff):treatmentA            -0.025025   0.011779  -2.124 0.033629
# scale(value_diff):treatmentE            -0.085573   0.015490  -5.524 3.31e-08
# scale(WTP):treatmentA                   -0.039901   0.014964  -2.666 0.007665
# scale(WTP):treatmentE                    0.005161   0.014759   0.350 0.726565
# slc_lot:treatmentA                       0.030457   0.024635   1.236 0.216341
# slc_lot:treatmentE                       0.115117   0.030273   3.803 0.000143
# correct:treatmentA                      -0.051341   0.025453  -2.017 0.043688
# correct:treatmentE                      -0.104368   0.031207  -3.344 0.000825
# scale(value_diff):scale(WTP):treatmentA  0.022118   0.009572   2.311 0.020844
# scale(value_diff):scale(WTP):treatmentE  0.048413   0.011757   4.118 3.82e-05
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      ***
# correct:treatmentA                      *
# correct:treatmentE                      ***
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E slc_:A slc_:E crrc:A crrc:E
# scl(vl_d):A   0.000
# scl(vl_d):E   0.022  0.000
# scl(WTP):tA   0.016 -0.228  0.000
# scl(WTP):tE  -0.019  0.000 -0.262  0.000
# slc_lt:trtA  -0.055  0.112 -0.001 -0.046    0.001
# slc_lt:trtE  -0.021  0.000  0.100  0.000   -0.085    0.001
# crrct:trtmA  -0.088 -0.117 -0.002 -0.007    0.002   -0.096  0.002
# crrct:trtmE  -0.086  0.000 -0.210 -0.001    0.151    0.005 -0.428  0.007
# s(_):(WTP):A -0.010 -0.037  0.000 -0.205    0.000   -0.124  0.000  0.069  0.001
# s(_):(WTP):E -0.021  0.000 -0.434  0.000   -0.091    0.001 -0.196  0.002  0.172
#              s(_):(WTP):A
# scl(vl_d):A
# scl(vl_d):E
# scl(WTP):tA
# scl(WTP):tE
# slc_lt:trtA
# slc_lt:trtE
# crrct:trtmA
# crrct:trtmE
# s(_):(WTP):A
# s(_):(WTP):E  0.000

# %%
# all subjects; adding the variable "correct"; with Psychometrics
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + correct + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + correct + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula:
# RT ~ scale(value_diff) * scale(WTP) + slc_lot + correct + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45170.4  45269.3 -22572.2  45144.4    14914
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4658 -0.6067 -0.2797  0.2751 13.5779
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2243   0.4736
#  Residual             0.3976   0.6305
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.366563   0.123446  19.171  < 2e-16 ***
# scale(value_diff)            -0.041908   0.009100  -4.605 4.12e-06 ***
# scale(WTP)                   -0.018030   0.010521  -1.714 0.086570 .
# slc_lot                       0.060976   0.018830   3.238 0.001203 **
# correct                      -0.071870   0.019471  -3.691 0.000223 ***
# scale(reflection)             0.170849   0.104394   1.637 0.101720
# scale(BNT)                    0.031609   0.102373   0.309 0.757499
# scale(NFC)                    0.044813   0.087339   0.513 0.607886
# scale(FI)                    -0.077360   0.087047  -0.889 0.374151
# treatmentE                    0.171959   0.175167   0.982 0.326254
# scale(value_diff):scale(WTP)  0.027444   0.007177   3.824 0.000131 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt corrct scl(r) s(BNT) s(NFC) sc(FI)
# scl(vl_dff)  0.004
# scale(WTP)   0.011 -0.250
# slc_lot     -0.044  0.093 -0.045
# correct     -0.089 -0.152  0.063 -0.248
# scl(rflctn)  0.104  0.005  0.002 -0.004 -0.006
# scale(BNT)  -0.130  0.003  0.001  0.000 -0.002 -0.538
# scale(NFC)  -0.067 -0.004  0.010  0.001  0.005 -0.140  0.086
# scale(FI)   -0.030  0.001  0.002 -0.003 -0.003  0.140  0.011  0.051
# treatmentE  -0.712  0.007 -0.017  0.002  0.001 -0.158  0.181  0.091  0.045
# sc(_):(WTP) -0.010 -0.194 -0.168 -0.156  0.098 -0.003  0.002  0.004  0.000
#             trtmnE
# scl(vl_dff)
# scale(WTP)
# slc_lot
# correct
# scl(rflctn)
# scale(BNT)
# scale(NFC)
# scale(FI)
# treatmentE
# sc(_):(WTP) -0.004
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0123998 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula:
# RT ~ (scale(value_diff) * scale(WTP) + slc_lot + correct + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45160.6  45320.5 -22559.3  45118.6    14906
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4685 -0.6090 -0.2795  0.2726 13.4431
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2132   0.4617
#  Residual             0.3966   0.6297
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.467526   0.086634  28.482  < 2e-16
# scale(value_diff):treatmentA            -0.025088   0.011781  -2.130 0.033210
# scale(value_diff):treatmentE            -0.085367   0.015493  -5.510 3.59e-08
# scale(WTP):treatmentA                   -0.039808   0.014962  -2.661 0.007802
# scale(WTP):treatmentE                    0.005556   0.014759   0.376 0.706574
# slc_lot:treatmentA                       0.030404   0.024633   1.234 0.217108
# slc_lot:treatmentE                       0.115464   0.030271   3.814 0.000137
# correct:treatmentA                      -0.050832   0.025440  -1.998 0.045708
# correct:treatmentE                      -0.105587   0.031192  -3.385 0.000712
# scale(reflection):treatmentA             0.234851   0.152286   1.542 0.123032
# scale(reflection):treatmentE             0.227869   0.142258   1.602 0.109200
# scale(BNT):treatmentA                   -0.225238   0.170414  -1.322 0.186263
# scale(BNT):treatmentE                    0.154046   0.127102   1.212 0.225519
# scale(NFC):treatmentA                    0.090544   0.149217   0.607 0.543987
# scale(NFC):treatmentE                    0.056938   0.106760   0.533 0.593806
# scale(FI):treatmentA                    -0.121934   0.117270  -1.040 0.298445
# scale(FI):treatmentE                    -0.045152   0.124996  -0.361 0.717927
# scale(value_diff):scale(WTP):treatmentA  0.022153   0.009574   2.314 0.020674
# scale(value_diff):scale(WTP):treatmentE  0.048399   0.011764   4.114 3.89e-05
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      ***
# correct:treatmentA                      *
# correct:treatmentE                      ***
# scale(reflection):treatmentA
# scale(reflection):treatmentE
# scale(BNT):treatmentA
# scale(BNT):treatmentE
# scale(NFC):treatmentA
# scale(NFC):treatmentE
# scale(FI):treatmentA
# scale(FI):treatmentE
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# convergence code: 0
# Model failed to converge with max|grad| = 0.0123998 (tol = 0.001, component 1)

# %% [markdown]
# # Others

# %% [markdown]
# ### Is the chance of choosing lottery affected by the treatments?

# %%
# All subjects
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16845.0  16890.7  -8416.5  16833.0    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1540 -0.7438 -0.1979  0.7181 17.7392
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8703   0.9329
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.12833    0.15833   0.811 0.417648
# scale(lottery_favour)             1.24103    0.03118  39.801  < 2e-16 ***
# scale(WTP)                       -0.08056    0.02384  -3.379 0.000728 ***
# treatmentE                       -0.40198    0.22339  -1.799 0.071945 .
# scale(lottery_favour):scale(WTP) -0.27586    0.02244 -12.292  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE
# scl(lttry_)  0.025
# scale(WTP)   0.038 -0.233
# treatmentE  -0.707 -0.031 -0.022
# sc(_):(WTP) -0.068 -0.371 -0.314  0.019

# %%
# All subjects; with Psychometrics
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16850.9  16927.0  -8415.4  16830.9    14977
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1803 -0.7442 -0.1977  0.7183 17.7803
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8436   0.9185
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.1282165  0.1577926   0.813 0.416468
# scale(lottery_favour)             1.2411462  0.0311809  39.805  < 2e-16 ***
# scale(WTP)                       -0.0804726  0.0238446  -3.375 0.000738 ***
# treatmentE                       -0.4040923  0.2252076  -1.794 0.072764 .
# scale(reflection)                 0.1332791  0.1338372   0.996 0.319333
# scale(BNT)                       -0.0006868  0.1318530  -0.005 0.995844
# scale(NFC)                        0.0479105  0.1118494   0.428 0.668398
# scale(FI)                         0.1058278  0.1120720   0.944 0.345025
# scale(lottery_favour):scale(WTP) -0.2756304  0.0224418 -12.282  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE scl(r) s(BNT) s(NFC) sc(FI)
# scl(lttry_)  0.024
# scale(WTP)   0.037 -0.233
# treatmentE  -0.715 -0.031 -0.020
# scl(rflctn)  0.109  0.008  0.000 -0.158
# scale(BNT)  -0.132 -0.002  0.000  0.182 -0.537
# scale(NFC)  -0.066  0.016  0.014  0.093 -0.140  0.088
# scale(FI)   -0.033  0.005  0.001  0.044  0.137  0.014  0.049
# sc(_):(WTP) -0.069 -0.370 -0.313  0.019 -0.002  0.007 -0.007  0.004

# %% [markdown]
# ### Is the decision consistency affected by the treatments?

# %%
# All subjects
summary(glmer(incorrect ~ scale(value_diff)*scale(WTP) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: incorrect ~ scale(value_diff) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17689.2  17734.8  -8838.6  17677.2    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8171 -0.7271 -0.4535  0.9741  7.9536
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.51     0.7141
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -0.79510    0.12220  -6.506 7.70e-11 ***
# scale(value_diff)            -0.52918    0.02458 -21.528  < 2e-16 ***
# scale(WTP)                    0.16560    0.02148   7.709 1.26e-14 ***
# treatmentE                   -0.01444    0.17254  -0.084    0.933
# scale(value_diff):scale(WTP)  0.17677    0.01746  10.122  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE
# scl(vl_dff)  0.043
# scale(WTP)   0.014 -0.321
# treatmentE  -0.706  0.004 -0.032
# sc(_):(WTP) -0.058 -0.385 -0.054  0.000

# %%
# All subjects; with Psychometrics
summary(glmer(incorrect ~ scale(value_diff)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: incorrect ~ scale(value_diff) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17679.5  17755.6  -8829.7  17659.5    14977
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8230 -0.7279 -0.4537  0.9761  7.8397
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.3951   0.6286
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -0.803011   0.109653  -7.323 2.42e-13 ***
# scale(value_diff)            -0.528724   0.024575 -21.514  < 2e-16 ***
# scale(WTP)                    0.164999   0.021458   7.689 1.48e-14 ***
# scale(reflection)            -0.283632   0.093129  -3.046  0.00232 **
# scale(BNT)                   -0.082866   0.091772  -0.903  0.36655
# scale(NFC)                    0.088709   0.077806   1.140  0.25424
# scale(FI)                    -0.133317   0.077742  -1.715  0.08637 .
# treatmentE                    0.006196   0.156585   0.040  0.96843
# scale(value_diff):scale(WTP)  0.176919   0.017456  10.135  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) scl(r) s(BNT) s(NFC) sc(FI) trtmnE
# scl(vl_dff)  0.048
# scale(WTP)   0.014 -0.321
# scl(rflctn)  0.112  0.008  0.001
# scale(BNT)  -0.131  0.008  0.001 -0.534
# scale(NFC)  -0.067 -0.006  0.024 -0.140  0.086
# scale(FI)   -0.032  0.002  0.002  0.138  0.018  0.049
# treatmentE  -0.714  0.005 -0.033 -0.157  0.183  0.092  0.047
# sc(_):(WTP) -0.065 -0.385 -0.054 -0.006  0.001  0.010  0.000  0.001

# %% [markdown]
# ### Decision consistency and value difference

# %%
# All subjects
summary(lmer(incorrect ~ (scale(value_diff)*scale(WTP)):treatment + (1|subject), data1))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: incorrect ~ (scale(value_diff) * scale(WTP)):treatment + (1 |
#     subject)
#    Data: data1
#
# REML criterion at convergence: 18671.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.6475 -0.7884 -0.4099  1.1035  2.4895
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02039  0.1428
#  Residual             0.19981  0.4470
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              3.334e-01  1.726e-02  7.146e+01
# scale(value_diff):treatmentA            -8.291e-02  5.320e-03  1.497e+04
# scale(value_diff):treatmentE            -1.060e-01  6.228e-03  1.496e+04
# scale(WTP):treatmentA                    6.321e-03  6.336e-03  1.477e+04
# scale(WTP):treatmentE                    4.947e-02  5.906e-03  1.496e+04
# scale(value_diff):scale(WTP):treatmentA  1.590e-02  4.484e-03  1.497e+04
# scale(value_diff):scale(WTP):treatmentE  3.947e-02  4.734e-03  1.498e+04
#                                         t value Pr(>|t|)
# (Intercept)                              19.321  < 2e-16 ***
# scale(value_diff):treatmentA            -15.584  < 2e-16 ***
# scale(value_diff):treatmentE            -17.020  < 2e-16 ***
# scale(WTP):treatmentA                     0.998 0.318497
# scale(WTP):treatmentE                     8.376  < 2e-16 ***
# scale(value_diff):scale(WTP):treatmentA   3.546 0.000392 ***
# scale(value_diff):scale(WTP):treatmentE   8.336  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E s(_):(WTP):A
# scl(vl_d):A  -0.007
# scl(vl_d):E   0.023  0.000
# scl(WTP):tA   0.032 -0.247  0.001
# scl(WTP):tE  -0.018  0.000 -0.269 -0.001
# s(_):(WTP):A -0.033  0.061 -0.001 -0.219    0.001
# s(_):(WTP):E -0.043  0.000 -0.375 -0.001   -0.132    0.001

# %%
# All subjects; with Psychometrics
summary(lmer(incorrect ~ (scale(value_diff)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: incorrect ~ (scale(value_diff) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18699.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.6448 -0.7876 -0.4071  1.1023  2.4746
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.01807  0.1344
#  Residual             0.19981  0.4470
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              3.340e-01  1.671e-02  6.341e+01
# scale(value_diff):treatmentA            -8.313e-02  5.320e-03  1.497e+04
# scale(value_diff):treatmentE            -1.057e-01  6.228e-03  1.496e+04
# scale(WTP):treatmentA                    6.772e-03  6.334e-03  1.466e+04
# scale(WTP):treatmentE                    4.899e-02  5.908e-03  1.495e+04
# scale(reflection):treatmentA            -4.151e-02  2.961e-02  6.285e+01
# scale(reflection):treatmentE            -6.080e-02  2.777e-02  6.295e+01
# scale(BNT):treatmentA                   -2.886e-02  3.340e-02  6.296e+01
# scale(BNT):treatmentE                   -1.205e-02  2.476e-02  6.286e+01
# scale(NFC):treatmentA                    4.555e-02  2.900e-02  6.292e+01
# scale(NFC):treatmentE                    3.193e-03  2.074e-02  6.295e+01
# scale(FI):treatmentA                    -1.788e-02  2.279e-02  6.289e+01
# scale(FI):treatmentE                    -3.061e-02  2.456e-02  6.293e+01
# scale(value_diff):scale(WTP):treatmentA  1.590e-02  4.484e-03  1.497e+04
# scale(value_diff):scale(WTP):treatmentE  3.942e-02  4.734e-03  1.497e+04
#                                         t value Pr(>|t|)
# (Intercept)                              19.991  < 2e-16 ***
# scale(value_diff):treatmentA            -15.626  < 2e-16 ***
# scale(value_diff):treatmentE            -16.976  < 2e-16 ***
# scale(WTP):treatmentA                     1.069 0.285021
# scale(WTP):treatmentE                     8.292  < 2e-16 ***
# scale(reflection):treatmentA             -1.402 0.165927
# scale(reflection):treatmentE             -2.190 0.032271 *
# scale(BNT):treatmentA                    -0.864 0.390928
# scale(BNT):treatmentE                    -0.487 0.628186
# scale(NFC):treatmentA                     1.571 0.121288
# scale(NFC):treatmentE                     0.154 0.878149
# scale(FI):treatmentA                     -0.784 0.435787
# scale(FI):treatmentE                     -1.246 0.217318
# scale(value_diff):scale(WTP):treatmentA   3.545 0.000394 ***
# scale(value_diff):scale(WTP):treatmentE   8.328  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
