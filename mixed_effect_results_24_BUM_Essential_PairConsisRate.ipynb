# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)
library(tidyr)
library(broom)

# %% [markdown]
# # Results to be presented in the paper (DDM parameters from  AM_n001_10s_B1)

# %% [markdown]
# ## Load data and preprocessing

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Cognitive Imprecision/Z1C Dataset_BU/trialsBUM_10s.csv", header=TRUE, sep=",")

data_raw$logRT <- log(1 + data_raw$RT)

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data1 <- subset(data_raw, RT > .3 & RT < 10)

# create another dataset in wh subjects with error_choice > 5 are rejected
data2 <- subset(data1, error_choice <= 5)

# split data by whether the subject has a positive or negative pre-evaluation bias
# L: risk-lover; H: risk-hater
data1L <- subset(data1, x0 > 0)
data1H <- subset(data1, x0 < 0)

data2L <- subset(data2, x0 > 0)
data2H <- subset(data2, x0 < 0)

# %%
names(data1)
# Out:
#  [1] "subject"         "trial"           "treatment"       "lot_code"
#  [5] "risk"            "reward"          "WTP"             "certainty"
#  [9] "RT"              "choice"          "slc_lot"         "display"
# [13] "correct"         "incorrect"       "decmode"         "reflection"
# [17] "intuition"       "BNT"             "NFC"             "FI"
# [21] "value_diff"      "value_sum"       "lottery_favour"  "lot_correct"
# [25] "error_choice"    "accuracy"        "risk_level"      "d"
# [29] "B"               "x0"              "nondectime"      "inv_d"
# [33] "pairs"           "pai_consis"      "pai_consis_rate" "NPCR"
# [37] "logRT"

# %% [markdown]
# ###  All continuous variables are scaled due to the inclusion of interactive terms and to avoid the error "Model failed to converge with max|grad|".

# %% [markdown]
# # Split by the pre-evaluation bias

# %%
# Split the dataset; Baseline
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 7997.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4139 -1.0554  0.3719  0.7859  3.0795
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.01302  0.1141
#  Residual             0.19829  0.4453
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.130e-01  3.541e-02  2.375e+01
# scale(lottery_favour):treatmentA             1.899e-01  8.309e-03  6.347e+03
# scale(lottery_favour):treatmentE             2.441e-01  1.382e-02  6.280e+03
# scale(WTP):treatmentA                        2.196e-02  8.742e-03  6.353e+03
# scale(WTP):treatmentE                        9.402e-03  1.181e-02  6.421e+03
# scale(NPCR):treatmentA                      -6.042e-02  5.650e-02  2.316e+01
# scale(NPCR):treatmentE                      -2.809e-02  1.033e-01  2.337e+01
# scale(x0):treatmentA                         5.189e-02  4.609e-02  2.318e+01
# scale(x0):treatmentE                         1.000e-01  2.152e-01  2.323e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.292e-02  7.298e-03  6.339e+03
# scale(lottery_favour):scale(WTP):treatmentE -6.965e-02  9.731e-03  6.199e+03
# scale(NPCR):scale(x0):treatmentA            -3.110e-02  5.127e-02  2.325e+01
# scale(NPCR):scale(x0):treatmentE            -7.602e-03  3.480e-01  2.321e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  17.314 5.71e-15 ***
# scale(lottery_favour):treatmentA             22.854  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.659  < 2e-16 ***
# scale(WTP):treatmentA                         2.512    0.012 *
# scale(WTP):treatmentE                         0.796    0.426
# scale(NPCR):treatmentA                       -1.069    0.296
# scale(NPCR):treatmentE                       -0.272    0.788
# scale(x0):treatmentA                          1.126    0.272
# scale(x0):treatmentE                          0.465    0.646
# scale(lottery_favour):scale(WTP):treatmentA  -7.251 4.63e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.157 9.19e-13 ***
# scale(NPCR):scale(x0):treatmentA             -0.607    0.550
# scale(NPCR):scale(x0):treatmentE             -0.022    0.983
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9924.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2297 -0.8399 -0.2908  0.9363  3.2251
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.008066 0.08981
#  Residual             0.183298 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.721e-01  1.929e-02  3.518e+01
# scale(lottery_favour):treatmentA             1.744e-01  8.879e-03  8.517e+03
# scale(lottery_favour):treatmentE             2.333e-01  7.614e-03  8.265e+03
# scale(WTP):treatmentA                       -3.784e-02  9.919e-03  8.368e+03
# scale(WTP):treatmentE                       -4.585e-02  7.201e-03  8.466e+03
# scale(NPCR):treatmentA                      -9.780e-03  5.311e-02  3.403e+01
# scale(NPCR):treatmentE                      -6.214e-02  4.748e-02  3.372e+01
# scale(x0):treatmentA                         1.349e-01  3.256e-02  3.413e+01
# scale(x0):treatmentE                         1.375e-01  2.474e-02  3.383e+01
# scale(lottery_favour):scale(WTP):treatmentA  9.916e-03  7.446e-03  6.366e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.540e-02  6.272e-03  7.890e+03
# scale(NPCR):scale(x0):treatmentA             4.741e-02  4.341e-02  3.482e+01
# scale(NPCR):scale(x0):treatmentE             4.313e-02  4.219e-02  3.377e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  19.285  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.646  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.645  < 2e-16 ***
# scale(WTP):treatmentA                        -3.815 0.000137 ***
# scale(WTP):treatmentE                        -6.367 2.03e-10 ***
# scale(NPCR):treatmentA                       -0.184 0.855001
# scale(NPCR):treatmentE                       -1.309 0.199400
# scale(x0):treatmentA                          4.144 0.000213 ***
# scale(x0):treatmentE                          5.558 3.28e-06 ***
# scale(lottery_favour):scale(WTP):treatmentA   1.332 0.183009
# scale(lottery_favour):scale(WTP):treatmentE  -5.644 1.72e-08 ***
# scale(NPCR):scale(x0):treatmentA              1.092 0.282308
# scale(NPCR):scale(x0):treatmentE              1.022 0.313874
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the dataset; with psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8026.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4194 -1.0549  0.3706  0.7842  3.0770
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.01287  0.1135
#  Residual             0.19828  0.4453
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.214e-01  4.083e-02  1.587e+01
# scale(lottery_favour):treatmentA             1.910e-01  8.331e-03  6.398e+03
# scale(lottery_favour):treatmentE             2.460e-01  1.385e-02  6.317e+03
# scale(WTP):treatmentA                        2.320e-02  8.766e-03  6.403e+03
# scale(WTP):treatmentE                        1.040e-02  1.182e-02  6.414e+03
# scale(NPCR):treatmentA                      -7.301e-02  6.917e-02  1.570e+01
# scale(NPCR):treatmentE                       9.823e-02  1.508e-01  1.590e+01
# scale(x0):treatmentA                         5.353e-02  5.087e-02  1.570e+01
# scale(x0):treatmentE                        -1.118e-01  2.870e-01  1.577e+01
# scale(reflection):treatmentA                 7.642e-03  2.957e-02  1.568e+01
# scale(reflection):treatmentE                -1.422e-02  4.874e-02  1.582e+01
# scale(BNT):treatmentA                       -3.822e-03  3.734e-02  1.576e+01
# scale(BNT):treatmentE                        1.967e-02  5.656e-02  1.582e+01
# scale(NFC):treatmentA                        5.203e-02  2.985e-02  1.607e+01
# scale(NFC):treatmentE                        1.175e-01  6.516e-02  1.603e+01
# scale(FI):treatmentA                         1.756e-03  2.808e-02  1.572e+01
# scale(FI):treatmentE                         4.910e-02  5.601e-02  1.585e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.375e-02  7.314e-03  6.380e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.052e-02  9.756e-03  6.268e+03
# scale(NPCR):scale(x0):treatmentA            -3.363e-02  6.158e-02  1.573e+01
# scale(NPCR):scale(x0):treatmentE            -3.271e-01  4.156e-01  1.580e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  15.222 6.91e-11 ***
# scale(lottery_favour):treatmentA             22.930  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.757  < 2e-16 ***
# scale(WTP):treatmentA                         2.647  0.00813 **
# scale(WTP):treatmentE                         0.880  0.37915
# scale(NPCR):treatmentA                       -1.055  0.30720
# scale(NPCR):treatmentE                        0.651  0.52409
# scale(x0):treatmentA                          1.052  0.30862
# scale(x0):treatmentE                         -0.389  0.70218
# scale(reflection):treatmentA                  0.258  0.79939
# scale(reflection):treatmentE                 -0.292  0.77430
# scale(BNT):treatmentA                        -0.102  0.91977
# scale(BNT):treatmentE                         0.348  0.73257
# scale(NFC):treatmentA                         1.743  0.10040
# scale(NFC):treatmentE                         1.804  0.09005 .
# scale(FI):treatmentA                          0.063  0.95092
# scale(FI):treatmentE                          0.877  0.39380
# scale(lottery_favour):scale(WTP):treatmentA  -7.349 2.24e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.228 5.47e-13 ***
# scale(NPCR):scale(x0):treatmentA             -0.546  0.59266
# scale(NPCR):scale(x0):treatmentE             -0.787  0.44294
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9950.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2502 -0.8401 -0.2884  0.9344  3.2333
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005455 0.07386
#  Residual             0.183295 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.759e-01  1.758e-02  2.735e+01
# scale(lottery_favour):treatmentA             1.749e-01  8.879e-03  8.485e+03
# scale(lottery_favour):treatmentE             2.347e-01  7.615e-03  8.135e+03
# scale(WTP):treatmentA                       -3.771e-02  9.906e-03  8.123e+03
# scale(WTP):treatmentE                       -4.478e-02  7.201e-03  8.412e+03
# scale(NPCR):treatmentA                       1.053e-02  4.796e-02  2.625e+01
# scale(NPCR):treatmentE                      -5.637e-02  4.450e-02  2.603e+01
# scale(x0):treatmentA                         1.427e-01  3.007e-02  2.622e+01
# scale(x0):treatmentE                         9.308e-02  2.491e-02  2.599e+01
# scale(reflection):treatmentA                 6.100e-02  3.678e-02  2.626e+01
# scale(reflection):treatmentE                 7.947e-02  2.096e-02  2.646e+01
# scale(BNT):treatmentA                       -2.075e-02  3.656e-02  2.620e+01
# scale(BNT):treatmentE                       -3.036e-02  1.963e-02  2.597e+01
# scale(NFC):treatmentA                       -2.400e-02  4.023e-02  2.621e+01
# scale(NFC):treatmentE                       -1.877e-02  1.524e-02  2.594e+01
# scale(FI):treatmentA                         1.685e-02  2.312e-02  2.640e+01
# scale(FI):treatmentE                         6.339e-02  2.160e-02  2.604e+01
# scale(lottery_favour):scale(WTP):treatmentA  1.075e-02  7.412e-03  5.018e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.697e-02  6.270e-03  7.588e+03
# scale(NPCR):scale(x0):treatmentA             6.599e-02  4.104e-02  2.727e+01
# scale(NPCR):scale(x0):treatmentE             5.827e-02  4.027e-02  2.595e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  21.386  < 2e-16 ***
# scale(lottery_favour):treatmentA             19.699  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.817  < 2e-16 ***
# scale(WTP):treatmentA                        -3.807 0.000142 ***
# scale(WTP):treatmentE                        -6.218 5.28e-10 ***
# scale(NPCR):treatmentA                        0.220 0.827855
# scale(NPCR):treatmentE                       -1.267 0.216476
# scale(x0):treatmentA                          4.747 6.42e-05 ***
# scale(x0):treatmentE                          3.737 0.000925 ***
# scale(reflection):treatmentA                  1.659 0.109061
# scale(reflection):treatmentE                  3.791 0.000786 ***
# scale(BNT):treatmentA                        -0.568 0.575191
# scale(BNT):treatmentE                        -1.547 0.133913
# scale(NFC):treatmentA                        -0.597 0.555941
# scale(NFC):treatmentE                        -1.232 0.228902
# scale(FI):treatmentA                          0.729 0.472448
# scale(FI):treatmentE                          2.935 0.006876 **
# scale(lottery_favour):scale(WTP):treatmentA   1.450 0.147028
# scale(lottery_favour):scale(WTP):treatmentE  -5.896 3.88e-09 ***
# scale(NPCR):scale(x0):treatmentA              1.608 0.119335
# scale(NPCR):scale(x0):treatmentE              1.447 0.159854
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the dataset; with psychometrics; with interaction
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1H))
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# Correlation matrix not shown by default, as p = 28 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8028.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4331 -1.0564  0.3696  0.7849  3.0730
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.002942 0.05424
#  Residual             0.198285 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.433e-01  2.833e-02  8.984e+00
# scale(lottery_favour):treatmentA             1.898e-01  8.284e-03  5.520e+03
# scale(lottery_favour):treatmentE             2.491e-01  1.391e-02  6.401e+03
# scale(WTP):treatmentA                        2.196e-02  8.725e-03  5.760e+03
# scale(WTP):treatmentE                        1.206e-02  1.184e-02  6.401e+03
# scale(NPCR):treatmentA                      -6.943e-02  4.586e-02  8.624e+00
# scale(NPCR):treatmentE                       1.424e-01  1.400e-01  9.225e+00
# scale(x0):treatmentA                         5.201e-02  3.176e-02  8.628e+00
# scale(x0):treatmentE                         9.248e-01  4.549e-01  9.524e+00
# scale(reflection):treatmentA                 4.940e-04  1.757e-02  8.860e+00
# scale(reflection):treatmentE                -2.281e-01  2.990e-01  9.465e+00
# scale(BNT):treatmentA                        1.742e-02  2.199e-02  8.792e+00
# scale(BNT):treatmentE                        7.833e-02  1.022e-01  9.108e+00
# scale(NFC):treatmentA                        3.182e-02  1.727e-02  9.143e+00
# scale(NFC):treatmentE                        7.161e-02  2.210e-01  9.418e+00
# scale(FI):treatmentA                         2.202e-02  1.657e-02  8.623e+00
# scale(FI):treatmentE                         2.021e-01  7.094e-02  8.701e+00
# scale(lottery_favour):scale(WTP):treatmentA -5.325e-02  7.315e-03  6.315e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.127e-02  9.806e-03  6.401e+03
# scale(NPCR):scale(x0):treatmentA            -8.502e-03  4.118e-02  8.607e+00
# scale(NPCR):scale(x0):treatmentE             7.418e-01  8.812e-01  9.408e+00
# scale(NPCR):scale(reflection):treatmentA    -5.945e-03  2.517e-02  9.001e+00
# scale(NPCR):scale(reflection):treatmentE    -9.342e-01  3.650e-01  9.603e+00
# scale(NPCR):scale(BNT):treatmentA           -2.472e-02  2.389e-02  8.835e+00
# scale(NPCR):scale(BNT):treatmentE            7.831e-01  2.997e-01  9.057e+00
# scale(NPCR):scale(NFC):treatmentA            1.753e-02  1.376e-02  8.875e+00
# scale(NPCR):scale(NFC):treatmentE            2.063e-01  2.967e-01  9.268e+00
# scale(NPCR):scale(FI):treatmentA            -3.597e-02  1.412e-02  8.737e+00
#                                             t value Pr(>|t|)
# (Intercept)                                  22.705 3.03e-09 ***
# scale(lottery_favour):treatmentA             22.914  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.901  < 2e-16 ***
# scale(WTP):treatmentA                         2.517   0.0119 *
# scale(WTP):treatmentE                         1.018   0.3085
# scale(NPCR):treatmentA                       -1.514   0.1658
# scale(NPCR):treatmentE                        1.017   0.3351
# scale(x0):treatmentA                          1.637   0.1374
# scale(x0):treatmentE                          2.033   0.0708 .
# scale(reflection):treatmentA                  0.028   0.9782
# scale(reflection):treatmentE                 -0.763   0.4641
# scale(BNT):treatmentA                         0.792   0.4491
# scale(BNT):treatmentE                         0.766   0.4630
# scale(NFC):treatmentA                         1.843   0.0979 .
# scale(NFC):treatmentE                         0.324   0.7529
# scale(FI):treatmentA                          1.329   0.2180
# scale(FI):treatmentE                          2.849   0.0198 *
# scale(lottery_favour):scale(WTP):treatmentA  -7.279 3.77e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.268 4.08e-13 ***
# scale(NPCR):scale(x0):treatmentA             -0.206   0.8412
# scale(NPCR):scale(x0):treatmentE              0.842   0.4208
# scale(NPCR):scale(reflection):treatmentA     -0.236   0.8186
# scale(NPCR):scale(reflection):treatmentE     -2.559   0.0293 *
# scale(NPCR):scale(BNT):treatmentA            -1.034   0.3284
# scale(NPCR):scale(BNT):treatmentE             2.613   0.0280 *
# scale(NPCR):scale(NFC):treatmentA             1.274   0.2351
# scale(NPCR):scale(NFC):treatmentE             0.696   0.5038
# scale(NPCR):scale(FI):treatmentA             -2.547   0.0321 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9975.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2438 -0.8413 -0.2902  0.9330  3.2321
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005663 0.07525
#  Residual             0.183295 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.735e-01  2.126e-02  1.866e+01
# scale(lottery_favour):treatmentA             1.751e-01  8.890e-03  8.493e+03
# scale(lottery_favour):treatmentE             2.345e-01  7.622e-03  8.047e+03
# scale(WTP):treatmentA                       -3.733e-02  9.941e-03  8.348e+03
# scale(WTP):treatmentE                       -4.485e-02  7.205e-03  8.358e+03
# scale(NPCR):treatmentA                       8.827e-03  5.287e-02  1.817e+01
# scale(NPCR):treatmentE                      -7.644e-02  5.571e-02  1.794e+01
# scale(x0):treatmentA                         1.446e-01  1.103e-01  1.795e+01
# scale(x0):treatmentE                         9.340e-02  2.873e-02  1.802e+01
# scale(reflection):treatmentA                 6.735e-02  1.169e-01  1.816e+01
# scale(reflection):treatmentE                 8.048e-02  2.209e-02  1.830e+01
# scale(BNT):treatmentA                       -4.690e-02  1.402e-01  1.801e+01
# scale(BNT):treatmentE                       -1.172e-02  2.397e-02  1.792e+01
# scale(NFC):treatmentA                       -3.358e-02  1.219e-01  1.834e+01
# scale(NFC):treatmentE                       -2.188e-02  1.673e-02  1.793e+01
# scale(FI):treatmentA                         1.455e-02  4.754e-02  1.803e+01
# scale(FI):treatmentE                         5.350e-02  2.332e-02  1.804e+01
# scale(lottery_favour):scale(WTP):treatmentA  1.040e-02  7.479e-03  5.947e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.670e-02  6.281e-03  7.476e+03
# scale(NPCR):scale(x0):treatmentA             8.018e-02  2.018e-01  1.799e+01
# scale(NPCR):scale(x0):treatmentE             9.224e-02  5.505e-02  1.792e+01
# scale(NPCR):scale(reflection):treatmentA     9.884e-03  1.722e-01  1.816e+01
# scale(NPCR):scale(reflection):treatmentE    -4.718e-02  2.639e-02  1.792e+01
# scale(NPCR):scale(BNT):treatmentA           -5.448e-02  2.366e-01  1.798e+01
# scale(NPCR):scale(BNT):treatmentE            5.708e-02  3.930e-02  1.785e+01
# scale(NPCR):scale(NFC):treatmentA           -2.661e-02  1.659e-01  1.811e+01
# scale(NPCR):scale(NFC):treatmentE            5.349e-02  2.893e-02  1.795e+01
# scale(NPCR):scale(FI):treatmentA            -7.057e-03  9.173e-02  1.797e+01
# scale(NPCR):scale(FI):treatmentE            -4.984e-02  4.827e-02  1.796e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  17.563 4.65e-13 ***
# scale(lottery_favour):treatmentA             19.701  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.769  < 2e-16 ***
# scale(WTP):treatmentA                        -3.755 0.000174 ***
# scale(WTP):treatmentE                        -6.225 5.06e-10 ***
# scale(NPCR):treatmentA                        0.167 0.869230
# scale(NPCR):treatmentE                       -1.372 0.186894
# scale(x0):treatmentA                          1.312 0.206150
# scale(x0):treatmentE                          3.250 0.004436 **
# scale(reflection):treatmentA                  0.576 0.571537
# scale(reflection):treatmentE                  3.643 0.001820 **
# scale(BNT):treatmentA                        -0.335 0.741860
# scale(BNT):treatmentE                        -0.489 0.630888
# scale(NFC):treatmentA                        -0.276 0.785994
# scale(NFC):treatmentE                        -1.308 0.207455
# scale(FI):treatmentA                          0.306 0.762997
# scale(FI):treatmentE                          2.295 0.033961 *
# scale(lottery_favour):scale(WTP):treatmentA   1.391 0.164365
# scale(lottery_favour):scale(WTP):treatmentE  -5.844 5.33e-09 ***
# scale(NPCR):scale(x0):treatmentA              0.397 0.695801
# scale(NPCR):scale(x0):treatmentE              1.676 0.111184
# scale(NPCR):scale(reflection):treatmentA      0.057 0.954844
# scale(NPCR):scale(reflection):treatmentE     -1.788 0.090716 .
# scale(NPCR):scale(BNT):treatmentA            -0.230 0.820537
# scale(NPCR):scale(BNT):treatmentE             1.453 0.163684
# scale(NPCR):scale(NFC):treatmentA            -0.160 0.874362
# scale(NPCR):scale(NFC):treatmentE             1.849 0.081008 .
# scale(NPCR):scale(FI):treatmentA             -0.077 0.939528
# scale(NPCR):scale(FI):treatmentE             -1.033 0.315512
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the datasets; with psychometrics; with interaction; change order (a different variable is droped due to rank difficiency)
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(FI) + scale(NFC) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(FI) + scale(NPCR):scale(NFC)):treatment + (1|subject), data1L))
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient
#
# Correlation matrix not shown by default, as p = 28 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(FI) +
#     scale(NFC) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(FI) + scale(NPCR):scale(NFC)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8028.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4331 -1.0564  0.3696  0.7849  3.0730
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.002942 0.05424
#  Residual             0.198285 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.433e-01  2.833e-02  8.984e+00
# scale(lottery_favour):treatmentA             1.898e-01  8.284e-03  5.520e+03
# scale(lottery_favour):treatmentE             2.491e-01  1.391e-02  6.401e+03
# scale(WTP):treatmentA                        2.196e-02  8.725e-03  5.760e+03
# scale(WTP):treatmentE                        1.206e-02  1.184e-02  6.401e+03
# scale(NPCR):treatmentA                      -6.943e-02  4.586e-02  8.624e+00
# scale(NPCR):treatmentE                       2.006e-01  9.579e-02  9.232e+00
# scale(x0):treatmentA                         5.201e-02  3.176e-02  8.628e+00
# scale(x0):treatmentE                         6.830e-01  2.254e-01  9.330e+00
# scale(reflection):treatmentA                 4.940e-04  1.757e-02  8.860e+00
# scale(reflection):treatmentE                -3.014e-02  8.413e-02  9.093e+00
# scale(BNT):treatmentA                        1.742e-02  2.199e-02  8.792e+00
# scale(BNT):treatmentE                        1.429e-01  3.852e-02  9.239e+00
# scale(FI):treatmentA                         2.202e-02  1.657e-02  8.623e+00
# scale(FI):treatmentE                         1.282e-01  1.677e-01  8.992e+00
# scale(NFC):treatmentA                        3.182e-02  1.727e-02  9.143e+00
# scale(NFC):treatmentE                       -7.535e-02  5.458e-02  9.154e+00
# scale(lottery_favour):scale(WTP):treatmentA -5.325e-02  7.315e-03  6.315e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.127e-02  9.806e-03  6.401e+03
# scale(NPCR):scale(x0):treatmentA            -8.502e-03  4.118e-02  8.607e+00
# scale(NPCR):scale(x0):treatmentE             2.115e-01  3.127e-01  9.211e+00
# scale(NPCR):scale(reflection):treatmentA    -5.945e-03  2.517e-02  9.001e+00
# scale(NPCR):scale(reflection):treatmentE    -6.963e-01  1.761e-01  9.060e+00
# scale(NPCR):scale(BNT):treatmentA           -2.472e-02  2.389e-02  8.835e+00
# scale(NPCR):scale(BNT):treatmentE            9.816e-01  1.671e-01  9.479e+00
# scale(NPCR):scale(FI):treatmentA            -3.597e-02  1.412e-02  8.737e+00
# scale(NPCR):scale(FI):treatmentE            -2.184e-01  3.140e-01  9.268e+00
# scale(NPCR):scale(NFC):treatmentA            1.753e-02  1.376e-02  8.875e+00
#                                             t value Pr(>|t|)
# (Intercept)                                  22.705 3.03e-09 ***
# scale(lottery_favour):treatmentA             22.914  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.901  < 2e-16 ***
# scale(WTP):treatmentA                         2.517 0.011852 *
# scale(WTP):treatmentE                         1.018 0.308504
# scale(NPCR):treatmentA                       -1.514 0.165784
# scale(NPCR):treatmentE                        2.094 0.064937 .
# scale(x0):treatmentA                          1.637 0.137443
# scale(x0):treatmentE                          3.031 0.013669 *
# scale(reflection):treatmentA                  0.028 0.978190
# scale(reflection):treatmentE                 -0.358 0.728326
# scale(BNT):treatmentA                         0.792 0.449112
# scale(BNT):treatmentE                         3.710 0.004629 **
# scale(FI):treatmentA                          1.329 0.218005
# scale(FI):treatmentE                          0.765 0.464131
# scale(NFC):treatmentA                         1.843 0.097901 .
# scale(NFC):treatmentE                        -1.381 0.200205
# scale(lottery_favour):scale(WTP):treatmentA  -7.279 3.77e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.268 4.08e-13 ***
# scale(NPCR):scale(x0):treatmentA             -0.206 0.841216
# scale(NPCR):scale(x0):treatmentE              0.676 0.515577
# scale(NPCR):scale(reflection):treatmentA     -0.236 0.818610
# scale(NPCR):scale(reflection):treatmentE     -3.955 0.003288 **
# scale(NPCR):scale(BNT):treatmentA            -1.034 0.328447
# scale(NPCR):scale(BNT):treatmentE             5.874 0.000193 ***
# scale(NPCR):scale(FI):treatmentA             -2.547 0.032057 *
# scale(NPCR):scale(FI):treatmentE             -0.696 0.503780
# scale(NPCR):scale(NFC):treatmentA             1.274 0.235078
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
# Split the dataset; with psychometrics; with interaction; BNT is dropped
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 25 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(NFC) + scale(FI) +
#     scale(NPCR):scale(reflection) + scale(NPCR):scale(NFC) +
#     scale(NPCR):scale(FI)):treatment + (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8025.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4260 -1.0543  0.3659  0.7841  3.0795
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.007649 0.08746
#  Residual             0.198283 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.415e-01  4.020e-02  1.204e+01
# scale(lottery_favour):treatmentA             1.910e-01  8.318e-03  6.275e+03
# scale(lottery_favour):treatmentE             2.465e-01  1.388e-02  6.383e+03
# scale(WTP):treatmentA                        2.324e-02  8.754e-03  6.307e+03
# scale(WTP):treatmentE                        1.073e-02  1.183e-02  6.413e+03
# scale(NPCR):treatmentA                      -7.716e-02  6.507e-02  1.172e+01
# scale(NPCR):treatmentE                       1.148e-01  1.152e-01  1.202e+01
# scale(x0):treatmentA                         4.983e-02  4.659e-02  1.174e+01
# scale(x0):treatmentE                         6.791e-01  3.104e-01  1.200e+01
# scale(reflection):treatmentA                 7.485e-03  2.515e-02  1.186e+01
# scale(reflection):treatmentE                -5.608e-01  1.968e-01  1.206e+01
# scale(NFC):treatmentA                        3.850e-02  2.449e-02  1.206e+01
# scale(NFC):treatmentE                        4.474e-01  1.223e-01  1.230e+01
# scale(FI):treatmentA                         1.649e-02  2.392e-02  1.172e+01
# scale(FI):treatmentE                         4.146e-01  2.618e-01  1.190e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.393e-02  7.321e-03  6.390e+03
# scale(lottery_favour):scale(WTP):treatmentE -6.935e-02  9.779e-03  6.370e+03
# scale(NPCR):scale(x0):treatmentA            -2.226e-02  5.748e-02  1.172e+01
# scale(NPCR):scale(x0):treatmentE             1.031e+00  5.380e-01  1.197e+01
# scale(NPCR):scale(reflection):treatmentA    -5.613e-03  3.493e-02  1.190e+01
# scale(NPCR):scale(reflection):treatmentE    -1.013e+00  3.541e-01  1.193e+01
# scale(NPCR):scale(NFC):treatmentA            1.667e-02  1.964e-02  1.189e+01
# scale(NPCR):scale(NFC):treatmentE            5.271e-01  1.773e-01  1.217e+01
# scale(NPCR):scale(FI):treatmentA            -3.408e-02  2.071e-02  1.181e+01
# scale(NPCR):scale(FI):treatmentE             6.948e-01  4.828e-01  1.199e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  15.959 1.82e-09 ***
# scale(lottery_favour):treatmentA             22.964  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.760  < 2e-16 ***
# scale(WTP):treatmentA                         2.655  0.00794 **
# scale(WTP):treatmentE                         0.907  0.36451
# scale(NPCR):treatmentA                       -1.186  0.25916
# scale(NPCR):treatmentE                        0.997  0.33860
# scale(x0):treatmentA                          1.070  0.30630
# scale(x0):treatmentE                          2.188  0.04918 *
# scale(reflection):treatmentA                  0.298  0.77110
# scale(reflection):treatmentE                 -2.849  0.01459 *
# scale(NFC):treatmentA                         1.572  0.14182
# scale(NFC):treatmentE                         3.658  0.00315 **
# scale(FI):treatmentA                          0.690  0.50386
# scale(FI):treatmentE                          1.584  0.13946
# scale(lottery_favour):scale(WTP):treatmentA  -7.367 1.97e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.092 1.46e-12 ***
# scale(NPCR):scale(x0):treatmentA             -0.387  0.70553
# scale(NPCR):scale(x0):treatmentE              1.916  0.07955 .
# scale(NPCR):scale(reflection):treatmentA     -0.161  0.87504
# scale(NPCR):scale(reflection):treatmentE     -2.862  0.01439 *
# scale(NPCR):scale(NFC):treatmentA             0.849  0.41288
# scale(NPCR):scale(NFC):treatmentE             2.973  0.01149 *
# scale(NPCR):scale(FI):treatmentA             -1.645  0.12624
# scale(NPCR):scale(FI):treatmentE              1.439  0.17575
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 25 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(NFC) + scale(FI) +
#     scale(NPCR):scale(reflection) + scale(NPCR):scale(NFC) +
#     scale(NPCR):scale(FI)):treatment + (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9964
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2390 -0.8393 -0.2903  0.9337  3.2328
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005657 0.07521
#  Residual             0.183295 0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.696e-01  2.111e-02  2.283e+01
# scale(lottery_favour):treatmentA             1.751e-01  8.889e-03  8.507e+03
# scale(lottery_favour):treatmentE             2.346e-01  7.622e-03  8.156e+03
# scale(WTP):treatmentA                       -3.740e-02  9.940e-03  8.396e+03
# scale(WTP):treatmentE                       -4.480e-02  7.205e-03  8.406e+03
# scale(NPCR):treatmentA                       4.869e-03  5.188e-02  2.224e+01
# scale(NPCR):treatmentE                      -1.093e-01  5.277e-02  2.190e+01
# scale(x0):treatmentA                         1.175e-01  4.223e-02  2.218e+01
# scale(x0):treatmentE                         8.871e-02  2.853e-02  2.208e+01
# scale(reflection):treatmentA                 3.112e-02  6.211e-02  2.274e+01
# scale(reflection):treatmentE                 7.087e-02  1.945e-02  2.247e+01
# scale(NFC):treatmentA                       -4.227e-02  1.158e-01  2.247e+01
# scale(NFC):treatmentE                       -2.772e-02  1.613e-02  2.196e+01
# scale(FI):treatmentA                         4.453e-03  2.978e-02  2.221e+01
# scale(FI):treatmentE                         6.321e-02  2.269e-02  2.207e+01
# scale(lottery_favour):scale(WTP):treatmentA  1.042e-02  7.479e-03  6.340e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.655e-02  6.278e-03  7.615e+03
# scale(NPCR):scale(x0):treatmentA             2.649e-02  6.838e-02  2.232e+01
# scale(NPCR):scale(x0):treatmentE             9.793e-02  5.026e-02  2.192e+01
# scale(NPCR):scale(reflection):treatmentA    -2.414e-02  8.753e-02  2.293e+01
# scale(NPCR):scale(reflection):treatmentE    -2.925e-02  2.152e-02  2.200e+01
# scale(NPCR):scale(NFC):treatmentA           -1.706e-02  1.651e-01  2.216e+01
# scale(NPCR):scale(NFC):treatmentE            2.451e-02  2.120e-02  2.212e+01
# scale(NPCR):scale(FI):treatmentA            -3.137e-02  5.086e-02  2.213e+01
# scale(NPCR):scale(FI):treatmentE            -2.490e-02  3.818e-02  2.205e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  17.512 9.94e-15 ***
# scale(lottery_favour):treatmentA             19.696  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.783  < 2e-16 ***
# scale(WTP):treatmentA                        -3.762 0.000169 ***
# scale(WTP):treatmentE                        -6.217 5.30e-10 ***
# scale(NPCR):treatmentA                        0.094 0.926065
# scale(NPCR):treatmentE                       -2.071 0.050346 .
# scale(x0):treatmentA                          2.782 0.010827 *
# scale(x0):treatmentE                          3.109 0.005096 **
# scale(reflection):treatmentA                  0.501 0.621143
# scale(reflection):treatmentE                  3.643 0.001398 **
# scale(NFC):treatmentA                        -0.365 0.718633
# scale(NFC):treatmentE                        -1.719 0.099774 .
# scale(FI):treatmentA                          0.150 0.882476
# scale(FI):treatmentE                          2.786 0.010766 *
# scale(lottery_favour):scale(WTP):treatmentA   1.393 0.163738
# scale(lottery_favour):scale(WTP):treatmentE  -5.822 6.05e-09 ***
# scale(NPCR):scale(x0):treatmentA              0.387 0.702199
# scale(NPCR):scale(x0):treatmentE              1.949 0.064268 .
# scale(NPCR):scale(reflection):treatmentA     -0.276 0.785159
# scale(NPCR):scale(reflection):treatmentE     -1.359 0.187833
# scale(NPCR):scale(NFC):treatmentA            -0.103 0.918600
# scale(NPCR):scale(NFC):treatmentE             1.156 0.259931
# scale(NPCR):scale(FI):treatmentA             -0.617 0.543646
# scale(NPCR):scale(FI):treatmentE             -0.652 0.521068
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Split the dataset; with psychometrics; with interaction; no interaction between d and x0
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1L))
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR) + scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1H))
# Out:
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1L
#
# REML criterion at convergence: 8026
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4340 -1.0551  0.3695  0.7856  3.0730
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.002557 0.05056
#  Residual             0.198286 0.44529
# Number of obs: 6438, groups:  subject, 31
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  6.479e-01  1.591e-02  1.102e+01
# scale(lottery_favour):treatmentA             1.896e-01  8.274e-03  5.393e+03
# scale(lottery_favour):treatmentE             2.491e-01  1.392e-02  6.401e+03
# scale(WTP):treatmentA                        2.177e-02  8.717e-03  5.689e+03
# scale(WTP):treatmentE                        1.206e-02  1.184e-02  6.401e+03
# scale(NPCR):treatmentA                      -6.112e-02  2.130e-02  9.809e+00
# scale(NPCR):treatmentE                       2.316e-01  6.390e-02  1.036e+01
# scale(x0):treatmentA                         5.719e-02  1.809e-02  9.636e+00
# scale(x0):treatmentE                         5.871e-01  1.051e-01  1.054e+01
# scale(reflection):treatmentA                 1.090e-03  1.647e-02  9.854e+00
# scale(reflection):treatmentE                 4.832e-02  9.267e-02  1.003e+01
# scale(BNT):treatmentA                        1.846e-02  2.042e-02  9.799e+00
# scale(BNT):treatmentE                        1.687e-01  4.358e-02  1.029e+01
# scale(NFC):treatmentA                        3.050e-02  1.551e-02  1.040e+01
# scale(NFC):treatmentE                       -1.297e-01  9.805e-02  1.022e+01
# scale(FI):treatmentA                         2.098e-02  1.496e-02  9.561e+00
# scale(FI):treatmentE                         1.002e-01  1.700e-01  1.016e+01
# scale(lottery_favour):scale(WTP):treatmentA -5.316e-02  7.313e-03  6.303e+03
# scale(lottery_favour):scale(WTP):treatmentE -7.127e-02  9.806e-03  6.401e+03
# scale(NPCR):scale(reflection):treatmentA    -5.450e-03  2.382e-02  1.003e+01
# scale(NPCR):scale(reflection):treatmentE    -6.011e-01  1.373e-01  9.801e+00
# scale(NPCR):scale(BNT):treatmentA           -2.583e-02  2.201e-02  9.806e+00
# scale(NPCR):scale(BNT):treatmentE            1.060e+00  2.108e-01  1.064e+01
# scale(NPCR):scale(NFC):treatmentA            1.783e-02  1.298e-02  9.867e+00
# scale(NPCR):scale(NFC):treatmentE           -7.384e-02  1.088e-01  1.039e+01
# scale(NPCR):scale(FI):treatmentA            -3.522e-02  1.296e-02  9.721e+00
# scale(NPCR):scale(FI):treatmentE            -3.016e-01  3.448e-01  1.053e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  40.720 2.27e-13 ***
# scale(lottery_favour):treatmentA             22.919  < 2e-16 ***
# scale(lottery_favour):treatmentE             17.901  < 2e-16 ***
# scale(WTP):treatmentA                         2.497 0.012547 *
# scale(WTP):treatmentE                         1.018 0.308505
# scale(NPCR):treatmentA                       -2.870 0.016968 *
# scale(NPCR):treatmentE                        3.624 0.004399 **
# scale(x0):treatmentA                          3.162 0.010590 *
# scale(x0):treatmentE                          5.585 0.000192 ***
# scale(reflection):treatmentA                  0.066 0.948555
# scale(reflection):treatmentE                  0.521 0.613409
# scale(BNT):treatmentA                         0.904 0.387833
# scale(BNT):treatmentE                         3.870 0.002947 **
# scale(NFC):treatmentA                         1.967 0.076461 .
# scale(NFC):treatmentE                        -1.323 0.214716
# scale(FI):treatmentA                          1.402 0.192551
# scale(FI):treatmentE                          0.590 0.568397
# scale(lottery_favour):scale(WTP):treatmentA  -7.269 4.06e-13 ***
# scale(lottery_favour):scale(WTP):treatmentE  -7.268 4.08e-13 ***
# scale(NPCR):scale(reflection):treatmentA     -0.229 0.823623
# scale(NPCR):scale(reflection):treatmentE     -4.379 0.001447 **
# scale(NPCR):scale(BNT):treatmentA            -1.174 0.268228
# scale(NPCR):scale(BNT):treatmentE             5.028 0.000427 ***
# scale(NPCR):scale(NFC):treatmentA             1.374 0.199976
# scale(NPCR):scale(NFC):treatmentE            -0.679 0.512166
# scale(NPCR):scale(FI):treatmentA             -2.717 0.022200 *
# scale(NPCR):scale(FI):treatmentE             -0.875 0.401241
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Correlation matrix not shown by default, as p = 27 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) +
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1H
#
# REML criterion at convergence: 9973.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2380 -0.8396 -0.2887  0.9304  3.2327
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.00597  0.07726
#  Residual             0.18330  0.42813
# Number of obs: 8549, groups:  subject, 41
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  3.924e-01  1.853e-02  2.073e+01
# scale(lottery_favour):treatmentA             1.752e-01  8.890e-03  8.502e+03
# scale(lottery_favour):treatmentE             2.346e-01  7.625e-03  8.151e+03
# scale(WTP):treatmentA                       -3.724e-02  9.941e-03  8.378e+03
# scale(WTP):treatmentE                       -4.475e-02  7.207e-03  8.399e+03
# scale(NPCR):treatmentA                       3.252e-02  5.171e-02  2.018e+01
# scale(NPCR):treatmentE                       4.160e-03  2.883e-02  1.996e+01
# scale(x0):treatmentA                         1.064e-01  2.869e-02  2.050e+01
# scale(x0):treatmentE                         1.094e-01  2.770e-02  2.007e+01
# scale(reflection):treatmentA                 5.444e-02  6.239e-02  2.110e+01
# scale(reflection):treatmentE                 8.589e-02  2.236e-02  2.031e+01
# scale(BNT):treatmentA                       -1.000e-02  5.016e-02  2.029e+01
# scale(BNT):treatmentE                       -2.769e-02  2.247e-02  1.993e+01
# scale(NFC):treatmentA                       -7.163e-02  1.191e-01  2.036e+01
# scale(NFC):treatmentE                       -1.533e-02  1.665e-02  1.998e+01
# scale(FI):treatmentA                        -3.224e-03  2.850e-02  2.006e+01
# scale(FI):treatmentE                         4.399e-02  2.313e-02  2.010e+01
# scale(lottery_favour):scale(WTP):treatmentA  1.021e-02  7.483e-03  6.277e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.702e-02  6.281e-03  7.584e+03
# scale(NPCR):scale(reflection):treatmentA    -6.334e-03  9.966e-02  2.104e+01
# scale(NPCR):scale(reflection):treatmentE    -2.317e-02  2.267e-02  1.997e+01
# scale(NPCR):scale(BNT):treatmentA            1.014e-02  9.390e-02  2.016e+01
# scale(NPCR):scale(BNT):treatmentE            4.170e-02  3.907e-02  1.986e+01
# scale(NPCR):scale(NFC):treatmentA           -4.777e-02  1.685e-01  2.015e+01
# scale(NPCR):scale(NFC):treatmentE            5.668e-02  2.954e-02  1.995e+01
# scale(NPCR):scale(FI):treatmentA            -4.210e-02  4.318e-02  1.995e+01
# scale(NPCR):scale(FI):treatmentE             1.909e-03  3.793e-02  1.999e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  21.173 1.62e-15 ***
# scale(lottery_favour):treatmentA             19.703  < 2e-16 ***
# scale(lottery_favour):treatmentE             30.767  < 2e-16 ***
# scale(WTP):treatmentA                        -3.746 0.000181 ***
# scale(WTP):treatmentE                        -6.209 5.58e-10 ***
# scale(NPCR):treatmentA                        0.629 0.536500
# scale(NPCR):treatmentE                        0.144 0.886732
# scale(x0):treatmentA                          3.709 0.001342 **
# scale(x0):treatmentE                          3.950 0.000787 ***
# scale(reflection):treatmentA                  0.873 0.392720
# scale(reflection):treatmentE                  3.842 0.000995 ***
# scale(BNT):treatmentA                        -0.199 0.843941
# scale(BNT):treatmentE                        -1.232 0.232247
# scale(NFC):treatmentA                        -0.602 0.554057
# scale(NFC):treatmentE                        -0.921 0.368169
# scale(FI):treatmentA                         -0.113 0.911073
# scale(FI):treatmentE                          1.902 0.071572 .
# scale(lottery_favour):scale(WTP):treatmentA   1.364 0.172585
# scale(lottery_favour):scale(WTP):treatmentE  -5.894 3.92e-09 ***
# scale(NPCR):scale(reflection):treatmentA     -0.064 0.949926
# scale(NPCR):scale(reflection):treatmentE     -1.022 0.319115
# scale(NPCR):scale(BNT):treatmentA             0.108 0.915106
# scale(NPCR):scale(BNT):treatmentE             1.067 0.298653
# scale(NPCR):scale(NFC):treatmentA            -0.283 0.779705
# scale(NPCR):scale(NFC):treatmentE             1.919 0.069431 .
# scale(NPCR):scale(FI):treatmentA             -0.975 0.341311
# scale(NPCR):scale(FI):treatmentE              0.050 0.960349
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Whole Dataset

# %%
# All subjects; Baseline
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17947.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4901 -0.9146  0.0353  0.8639  3.1809
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.01001  0.1000
#  Residual             0.19062  0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.918e-01  1.395e-02  6.597e+01
# scale(lottery_favour):treatmentA             1.814e-01  6.032e-03  1.474e+04
# scale(lottery_favour):treatmentE             2.355e-01  6.739e-03  1.460e+04
# scale(WTP):treatmentA                       -3.665e-03  6.521e-03  1.451e+04
# scale(WTP):treatmentE                       -3.017e-02  6.198e-03  1.493e+04
# scale(NPCR):treatmentA                      -6.808e-03  2.497e-02  6.362e+01
# scale(NPCR):treatmentE                      -8.227e-03  2.374e-02  6.334e+01
# scale(x0):treatmentA                         1.352e-01  3.386e-02  6.358e+01
# scale(x0):treatmentE                         1.439e-01  2.840e-02  6.331e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.281e-02  5.174e-03  1.297e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.605e-02  5.292e-03  1.391e+04
# scale(NPCR):scale(x0):treatmentA            -1.966e-02  5.324e-02  6.366e+01
# scale(NPCR):scale(x0):treatmentE            -1.599e-02  5.571e-02  6.331e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  35.249  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.070  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.946  < 2e-16 ***
# scale(WTP):treatmentA                        -0.562 0.574104
# scale(WTP):treatmentE                        -4.867 1.14e-06 ***
# scale(NPCR):treatmentA                       -0.273 0.785958
# scale(NPCR):treatmentE                       -0.346 0.730137
# scale(x0):treatmentA                          3.993 0.000172 ***
# scale(x0):treatmentE                          5.067 3.75e-06 ***
# scale(lottery_favour):scale(WTP):treatmentA  -4.409 1.05e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.703  < 2e-16 ***
# scale(NPCR):scale(x0):treatmentA             -0.369 0.713102
# scale(NPCR):scale(x0):treatmentE             -0.287 0.774988
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# All subjects; with psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 17982
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4904 -0.9150  0.0356  0.8631  3.1782
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.009005 0.0949
#  Residual             0.190624 0.4366
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.867e-01  1.375e-02  5.782e+01
# scale(lottery_favour):treatmentA             1.813e-01  6.030e-03  1.463e+04
# scale(lottery_favour):treatmentE             2.362e-01  6.742e-03  1.458e+04
# scale(WTP):treatmentA                       -3.869e-03  6.520e-03  1.437e+04
# scale(WTP):treatmentE                       -2.968e-02  6.199e-03  1.491e+04
# scale(NPCR):treatmentA                      -8.833e-03  2.403e-02  5.570e+01
# scale(NPCR):treatmentE                       9.612e-03  2.368e-02  5.546e+01
# scale(x0):treatmentA                         1.417e-01  3.324e-02  5.560e+01
# scale(x0):treatmentE                         1.306e-01  2.811e-02  5.546e+01
# scale(reflection):treatmentA                 4.605e-03  2.159e-02  5.568e+01
# scale(reflection):treatmentE                 6.582e-02  2.072e-02  5.595e+01
# scale(BNT):treatmentA                        1.065e-02  2.483e-02  5.568e+01
# scale(BNT):treatmentE                       -3.131e-02  1.875e-02  5.564e+01
# scale(NFC):treatmentA                        1.489e-02  2.195e-02  5.568e+01
# scale(NFC):treatmentE                        4.974e-03  1.511e-02  5.578e+01
# scale(FI):treatmentA                        -6.911e-03  1.678e-02  5.556e+01
# scale(FI):treatmentE                         3.964e-02  1.941e-02  5.565e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.256e-02  5.172e-03  1.252e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.692e-02  5.295e-03  1.384e+04
# scale(NPCR):scale(x0):treatmentA            -8.457e-03  5.359e-02  5.565e+01
# scale(NPCR):scale(x0):treatmentE            -1.901e-02  5.530e-02  5.542e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  35.392  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.058  < 2e-16 ***
# scale(lottery_favour):treatmentE             35.028  < 2e-16 ***
# scale(WTP):treatmentA                        -0.593  0.55296
# scale(WTP):treatmentE                        -4.788 1.70e-06 ***
# scale(NPCR):treatmentA                       -0.368  0.71459
# scale(NPCR):treatmentE                        0.406  0.68642
# scale(x0):treatmentA                          4.264 7.86e-05 ***
# scale(x0):treatmentE                          4.647 2.12e-05 ***
# scale(reflection):treatmentA                  0.213  0.83189
# scale(reflection):treatmentE                  3.178  0.00242 **
# scale(BNT):treatmentA                         0.429  0.66946
# scale(BNT):treatmentE                        -1.670  0.10058
# scale(NFC):treatmentA                         0.678  0.50059
# scale(NFC):treatmentE                         0.329  0.74320
# scale(FI):treatmentA                         -0.412  0.68203
# scale(FI):treatmentE                          2.043  0.04585 *
# scale(lottery_favour):scale(WTP):treatmentA  -4.362 1.30e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.862  < 2e-16 ***
# scale(NPCR):scale(x0):treatmentA             -0.158  0.87518
# scale(NPCR):scale(x0):treatmentE             -0.344  0.73234
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# All subjects; with psychometrics; with interaction
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment +
#     (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18012.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.5022 -0.9163  0.0350  0.8629  3.1894
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.008054 0.08974
#  Residual             0.190622 0.43660
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.973e-01  1.564e-02  4.949e+01
# scale(lottery_favour):treatmentA             1.820e-01  6.035e-03  1.464e+04
# scale(lottery_favour):treatmentE             2.358e-01  6.741e-03  1.443e+04
# scale(WTP):treatmentA                       -3.077e-03  6.525e-03  1.433e+04
# scale(WTP):treatmentE                       -2.995e-02  6.199e-03  1.486e+04
# scale(NPCR):treatmentA                      -1.726e-03  2.579e-02  4.815e+01
# scale(NPCR):treatmentE                       3.845e-02  3.351e-02  4.798e+01
# scale(x0):treatmentA                         1.264e-01  3.343e-02  4.774e+01
# scale(x0):treatmentE                         1.535e-01  2.837e-02  4.783e+01
# scale(reflection):treatmentA                 1.958e-03  2.234e-02  4.828e+01
# scale(reflection):treatmentE                 6.512e-02  2.105e-02  4.811e+01
# scale(BNT):treatmentA                        1.653e-02  2.692e-02  4.797e+01
# scale(BNT):treatmentE                       -5.017e-03  2.306e-02  4.803e+01
# scale(NFC):treatmentA                        6.466e-03  2.131e-02  4.780e+01
# scale(NFC):treatmentE                        1.899e-02  1.682e-02  4.810e+01
# scale(FI):treatmentA                         5.342e-03  1.689e-02  4.786e+01
# scale(FI):treatmentE                         2.282e-02  2.370e-02  4.781e+01
# scale(lottery_favour):scale(WTP):treatmentA -2.284e-02  5.179e-03  1.255e+04
# scale(lottery_favour):scale(WTP):treatmentE -4.636e-02  5.296e-03  1.364e+04
# scale(NPCR):scale(x0):treatmentA            -3.864e-02  5.381e-02  4.778e+01
# scale(NPCR):scale(x0):treatmentE             1.491e-02  5.671e-02  4.768e+01
# scale(NPCR):scale(reflection):treatmentA    -4.968e-03  2.782e-02  4.854e+01
# scale(NPCR):scale(reflection):treatmentE    -3.823e-02  3.181e-02  4.775e+01
# scale(NPCR):scale(BNT):treatmentA           -1.174e-03  2.760e-02  4.823e+01
# scale(NPCR):scale(BNT):treatmentE            8.918e-02  4.422e-02  4.791e+01
# scale(NPCR):scale(NFC):treatmentA            2.208e-02  1.655e-02  4.833e+01
# scale(NPCR):scale(NFC):treatmentE            7.662e-02  3.434e-02  4.798e+01
# scale(NPCR):scale(FI):treatmentA            -3.432e-02  1.534e-02  4.842e+01
# scale(NPCR):scale(FI):treatmentE            -2.324e-02  5.106e-02  4.782e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  31.795  < 2e-16 ***
# scale(lottery_favour):treatmentA             30.157  < 2e-16 ***
# scale(lottery_favour):treatmentE             34.980  < 2e-16 ***
# scale(WTP):treatmentA                        -0.472 0.637163
# scale(WTP):treatmentE                        -4.831 1.37e-06 ***
# scale(NPCR):treatmentA                       -0.067 0.946917
# scale(NPCR):treatmentE                        1.147 0.256916
# scale(x0):treatmentA                          3.782 0.000434 ***
# scale(x0):treatmentE                          5.412 1.98e-06 ***
# scale(reflection):treatmentA                  0.088 0.930532
# scale(reflection):treatmentE                  3.094 0.003284 **
# scale(BNT):treatmentA                         0.614 0.542173
# scale(BNT):treatmentE                        -0.218 0.828720
# scale(NFC):treatmentA                         0.303 0.762888
# scale(NFC):treatmentE                         1.129 0.264375
# scale(FI):treatmentA                          0.316 0.753119
# scale(FI):treatmentE                          0.963 0.340469
# scale(lottery_favour):scale(WTP):treatmentA  -4.409 1.05e-05 ***
# scale(lottery_favour):scale(WTP):treatmentE  -8.753  < 2e-16 ***
# scale(NPCR):scale(x0):treatmentA             -0.718 0.476226
# scale(NPCR):scale(x0):treatmentE              0.263 0.793750
# scale(NPCR):scale(reflection):treatmentA     -0.179 0.859037
# scale(NPCR):scale(reflection):treatmentE     -1.202 0.235333
# scale(NPCR):scale(BNT):treatmentA            -0.043 0.966245
# scale(NPCR):scale(BNT):treatmentE             2.017 0.049370 *
# scale(NPCR):scale(NFC):treatmentA             1.334 0.188516
# scale(NPCR):scale(NFC):treatmentE             2.231 0.030370 *
# scale(NPCR):scale(FI):treatmentA             -2.238 0.029865 *
# scale(NPCR):scale(FI):treatmentE             -0.455 0.651081
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Low-attention subjects removed

# %%
# Low-attention subjects removed; Baseline
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 13 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11194.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4642 -0.8682 -0.0474  0.8406  3.7898
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.008347 0.09136
#  Residual             0.168101 0.41000
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.514e-01  1.445e-02  4.445e+01
# scale(lottery_favour):treatmentA             2.388e-01  7.034e-03  1.033e+04
# scale(lottery_favour):treatmentE             2.881e-01  7.239e-03  9.980e+03
# scale(WTP):treatmentA                       -4.176e-02  7.603e-03  1.025e+04
# scale(WTP):treatmentE                       -7.564e-02  6.734e-03  1.033e+04
# scale(NPCR):treatmentA                       1.472e-02  2.290e-02  4.248e+01
# scale(NPCR):treatmentE                      -9.494e-03  2.009e-02  4.239e+01
# scale(x0):treatmentA                         1.400e-01  2.232e-02  4.223e+01
# scale(x0):treatmentE                         1.754e-01  2.633e-02  4.250e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.238e-02  6.122e-03  8.801e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.674e-02  5.614e-03  9.548e+03
# scale(NPCR):scale(x0):treatmentA            -1.249e-03  2.095e-02  4.221e+01
# scale(NPCR):scale(x0):treatmentE             4.019e-02  4.040e-02  4.235e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  31.247  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.944  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.798  < 2e-16 ***
# scale(WTP):treatmentA                        -5.493 4.05e-08 ***
# scale(WTP):treatmentE                       -11.233  < 2e-16 ***
# scale(NPCR):treatmentA                        0.643   0.5238
# scale(NPCR):treatmentE                       -0.473   0.6389
# scale(x0):treatmentA                          6.273 1.57e-07 ***
# scale(x0):treatmentE                          6.659 4.24e-08 ***
# scale(lottery_favour):scale(WTP):treatmentA  -2.022   0.0432 *
# scale(lottery_favour):scale(WTP):treatmentE  -6.545 6.25e-11 ***
# scale(NPCR):scale(x0):treatmentA             -0.060   0.9527
# scale(NPCR):scale(x0):treatmentE              0.995   0.3254
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Low-attention subjects removed; with psychometrics
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 21 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI)):treatment + (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11218
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4764 -0.8707 -0.0443  0.8369  3.8066
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.005373 0.0733
#  Residual             0.168099 0.4100
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.434e-01  1.352e-02  3.640e+01
# scale(lottery_favour):treatmentA             2.389e-01  7.025e-03  1.018e+04
# scale(lottery_favour):treatmentE             2.887e-01  7.231e-03  9.652e+03
# scale(WTP):treatmentA                       -4.206e-02  7.588e-03  9.951e+03
# scale(WTP):treatmentE                       -7.518e-02  6.729e-03  1.022e+04
# scale(NPCR):treatmentA                       1.116e-02  2.010e-02  3.463e+01
# scale(NPCR):treatmentE                       5.222e-03  2.047e-02  3.481e+01
# scale(x0):treatmentA                         1.649e-01  2.062e-02  3.454e+01
# scale(x0):treatmentE                         1.102e-01  2.749e-02  3.477e+01
# scale(reflection):treatmentA                 3.542e-02  2.515e-02  3.487e+01
# scale(reflection):treatmentE                 8.157e-02  2.161e-02  3.499e+01
# scale(BNT):treatmentA                        3.515e-04  2.818e-02  3.474e+01
# scale(BNT):treatmentE                       -1.460e-02  1.851e-02  3.477e+01
# scale(NFC):treatmentA                       -2.575e-02  2.445e-02  3.461e+01
# scale(NFC):treatmentE                       -1.338e-02  1.579e-02  3.473e+01
# scale(FI):treatmentA                         3.640e-02  1.825e-02  3.487e+01
# scale(FI):treatmentE                         7.732e-02  2.098e-02  3.488e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.107e-02  6.101e-03  7.665e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.742e-02  5.605e-03  8.977e+03
# scale(NPCR):scale(x0):treatmentA             1.828e-02  1.969e-02  3.450e+01
# scale(NPCR):scale(x0):treatmentE             8.667e-02  3.849e-02  3.467e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  32.810  < 2e-16 ***
# scale(lottery_favour):treatmentA             34.001  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.931  < 2e-16 ***
# scale(WTP):treatmentA                        -5.543 3.06e-08 ***
# scale(WTP):treatmentE                       -11.172  < 2e-16 ***
# scale(NPCR):treatmentA                        0.555 0.582243
# scale(NPCR):treatmentE                        0.255 0.800131
# scale(x0):treatmentA                          7.994 2.30e-09 ***
# scale(x0):treatmentE                          4.007 0.000308 ***
# scale(reflection):treatmentA                  1.409 0.167799
# scale(reflection):treatmentE                  3.775 0.000596 ***
# scale(BNT):treatmentA                         0.012 0.990118
# scale(BNT):treatmentE                        -0.789 0.435502
# scale(NFC):treatmentA                        -1.053 0.299459
# scale(NFC):treatmentE                        -0.847 0.402574
# scale(FI):treatmentA                          1.994 0.054032 .
# scale(FI):treatmentE                          3.685 0.000771 ***
# scale(lottery_favour):scale(WTP):treatmentA  -1.815 0.069582 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.677 2.59e-11 ***
# scale(NPCR):scale(x0):treatmentA              0.929 0.359450
# scale(NPCR):scale(x0):treatmentE              2.252 0.030767 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# Low-attention subjects removed; with psychometrics; with interaction
summary(lmer(slc_lot ~ (scale(lottery_favour)*scale(WTP) + scale(NPCR)*scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) + scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment + (1|subject), data2))
# Out:
# Correlation matrix not shown by default, as p = 29 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: slc_lot ~ (scale(lottery_favour) * scale(WTP) + scale(NPCR) *
#     scale(x0) + scale(reflection) + scale(BNT) + scale(NFC) +
#     scale(FI) + scale(NPCR):scale(reflection) + scale(NPCR):scale(BNT) +
#     scale(NPCR):scale(NFC) + scale(NPCR):scale(FI)):treatment +
#     (1 | subject)
#    Data: data2
#
# REML criterion at convergence: 11251.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.4810 -0.8695 -0.0426  0.8359  3.8015
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.004466 0.06683
#  Residual             0.168100 0.41000
# Number of obs: 10425, groups:  subject, 50
#
# Fixed effects:
#                                               Estimate Std. Error         df
# (Intercept)                                  4.552e-01  1.397e-02  2.771e+01
# scale(lottery_favour):treatmentA             2.395e-01  7.050e-03  1.037e+04
# scale(lottery_favour):treatmentE             2.882e-01  7.227e-03  9.247e+03
# scale(WTP):treatmentA                       -4.134e-02  7.615e-03  1.023e+04
# scale(WTP):treatmentE                       -7.549e-02  6.726e-03  1.006e+04
# scale(NPCR):treatmentA                       1.831e-02  2.288e-02  2.638e+01
# scale(NPCR):treatmentE                       6.216e-02  2.855e-02  2.621e+01
# scale(x0):treatmentA                         1.664e-01  2.075e-02  2.646e+01
# scale(x0):treatmentE                         1.207e-01  2.619e-02  2.661e+01
# scale(reflection):treatmentA                 5.137e-02  2.558e-02  2.686e+01
# scale(reflection):treatmentE                 7.765e-02  2.120e-02  2.687e+01
# scale(BNT):treatmentA                       -1.649e-02  2.839e-02  2.664e+01
# scale(BNT):treatmentE                       -1.374e-02  1.851e-02  2.647e+01
# scale(NFC):treatmentA                       -2.671e-02  2.409e-02  2.638e+01
# scale(NFC):treatmentE                       -3.707e-02  1.614e-02  2.657e+01
# scale(FI):treatmentA                         3.775e-02  1.872e-02  2.683e+01
# scale(FI):treatmentE                         7.143e-02  1.978e-02  2.666e+01
# scale(lottery_favour):scale(WTP):treatmentA -1.143e-02  6.102e-03  7.001e+03
# scale(lottery_favour):scale(WTP):treatmentE -3.716e-02  5.598e-03  8.178e+03
# scale(NPCR):scale(x0):treatmentA             2.639e-02  2.271e-02  2.682e+01
# scale(NPCR):scale(x0):treatmentE             1.075e-01  4.375e-02  2.640e+01
# scale(NPCR):scale(reflection):treatmentA     2.706e-02  2.840e-02  2.661e+01
# scale(NPCR):scale(reflection):treatmentE    -5.744e-02  3.387e-02  2.622e+01
# scale(NPCR):scale(BNT):treatmentA           -3.472e-02  3.042e-02  2.669e+01
# scale(NPCR):scale(BNT):treatmentE            3.509e-02  2.597e-02  2.621e+01
# scale(NPCR):scale(NFC):treatmentA            8.513e-03  1.637e-02  2.697e+01
# scale(NPCR):scale(NFC):treatmentE            5.110e-02  1.615e-02  2.624e+01
# scale(NPCR):scale(FI):treatmentA             1.341e-02  2.712e-02  2.692e+01
# scale(NPCR):scale(FI):treatmentE            -1.230e-02  2.637e-02  2.642e+01
#                                             t value Pr(>|t|)
# (Intercept)                                  32.578  < 2e-16 ***
# scale(lottery_favour):treatmentA             33.974  < 2e-16 ***
# scale(lottery_favour):treatmentE             39.881  < 2e-16 ***
# scale(WTP):treatmentA                        -5.428 5.83e-08 ***
# scale(WTP):treatmentE                       -11.223  < 2e-16 ***
# scale(NPCR):treatmentA                        0.800  0.43076
# scale(NPCR):treatmentE                        2.177  0.03865 *
# scale(x0):treatmentA                          8.017 1.50e-08 ***
# scale(x0):treatmentE                          4.609 8.97e-05 ***
# scale(reflection):treatmentA                  2.008  0.05478 .
# scale(reflection):treatmentE                  3.664  0.00108 **
# scale(BNT):treatmentA                        -0.581  0.56620
# scale(BNT):treatmentE                        -0.742  0.46454
# scale(NFC):treatmentA                        -1.109  0.27742
# scale(NFC):treatmentE                        -2.297  0.02976 *
# scale(FI):treatmentA                          2.016  0.05391 .
# scale(FI):treatmentE                          3.611  0.00124 **
# scale(lottery_favour):scale(WTP):treatmentA  -1.873  0.06109 .
# scale(lottery_favour):scale(WTP):treatmentE  -6.638 3.38e-11 ***
# scale(NPCR):scale(x0):treatmentA              1.162  0.25535
# scale(NPCR):scale(x0):treatmentE              2.457  0.02087 *
# scale(NPCR):scale(reflection):treatmentA      0.953  0.34921
# scale(NPCR):scale(reflection):treatmentE     -1.696  0.10174
# scale(NPCR):scale(BNT):treatmentA            -1.141  0.26388
# scale(NPCR):scale(BNT):treatmentE             1.351  0.18826
# scale(NPCR):scale(NFC):treatmentA             0.520  0.60724
# scale(NPCR):scale(NFC):treatmentE             3.164  0.00391 **
# scale(NPCR):scale(FI):treatmentA              0.495  0.62491
# scale(NPCR):scale(FI):treatmentE             -0.467  0.64462
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # RT analysis

# %%
# all subjects 
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45378.7  45439.6 -22681.4  45362.7    14979
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4641 -0.6078 -0.2815  0.2766 12.8588
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2449   0.4949
#  Residual             0.3978   0.6307
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.319494   0.127343  18.215  < 2e-16 ***
# scale(value_diff)            -0.047105   0.008963  -5.255 1.48e-07 ***
# scale(WTP)                   -0.014621   0.010495  -1.393   0.1636
# slc_lot                       0.045321   0.018174   2.494   0.0126 *
# treatmentE                    0.194114   0.179420   1.082   0.2793
# scale(value_diff):scale(WTP)  0.029356   0.007086   4.143 3.43e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt trtmnE
# scl(vl_dff) -0.010
# scale(WTP)   0.016 -0.247
# slc_lot     -0.066  0.059 -0.023
# treatmentE  -0.707  0.008 -0.018  0.002
# sc(_):(WTP) -0.001 -0.177 -0.175 -0.126 -0.005
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot):treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45365.3  45449.0 -22671.6  45343.3    14976
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4657 -0.6080 -0.2821  0.2771 12.9894
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2476   0.4976
#  Residual             0.3967   0.6299
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.408249   0.090715  26.547  < 2e-16
# scale(value_diff):treatmentA            -0.027841   0.011680  -2.384  0.01714
# scale(value_diff):treatmentE            -0.095725   0.015094  -6.342 2.27e-10
# scale(WTP):treatmentA                   -0.040187   0.014954  -2.687  0.00720
# scale(WTP):treatmentE                    0.014636   0.014612   1.002  0.31650
# slc_lot:treatmentA                       0.026114   0.024462   1.068  0.28573
# slc_lot:treatmentE                       0.074391   0.027223   2.733  0.00628
# scale(value_diff):scale(WTP):treatmentA  0.023461   0.009495   2.471  0.01348
# scale(value_diff):scale(WTP):treatmentE  0.053257   0.011513   4.626 3.73e-06
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      **
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E slc_:A slc_:E s(_):(WTP):A
# scl(vl_d):A  -0.010
# scl(vl_d):E   0.004  0.000
# scl(WTP):tA   0.015 -0.229  0.000
# scl(WTP):tE  -0.007  0.000 -0.248  0.000
# slc_lt:trtA  -0.064  0.103  0.000 -0.041    0.000
# slc_lt:trtE  -0.064  0.001  0.012 -0.001   -0.010    0.004
# s(_):(WTP):A -0.004 -0.029  0.000 -0.203    0.000   -0.110  0.000
# s(_):(WTP):E -0.008  0.000 -0.409  0.000   -0.119    0.001 -0.123  0.000

# %%
# all subjects; with Psychometrics
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45380.1  45471.5 -22678.1  45356.1    14975
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4646 -0.6088 -0.2814  0.2765 12.8728
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2236   0.4728
#  Residual             0.3975   0.6305
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.326512   0.122903  18.930  < 2e-16 ***
# scale(value_diff)            -0.047015   0.008964  -5.245 1.57e-07 ***
# scale(WTP)                   -0.014546   0.010496  -1.386    0.166
# slc_lot                       0.045161   0.018174   2.485    0.013 *
# scale(reflection)             0.168152   0.104304   1.612    0.107
# scale(BNT)                    0.031720   0.102289   0.310    0.756
# scale(NFC)                    0.046857   0.087243   0.537    0.591
# scale(FI)                    -0.078089   0.086956  -0.898    0.369
# treatmentE                    0.173602   0.175141   0.991    0.322
# scale(value_diff):scale(WTP)  0.029379   0.007087   4.145 3.39e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt scl(r) s(BNT) s(NFC) sc(FI) trtmnE
# scl(vl_dff) -0.010
# scale(WTP)   0.016 -0.247
# slc_lot     -0.069  0.059 -0.023
# scl(rflctn)  0.104  0.004  0.001 -0.006
# scale(BNT)  -0.131  0.003  0.001  0.000 -0.538
# scale(NFC)  -0.067 -0.003  0.010  0.002 -0.140  0.086
# scale(FI)   -0.031  0.001  0.002 -0.003  0.140  0.011  0.051
# treatmentE  -0.715  0.008 -0.018  0.003 -0.158  0.181  0.091  0.045
# sc(_):(WTP) -0.002 -0.177 -0.174 -0.126 -0.002  0.002  0.004  0.000 -0.005
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0199534 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 17 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45370.0  45514.7 -22666.0  45332.0    14968
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4667 -0.6085 -0.2822  0.2742 13.0033
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2117   0.4601
#  Residual             0.3966   0.6298
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.426209   0.085614  28.339  < 2e-16
# scale(value_diff):treatmentA            -0.027884   0.011680  -2.387   0.0170
# scale(value_diff):treatmentE            -0.095616   0.015101  -6.332 2.42e-10
# scale(WTP):treatmentA                   -0.040110   0.014951  -2.683   0.0073
# scale(WTP):treatmentE                    0.015138   0.014614   1.036   0.3003
# slc_lot:treatmentA                       0.026200   0.024459   1.071   0.2841
# slc_lot:treatmentE                       0.074060   0.027212   2.722   0.0065
# scale(reflection):treatmentA             0.231246   0.151801   1.523   0.1277
# scale(reflection):treatmentE             0.222223   0.141736   1.568   0.1169
# scale(BNT):treatmentA                   -0.222633   0.169902  -1.310   0.1901
# scale(BNT):treatmentE                    0.155871   0.126677   1.230   0.2185
# scale(NFC):treatmentA                    0.094062   0.148724   0.632   0.5271
# scale(NFC):treatmentE                    0.059922   0.106391   0.563   0.5733
# scale(FI):treatmentA                    -0.121471   0.116879  -1.039   0.2987
# scale(FI):treatmentE                    -0.045469   0.124597  -0.365   0.7152
# scale(value_diff):scale(WTP):treatmentA  0.023620   0.009499   2.487   0.0129
# scale(value_diff):scale(WTP):treatmentE  0.053277   0.011522   4.624 3.76e-06
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      **
# scale(reflection):treatmentA
# scale(reflection):treatmentE
# scale(BNT):treatmentA
# scale(BNT):treatmentE
# scale(NFC):treatmentA
# scale(NFC):treatmentE
# scale(FI):treatmentA
# scale(FI):treatmentE
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# convergence code: 0
# Model failed to converge with max|grad| = 0.0199534 (tol = 0.001, component 1)

# %%
# all subjects; adding the variable "correct" –– whether the higher values option is chosen.
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + correct + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + correct):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ scale(value_diff) * scale(WTP) + slc_lot + correct + treatment +
#     (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45169.1  45237.6 -22575.5  45151.1    14918
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4652 -0.6064 -0.2789  0.2750 13.5606
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2460   0.4959
#  Residual             0.3979   0.6308
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.359134   0.128026  18.427  < 2e-16 ***
# scale(value_diff)            -0.042014   0.009099  -4.618 3.88e-06 ***
# scale(WTP)                   -0.018101   0.010520  -1.721 0.085318 .
# slc_lot                       0.061071   0.018830   3.243 0.001181 **
# correct                      -0.071649   0.019470  -3.680 0.000233 ***
# treatmentE                    0.193145   0.179687   1.075 0.282421
# scale(value_diff):scale(WTP)  0.027435   0.007175   3.824 0.000131 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt corrct trtmnE
# scl(vl_dff)  0.004
# scale(WTP)   0.011 -0.250
# slc_lot     -0.042  0.093 -0.045
# correct     -0.085 -0.152  0.063 -0.248
# treatmentE  -0.704  0.007 -0.018  0.001  0.001
# sc(_):(WTP) -0.009 -0.194 -0.168 -0.156  0.098 -0.005
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula: RT ~ (scale(value_diff) * scale(WTP) + slc_lot + correct):treatment +
#     (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#    45156    45255   -22565    45130    14914
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4674 -0.6078 -0.2793  0.2723 13.4339
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2494   0.4994
#  Residual             0.3967   0.6298
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.449656   0.091732  26.705  < 2e-16
# scale(value_diff):treatmentA            -0.025027   0.011779  -2.125 0.033616
# scale(value_diff):treatmentE            -0.085575   0.015490  -5.525 3.30e-08
# scale(WTP):treatmentA                   -0.039905   0.014964  -2.667 0.007659
# scale(WTP):treatmentE                    0.005161   0.014759   0.350 0.726563
# slc_lot:treatmentA                       0.030456   0.024635   1.236 0.216353
# slc_lot:treatmentE                       0.115118   0.030273   3.803 0.000143
# correct:treatmentA                      -0.051342   0.025453  -2.017 0.043684
# correct:treatmentE                      -0.104373   0.031207  -3.345 0.000824
# scale(value_diff):scale(WTP):treatmentA  0.022120   0.009572   2.311 0.020832
# scale(value_diff):scale(WTP):treatmentE  0.048416   0.011757   4.118 3.82e-05
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      ***
# correct:treatmentA                      *
# correct:treatmentE                      ***
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E slc_:A slc_:E crrc:A crrc:E
# scl(vl_d):A   0.000
# scl(vl_d):E   0.022  0.000
# scl(WTP):tA   0.016 -0.228  0.000
# scl(WTP):tE  -0.019  0.000 -0.262  0.000
# slc_lt:trtA  -0.055  0.112 -0.001 -0.046    0.001
# slc_lt:trtE  -0.021  0.000  0.100  0.000   -0.085    0.001
# crrct:trtmA  -0.088 -0.117 -0.002 -0.007    0.002   -0.096  0.002
# crrct:trtmE  -0.086  0.000 -0.210 -0.001    0.151    0.005 -0.428  0.007
# s(_):(WTP):A -0.010 -0.037  0.000 -0.205    0.000   -0.124  0.000  0.069  0.001
# s(_):(WTP):E -0.021  0.000 -0.433  0.000   -0.091    0.001 -0.196  0.002  0.172
#              s(_):(WTP):A
# scl(vl_d):A
# scl(vl_d):E
# scl(WTP):tA
# scl(WTP):tE
# slc_lt:trtA
# slc_lt:trtE
# crrct:trtmA
# crrct:trtmE
# s(_):(WTP):A
# s(_):(WTP):E  0.000

# %%
# all subjects; adding the variable "correct"; with Psychometrics
summary(glmer(RT ~ scale(value_diff)*scale(WTP) + slc_lot + correct + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + treatment + (1|subject), data1, family = Gamma(link = "identity")))
summary(glmer(RT ~ (scale(value_diff)*scale(WTP) + slc_lot + correct + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1, family = Gamma(link = "identity")))
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.00131282 (tol = 0.001, component 1)”
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula:
# RT ~ scale(value_diff) * scale(WTP) + slc_lot + correct + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45170.4  45269.3 -22572.2  45144.4    14914
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4658 -0.6067 -0.2797  0.2751 13.5778
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2243   0.4736
#  Residual             0.3976   0.6305
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error t value Pr(>|z|)
# (Intercept)                   2.366565   0.123510  19.161  < 2e-16 ***
# scale(value_diff)            -0.041909   0.009100  -4.606 4.11e-06 ***
# scale(WTP)                   -0.018029   0.010521  -1.714 0.086594 .
# slc_lot                       0.060975   0.018830   3.238 0.001203 **
# correct                      -0.071869   0.019471  -3.691 0.000223 ***
# scale(reflection)             0.170841   0.104414   1.636 0.101801
# scale(BNT)                    0.031612   0.102392   0.309 0.757519
# scale(NFC)                    0.044839   0.087349   0.513 0.607716
# scale(FI)                    -0.077356   0.087060  -0.889 0.374250
# treatmentE                    0.171967   0.175265   0.981 0.326503
# scale(value_diff):scale(WTP)  0.027445   0.007177   3.824 0.000131 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) slc_lt corrct scl(r) s(BNT) s(NFC) sc(FI)
# scl(vl_dff)  0.004
# scale(WTP)   0.011 -0.250
# slc_lot     -0.044  0.093 -0.045
# correct     -0.089 -0.152  0.063 -0.248
# scl(rflctn)  0.104  0.005  0.001 -0.004 -0.006
# scale(BNT)  -0.130  0.003  0.001  0.000 -0.002 -0.538
# scale(NFC)  -0.067 -0.004  0.010  0.001  0.005 -0.140  0.086
# scale(FI)   -0.030  0.001  0.002 -0.003 -0.003  0.140  0.011  0.051
# treatmentE  -0.712  0.007 -0.017  0.002  0.001 -0.158  0.181  0.090  0.045
# sc(_):(WTP) -0.010 -0.194 -0.168 -0.156  0.098 -0.003  0.002  0.004  0.000
#             trtmnE
# scl(vl_dff)
# scale(WTP)
# slc_lot
# correct
# scl(rflctn)
# scale(BNT)
# scale(NFC)
# scale(FI)
# treatmentE
# sc(_):(WTP) -0.004
# convergence code: 0
# Model failed to converge with max|grad| = 0.00131282 (tol = 0.001, component 1)
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0101913 (tol = 0.001, component 1)”
# Correlation matrix not shown by default, as p = 19 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: Gamma  ( identity )
# Formula:
# RT ~ (scale(value_diff) * scale(WTP) + slc_lot + correct + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  45160.6  45320.5 -22559.3  45118.6    14906
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4685 -0.6090 -0.2796  0.2726 13.4444
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.2132   0.4617
#  Residual             0.3966   0.6297
# Number of obs: 14927, groups:  subject, 72
#
# Fixed effects:
#                                          Estimate Std. Error t value Pr(>|z|)
# (Intercept)                              2.467429   0.086629  28.483  < 2e-16
# scale(value_diff):treatmentA            -0.025070   0.011780  -2.128 0.033331
# scale(value_diff):treatmentE            -0.085402   0.015492  -5.512 3.54e-08
# scale(WTP):treatmentA                   -0.039912   0.014960  -2.668 0.007633
# scale(WTP):treatmentE                    0.005513   0.014759   0.374 0.708774
# slc_lot:treatmentA                       0.030492   0.024633   1.238 0.215761
# slc_lot:treatmentE                       0.115405   0.030272   3.812 0.000138
# correct:treatmentA                      -0.050826   0.025440  -1.998 0.045732
# correct:treatmentE                      -0.105554   0.031193  -3.384 0.000715
# scale(reflection):treatmentA             0.235765   0.152261   1.548 0.121519
# scale(reflection):treatmentE             0.228020   0.142245   1.603 0.108933
# scale(BNT):treatmentA                   -0.226014   0.170393  -1.326 0.184698
# scale(BNT):treatmentE                    0.153547   0.127100   1.208 0.227017
# scale(NFC):treatmentA                    0.091302   0.149170   0.612 0.540495
# scale(NFC):treatmentE                    0.056887   0.106753   0.533 0.594112
# scale(FI):treatmentA                    -0.121890   0.117235  -1.040 0.298474
# scale(FI):treatmentE                    -0.044398   0.125002  -0.355 0.722455
# scale(value_diff):scale(WTP):treatmentA  0.022204   0.009574   2.319 0.020378
# scale(value_diff):scale(WTP):treatmentE  0.048387   0.011763   4.114 3.90e-05
#
# (Intercept)                             ***
# scale(value_diff):treatmentA            *
# scale(value_diff):treatmentE            ***
# scale(WTP):treatmentA                   **
# scale(WTP):treatmentE
# slc_lot:treatmentA
# slc_lot:treatmentE                      ***
# correct:treatmentA                      *
# correct:treatmentE                      ***
# scale(reflection):treatmentA
# scale(reflection):treatmentE
# scale(BNT):treatmentA
# scale(BNT):treatmentE
# scale(NFC):treatmentA
# scale(NFC):treatmentE
# scale(FI):treatmentA
# scale(FI):treatmentE
# scale(value_diff):scale(WTP):treatmentA *
# scale(value_diff):scale(WTP):treatmentE ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# convergence code: 0
# Model failed to converge with max|grad| = 0.0101913 (tol = 0.001, component 1)

# %% [markdown]
# # Others

# %% [markdown]
# ### Is the chance of choosing lottery affected by the treatments?

# %%
# All subjects
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16845.0  16890.7  -8416.5  16833.0    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1540 -0.7438 -0.1979  0.7181 17.7393
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8703   0.9329
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.12833    0.15834   0.810 0.417677
# scale(lottery_favour)             1.24103    0.03118  39.801  < 2e-16 ***
# scale(WTP)                       -0.08056    0.02384  -3.379 0.000728 ***
# treatmentE                       -0.40199    0.22341  -1.799 0.071962 .
# scale(lottery_favour):scale(WTP) -0.27586    0.02244 -12.292  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE
# scl(lttry_)  0.025
# scale(WTP)   0.038 -0.233
# treatmentE  -0.707 -0.031 -0.022
# sc(_):(WTP) -0.068 -0.371 -0.314  0.019

# %%
# All subjects; with Psychometrics
summary(glmer(slc_lot ~ scale(lottery_favour)*scale(WTP) + treatment + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# slc_lot ~ scale(lottery_favour) * scale(WTP) + treatment + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  16850.9  16927.0  -8415.4  16830.9    14977
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -5.1803 -0.7442 -0.1977  0.7183 17.7803
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.8436   0.9185
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                    Estimate Std. Error z value Pr(>|z|)
# (Intercept)                       0.1282090  0.1578054   0.812 0.416533
# scale(lottery_favour)             1.2411467  0.0311809  39.805  < 2e-16 ***
# scale(WTP)                       -0.0804728  0.0238446  -3.375 0.000738 ***
# treatmentE                       -0.4040850  0.2252312  -1.794 0.072799 .
# scale(reflection)                 0.1332754  0.1338225   0.996 0.319293
# scale(BNT)                       -0.0006891  0.1318357  -0.005 0.995830
# scale(NFC)                        0.0479075  0.1118469   0.428 0.668410
# scale(FI)                         0.1058226  0.1120677   0.944 0.345030
# scale(lottery_favour):scale(WTP) -0.2756307  0.0224418 -12.282  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE scl(r) s(BNT) s(NFC) sc(FI)
# scl(lttry_)  0.024
# scale(WTP)   0.037 -0.233
# treatmentE  -0.715 -0.031 -0.020
# scl(rflctn)  0.109  0.008  0.000 -0.158
# scale(BNT)  -0.132 -0.002  0.000  0.182 -0.537
# scale(NFC)  -0.066  0.016  0.014  0.093 -0.140  0.088
# scale(FI)   -0.033  0.005  0.001  0.044  0.137  0.014  0.049
# sc(_):(WTP) -0.069 -0.370 -0.313  0.019 -0.002  0.007 -0.007  0.004

# %% [markdown]
# ### Is the decision consistency affected by the treatments?

# %%
# All subjects
summary(glmer(incorrect ~ scale(value_diff)*scale(WTP) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: incorrect ~ scale(value_diff) * scale(WTP) + treatment + (1 |
#     subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17689.2  17734.8  -8838.6  17677.2    14981
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8171 -0.7271 -0.4535  0.9741  7.9535
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.5099   0.7141
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -0.79516    0.12221  -6.506 7.70e-11 ***
# scale(value_diff)            -0.52918    0.02458 -21.528  < 2e-16 ***
# scale(WTP)                    0.16560    0.02148   7.709 1.26e-14 ***
# treatmentE                   -0.01436    0.17256  -0.083    0.934
# scale(value_diff):scale(WTP)  0.17677    0.01746  10.122  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) trtmnE
# scl(vl_dff)  0.043
# scale(WTP)   0.014 -0.321
# treatmentE  -0.706  0.004 -0.032
# sc(_):(WTP) -0.058 -0.385 -0.054  0.000

# %%
# All subjects; with Psychometrics
summary(glmer(incorrect ~ scale(value_diff)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI) + treatment + (1|subject), data1, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: incorrect ~ scale(value_diff) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI) + treatment + (1 | subject)
#    Data: data1
#
#      AIC      BIC   logLik deviance df.resid
#  17679.5  17755.6  -8829.7  17659.5    14977
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8230 -0.7279 -0.4537  0.9761  7.8397
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 0.3951   0.6286
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -0.803011   0.109664  -7.322 2.43e-13 ***
# scale(value_diff)            -0.528724   0.024575 -21.514  < 2e-16 ***
# scale(WTP)                    0.164999   0.021458   7.689 1.48e-14 ***
# scale(reflection)            -0.283632   0.093129  -3.046  0.00232 **
# scale(BNT)                   -0.082866   0.091780  -0.903  0.36659
# scale(NFC)                    0.088709   0.077808   1.140  0.25425
# scale(FI)                    -0.133317   0.077745  -1.715  0.08638 .
# treatmentE                    0.006196   0.156605   0.040  0.96844
# scale(value_diff):scale(WTP)  0.176919   0.017456  10.135  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) scl(_) s(WTP) scl(r) s(BNT) s(NFC) sc(FI) trtmnE
# scl(vl_dff)  0.048
# scale(WTP)   0.014 -0.321
# scl(rflctn)  0.112  0.008  0.001
# scale(BNT)  -0.131  0.008  0.001 -0.534
# scale(NFC)  -0.067 -0.006  0.024 -0.139  0.086
# scale(FI)   -0.032  0.002  0.002  0.138  0.018  0.049
# treatmentE  -0.714  0.005 -0.033 -0.157  0.183  0.092  0.047
# sc(_):(WTP) -0.065 -0.385 -0.054 -0.006  0.001  0.010  0.000  0.001

# %% [markdown]
# ### Decision consistency and value difference

# %%
# All subjects
summary(lmer(incorrect ~ (scale(value_diff)*scale(WTP)):treatment + (1|subject), data1))
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: incorrect ~ (scale(value_diff) * scale(WTP)):treatment + (1 |
#     subject)
#    Data: data1
#
# REML criterion at convergence: 18671.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.6475 -0.7884 -0.4099  1.1035  2.4895
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.02039  0.1428
#  Residual             0.19981  0.4470
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              3.334e-01  1.726e-02  7.146e+01
# scale(value_diff):treatmentA            -8.291e-02  5.320e-03  1.497e+04
# scale(value_diff):treatmentE            -1.060e-01  6.228e-03  1.496e+04
# scale(WTP):treatmentA                    6.321e-03  6.336e-03  1.477e+04
# scale(WTP):treatmentE                    4.947e-02  5.906e-03  1.496e+04
# scale(value_diff):scale(WTP):treatmentA  1.590e-02  4.484e-03  1.497e+04
# scale(value_diff):scale(WTP):treatmentE  3.947e-02  4.734e-03  1.498e+04
#                                         t value Pr(>|t|)
# (Intercept)                              19.321  < 2e-16 ***
# scale(value_diff):treatmentA            -15.584  < 2e-16 ***
# scale(value_diff):treatmentE            -17.020  < 2e-16 ***
# scale(WTP):treatmentA                     0.998 0.318497
# scale(WTP):treatmentE                     8.376  < 2e-16 ***
# scale(value_diff):scale(WTP):treatmentA   3.546 0.000392 ***
# scale(value_diff):scale(WTP):treatmentE   8.336  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#              (Intr) s(_):A s(_):E s(WTP):A s(WTP):E s(_):(WTP):A
# scl(vl_d):A  -0.007
# scl(vl_d):E   0.023  0.000
# scl(WTP):tA   0.032 -0.247  0.001
# scl(WTP):tE  -0.018  0.000 -0.269 -0.001
# s(_):(WTP):A -0.033  0.061 -0.001 -0.219    0.001
# s(_):(WTP):E -0.043  0.000 -0.375 -0.001   -0.132    0.001

# %%
# All subjects; with Psychometrics
summary(lmer(incorrect ~ (scale(value_diff)*scale(WTP) + scale(reflection) + scale(BNT) + scale(NFC) + scale(FI)):treatment + (1|subject), data1))
# Out:
# Correlation matrix not shown by default, as p = 15 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: incorrect ~ (scale(value_diff) * scale(WTP) + scale(reflection) +
#     scale(BNT) + scale(NFC) + scale(FI)):treatment + (1 | subject)
#    Data: data1
#
# REML criterion at convergence: 18699.5
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.6448 -0.7876 -0.4071  1.1023  2.4746
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  subject  (Intercept) 0.01807  0.1344
#  Residual             0.19981  0.4470
# Number of obs: 14987, groups:  subject, 72
#
# Fixed effects:
#                                           Estimate Std. Error         df
# (Intercept)                              3.340e-01  1.671e-02  6.341e+01
# scale(value_diff):treatmentA            -8.313e-02  5.320e-03  1.497e+04
# scale(value_diff):treatmentE            -1.057e-01  6.228e-03  1.496e+04
# scale(WTP):treatmentA                    6.772e-03  6.334e-03  1.466e+04
# scale(WTP):treatmentE                    4.899e-02  5.908e-03  1.495e+04
# scale(reflection):treatmentA            -4.151e-02  2.961e-02  6.285e+01
# scale(reflection):treatmentE            -6.080e-02  2.777e-02  6.295e+01
# scale(BNT):treatmentA                   -2.886e-02  3.340e-02  6.296e+01
# scale(BNT):treatmentE                   -1.205e-02  2.476e-02  6.286e+01
# scale(NFC):treatmentA                    4.555e-02  2.900e-02  6.292e+01
# scale(NFC):treatmentE                    3.193e-03  2.074e-02  6.295e+01
# scale(FI):treatmentA                    -1.788e-02  2.279e-02  6.289e+01
# scale(FI):treatmentE                    -3.061e-02  2.456e-02  6.293e+01
# scale(value_diff):scale(WTP):treatmentA  1.590e-02  4.484e-03  1.497e+04
# scale(value_diff):scale(WTP):treatmentE  3.942e-02  4.734e-03  1.497e+04
#                                         t value Pr(>|t|)
# (Intercept)                              19.991  < 2e-16 ***
# scale(value_diff):treatmentA            -15.626  < 2e-16 ***
# scale(value_diff):treatmentE            -16.976  < 2e-16 ***
# scale(WTP):treatmentA                     1.069 0.285021
# scale(WTP):treatmentE                     8.292  < 2e-16 ***
# scale(reflection):treatmentA             -1.402 0.165927
# scale(reflection):treatmentE             -2.190 0.032271 *
# scale(BNT):treatmentA                    -0.864 0.390928
# scale(BNT):treatmentE                    -0.487 0.628186
# scale(NFC):treatmentA                     1.571 0.121288
# scale(NFC):treatmentE                     0.154 0.878149
# scale(FI):treatmentA                     -0.784 0.435787
# scale(FI):treatmentE                     -1.246 0.217318
# scale(value_diff):scale(WTP):treatmentA   3.545 0.000394 ***
# scale(value_diff):scale(WTP):treatmentE   8.328  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
